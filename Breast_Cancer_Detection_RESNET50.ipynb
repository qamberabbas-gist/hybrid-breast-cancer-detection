# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
import os

# Define the path to the dataset directory
dataset_path = "/content/drive/MyDrive/Dataset BUSI with GT"

# Get the list of image files
image_files = []
labels = []

# Iterate over the directories
for class_name in ['benign', 'malignant', 'normal']:
    class_path = os.path.join(dataset_path, class_name)
    for filename in os.listdir(class_path):
        image_path = os.path.join(class_path, filename)
        image_files.append(image_path)
        labels.append(class_name)

# Convert labels to numerical values
from tensorflow.keras.utils import to_categorical

# Convert labels to numerical values
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
# Get the original class labels from the label encoder
original_labels = label_encoder.classes_

# Convert labels to one-hot encoded format
labels = to_categorical(labels)


# Print the mapping between numerical values and original labels
for numerical_value, original_label in enumerate(original_labels):
    print(f"Numerical Value: {numerical_value}, Original Label: {original_label}")
# Out:
# Numerical Value: 0, Original Label: benign
# Numerical Value: 1, Original Label: malignant
# Numerical Value: 2, Original Label: normal

# %% [markdown]
# ### **CNN**

# %%
X_train, X_test, y_train, y_test = train_test_split(image_files, labels, test_size=0.3, random_state=42, stratify=labels)

# %%
# Define a function to load and preprocess the images
def load_preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((150, 150))
#this converts the image to BW
    image = image.convert('L')
    image = np.array(image)
    image = image.reshape((150, 150, 1))
#image normalization
    image = image.astype('float32') / 255.0
    return image

X_train = [str(image_path) for image_path in X_train]
X_test = [str(image_path) for image_path in X_test]

# Load and preprocess the training images and labels
X_train = [load_preprocess_image(image_path) for image_path in X_train]
X_train = np.array(X_train)
y_train= np.array(y_train)

# Load and preprocess the testing images and labels
X_test= [load_preprocess_image(image_path) for image_path in X_test]
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
#Check size and color channels of images and labels
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)

#Show images
images = X_test[:10]  # Assuming X_test contains the image data
labels = y_test[:10]  # Assuming y_test contains the corresponding labels

# Convert them to class indices
class_indices = np.argmax(labels, axis=1)

# Define class labels
class_labels = ['Benign', 'Malignant', 'Normal']

num_rows = 2
num_cols = len(images) // num_rows

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display images with labels in the subplots
for i in range(len(images)):
    ax = axes[i]
    ax.imshow(images[i], cmap='gray')  # Assuming images are 2D arrays (grayscale)
    ax.set_title(f'True Label: {class_labels[class_indices[i]]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# (1104, 150, 150, 1) (1104, 3)
# (474, 150, 150, 1) (474, 3)

# %%
from keras.applications import VGG19
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, Dense, Dropout


# Load ResNet50 model without the top (fully connected) layers
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

# Create a Sequential model
model = Sequential()

# Add a custom convolutional layer to handle grayscale input
model.add(Conv2D(3, (3, 3), activation='relu', input_shape=(150, 150, 1), padding='same'))  # Adjust input_shape to (150, 150, 1)

# Add the ResNet50 base (excluding top layers)
model.add(base_model)

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top of ResNet50
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes (benign, malignant, normal)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
# Train the model and collect the history
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))


# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 35/35 [==============================] - 22s 301ms/step - loss: 1.4200 - accuracy: 0.5190 - val_loss: 0.9893 - val_accuracy: 0.5654
# Epoch 2/200
# 35/35 [==============================] - 5s 140ms/step - loss: 1.0148 - accuracy: 0.5616 - val_loss: 0.9878 - val_accuracy: 0.5654
# Epoch 3/200
# 35/35 [==============================] - 5s 144ms/step - loss: 1.0240 - accuracy: 0.5643 - val_loss: 0.9790 - val_accuracy: 0.5654
# Epoch 4/200
# 35/35 [==============================] - 5s 144ms/step - loss: 1.0145 - accuracy: 0.5643 - val_loss: 0.9775 - val_accuracy: 0.5654
# Epoch 5/200
# 35/35 [==============================] - 5s 141ms/step - loss: 1.0096 - accuracy: 0.5643 - val_loss: 1.0079 - val_accuracy: 0.5654
# Epoch 6/200
# 35/35 [==============================] - 6s 161ms/step - loss: 1.0281 - accuracy: 0.5643 - val_loss: 1.0058 - val_accuracy: 0.5654
# Epoch 7/200
# 35/35 [==============================] - 6s 161ms/step - loss: 1.0000 - accuracy: 0.5643 - val_loss: 0.9799 - val_accuracy: 0.5654
# Epoch 8/200
# 35/35 [==============================] - 6s 160ms/step - loss: 1.0100 - accuracy: 0.5589 - val_loss: 0.9870 - val_accuracy: 0.5654
# Epoch 9/200
# 35/35 [==============================] - 6s 163ms/step - loss: 1.0047 - accuracy: 0.5598 - val_loss: 0.9735 - val_accuracy: 0.5654
# Epoch 10/200
# 35/35 [==============================] - 6s 161ms/step - loss: 1.0078 - accuracy: 0.5580 - val_loss: 0.9576 - val_accuracy: 0.5654
# Epoch 11/200
# 35/35 [==============================] - 6s 161ms/step - loss: 0.9792 - accuracy: 0.5553 - val_loss: 0.9112 - val_accuracy: 0.5654
# Epoch 12/200
# 35/35 [==============================] - 5s 147ms/step - loss: 0.9447 - accuracy: 0.5652 - val_loss: 0.8385 - val_accuracy: 0.5654
# Epoch 13/200
# 35/35 [==============================] - 5s 145ms/step - loss: 0.8467 - accuracy: 0.5888 - val_loss: 0.7391 - val_accuracy: 0.6329
# Epoch 14/200
# 35/35 [==============================] - 6s 164ms/step - loss: 0.8169 - accuracy: 0.6114 - val_loss: 0.7118 - val_accuracy: 0.6456
# Epoch 15/200
# 35/35 [==============================] - 6s 163ms/step - loss: 0.7782 - accuracy: 0.6205 - val_loss: 0.6760 - val_accuracy: 0.6561
# Epoch 16/200
# 35/35 [==============================] - 6s 163ms/step - loss: 0.7650 - accuracy: 0.6223 - val_loss: 0.6706 - val_accuracy: 0.6688
# Epoch 17/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.7355 - accuracy: 0.6322 - val_loss: 0.7137 - val_accuracy: 0.6667
# Epoch 18/200
# 35/35 [==============================] - 5s 147ms/step - loss: 0.7363 - accuracy: 0.6413 - val_loss: 0.6325 - val_accuracy: 0.6603
# Epoch 19/200
# 35/35 [==============================] - 6s 164ms/step - loss: 0.7237 - accuracy: 0.6458 - val_loss: 0.6345 - val_accuracy: 0.6730
# Epoch 20/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.6911 - accuracy: 0.6422 - val_loss: 0.6310 - val_accuracy: 0.6730
# Epoch 21/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.6985 - accuracy: 0.6495 - val_loss: 0.5947 - val_accuracy: 0.6772
# Epoch 22/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.6610 - accuracy: 0.6458 - val_loss: 0.6136 - val_accuracy: 0.6624
# Epoch 23/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.6741 - accuracy: 0.6486 - val_loss: 0.5944 - val_accuracy: 0.6751
# Epoch 24/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.6694 - accuracy: 0.6467 - val_loss: 0.6121 - val_accuracy: 0.6667
# Epoch 25/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.6656 - accuracy: 0.6422 - val_loss: 0.5886 - val_accuracy: 0.6730
# Epoch 26/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.6392 - accuracy: 0.6567 - val_loss: 0.5796 - val_accuracy: 0.6772
# Epoch 27/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.6298 - accuracy: 0.6649 - val_loss: 0.5813 - val_accuracy: 0.6751
# Epoch 28/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.6246 - accuracy: 0.6621 - val_loss: 0.5690 - val_accuracy: 0.6793
# Epoch 29/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.6622 - accuracy: 0.6567 - val_loss: 0.6076 - val_accuracy: 0.6730
# Epoch 30/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.6271 - accuracy: 0.6549 - val_loss: 0.5796 - val_accuracy: 0.6793
# Epoch 31/200
# 35/35 [==============================] - 6s 164ms/step - loss: 0.6109 - accuracy: 0.6549 - val_loss: 0.5907 - val_accuracy: 0.6730
# Epoch 32/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.6323 - accuracy: 0.6513 - val_loss: 0.5871 - val_accuracy: 0.6709
# Epoch 33/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.6073 - accuracy: 0.6649 - val_loss: 0.5869 - val_accuracy: 0.6709
# Epoch 34/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.6011 - accuracy: 0.6549 - val_loss: 0.5962 - val_accuracy: 0.6709
# Epoch 35/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.6151 - accuracy: 0.6639 - val_loss: 0.5725 - val_accuracy: 0.6793
# Epoch 36/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.6037 - accuracy: 0.6540 - val_loss: 0.5993 - val_accuracy: 0.6751
# Epoch 37/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.6092 - accuracy: 0.6431 - val_loss: 0.5679 - val_accuracy: 0.6751
# Epoch 38/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.5757 - accuracy: 0.6603 - val_loss: 0.5691 - val_accuracy: 0.6772
# Epoch 39/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.5770 - accuracy: 0.6440 - val_loss: 0.5687 - val_accuracy: 0.6772
# Epoch 40/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.5781 - accuracy: 0.6594 - val_loss: 0.5789 - val_accuracy: 0.6751
# Epoch 41/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.5767 - accuracy: 0.7056 - val_loss: 0.5635 - val_accuracy: 0.7658
# Epoch 42/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.5727 - accuracy: 0.7083 - val_loss: 0.5663 - val_accuracy: 0.7806
# Epoch 43/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.5909 - accuracy: 0.7011 - val_loss: 0.5782 - val_accuracy: 0.7743
# Epoch 44/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.5693 - accuracy: 0.7147 - val_loss: 0.5755 - val_accuracy: 0.7722
# Epoch 45/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.5739 - accuracy: 0.7038 - val_loss: 0.5650 - val_accuracy: 0.7743
# Epoch 46/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.5523 - accuracy: 0.7255 - val_loss: 0.5738 - val_accuracy: 0.7595
# Epoch 47/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.5321 - accuracy: 0.7373 - val_loss: 0.5825 - val_accuracy: 0.7468
# Epoch 48/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.5314 - accuracy: 0.7364 - val_loss: 0.5643 - val_accuracy: 0.7616
# Epoch 49/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.5351 - accuracy: 0.7319 - val_loss: 0.5807 - val_accuracy: 0.7637
# Epoch 50/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.5497 - accuracy: 0.7147 - val_loss: 0.5740 - val_accuracy: 0.7785
# Epoch 51/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.5347 - accuracy: 0.7301 - val_loss: 0.6111 - val_accuracy: 0.7785
# Epoch 52/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.5244 - accuracy: 0.7428 - val_loss: 0.6163 - val_accuracy: 0.7700
# Epoch 53/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.5353 - accuracy: 0.7355 - val_loss: 0.6072 - val_accuracy: 0.7722
# Epoch 54/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.5536 - accuracy: 0.7156 - val_loss: 0.5729 - val_accuracy: 0.7806
# Epoch 55/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.5028 - accuracy: 0.7645 - val_loss: 0.6116 - val_accuracy: 0.7848
# Epoch 56/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.5298 - accuracy: 0.7391 - val_loss: 0.5854 - val_accuracy: 0.7785
# Epoch 57/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.5049 - accuracy: 0.7509 - val_loss: 0.5963 - val_accuracy: 0.7722
# Epoch 58/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.4953 - accuracy: 0.7518 - val_loss: 0.5742 - val_accuracy: 0.7932
# Epoch 59/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.5058 - accuracy: 0.7563 - val_loss: 0.6353 - val_accuracy: 0.7722
# Epoch 60/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.5063 - accuracy: 0.7473 - val_loss: 0.6676 - val_accuracy: 0.7848
# Epoch 61/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.5354 - accuracy: 0.7337 - val_loss: 0.5725 - val_accuracy: 0.7848
# Epoch 62/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.4798 - accuracy: 0.7672 - val_loss: 0.6176 - val_accuracy: 0.8101
# Epoch 63/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.4900 - accuracy: 0.7636 - val_loss: 0.6212 - val_accuracy: 0.7827
# Epoch 64/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.4707 - accuracy: 0.7654 - val_loss: 0.6088 - val_accuracy: 0.7848
# Epoch 65/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.4761 - accuracy: 0.7600 - val_loss: 0.5905 - val_accuracy: 0.7975
# Epoch 66/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.4762 - accuracy: 0.7790 - val_loss: 0.6197 - val_accuracy: 0.7954
# Epoch 67/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.4507 - accuracy: 0.7989 - val_loss: 0.5994 - val_accuracy: 0.7869
# Epoch 68/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.4634 - accuracy: 0.7699 - val_loss: 0.5632 - val_accuracy: 0.8165
# Epoch 69/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.4606 - accuracy: 0.7772 - val_loss: 0.5783 - val_accuracy: 0.8059
# Epoch 70/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.4510 - accuracy: 0.7880 - val_loss: 0.5910 - val_accuracy: 0.8207
# Epoch 71/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.4301 - accuracy: 0.8043 - val_loss: 0.6651 - val_accuracy: 0.8080
# Epoch 72/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.4248 - accuracy: 0.8025 - val_loss: 0.5973 - val_accuracy: 0.8059
# Epoch 73/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.4674 - accuracy: 0.7745 - val_loss: 0.6166 - val_accuracy: 0.8186
# Epoch 74/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.4288 - accuracy: 0.8043 - val_loss: 0.6272 - val_accuracy: 0.8186
# Epoch 75/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.4302 - accuracy: 0.8007 - val_loss: 0.6136 - val_accuracy: 0.8186
# Epoch 76/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.4216 - accuracy: 0.8071 - val_loss: 0.6111 - val_accuracy: 0.8249
# Epoch 77/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.4637 - accuracy: 0.7799 - val_loss: 0.6031 - val_accuracy: 0.8165
# Epoch 78/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.4626 - accuracy: 0.7708 - val_loss: 0.6148 - val_accuracy: 0.7911
# Epoch 79/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.4498 - accuracy: 0.7871 - val_loss: 0.5986 - val_accuracy: 0.8249
# Epoch 80/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.4512 - accuracy: 0.7853 - val_loss: 0.7047 - val_accuracy: 0.7869
# Epoch 81/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.4703 - accuracy: 0.7563 - val_loss: 0.6363 - val_accuracy: 0.7785
# Epoch 82/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.4548 - accuracy: 0.7654 - val_loss: 0.6189 - val_accuracy: 0.8312
# Epoch 83/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.4170 - accuracy: 0.7962 - val_loss: 0.6314 - val_accuracy: 0.8291
# Epoch 84/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.4000 - accuracy: 0.8125 - val_loss: 0.6231 - val_accuracy: 0.8333
# Epoch 85/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.4164 - accuracy: 0.8098 - val_loss: 0.6428 - val_accuracy: 0.8354
# Epoch 86/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3868 - accuracy: 0.8179 - val_loss: 0.6019 - val_accuracy: 0.8354
# Epoch 87/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.4254 - accuracy: 0.7998 - val_loss: 0.6547 - val_accuracy: 0.7932
# Epoch 88/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.4470 - accuracy: 0.7681 - val_loss: 0.5963 - val_accuracy: 0.8017
# Epoch 89/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.4073 - accuracy: 0.8043 - val_loss: 0.6017 - val_accuracy: 0.8186
# Epoch 90/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3818 - accuracy: 0.8261 - val_loss: 0.6429 - val_accuracy: 0.8333
# Epoch 91/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.3771 - accuracy: 0.8252 - val_loss: 0.6307 - val_accuracy: 0.8291
# Epoch 92/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.3763 - accuracy: 0.8315 - val_loss: 0.5836 - val_accuracy: 0.8312
# Epoch 93/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.3979 - accuracy: 0.8179 - val_loss: 0.6615 - val_accuracy: 0.8460
# Epoch 94/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.4154 - accuracy: 0.8025 - val_loss: 0.6096 - val_accuracy: 0.8397
# Epoch 95/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.4083 - accuracy: 0.8125 - val_loss: 0.5787 - val_accuracy: 0.8333
# Epoch 96/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.4149 - accuracy: 0.8080 - val_loss: 0.6487 - val_accuracy: 0.8418
# Epoch 97/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.3997 - accuracy: 0.8179 - val_loss: 0.6438 - val_accuracy: 0.8270
# Epoch 98/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3826 - accuracy: 0.8288 - val_loss: 0.6343 - val_accuracy: 0.8333
# Epoch 99/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.3825 - accuracy: 0.8315 - val_loss: 0.6413 - val_accuracy: 0.8165
# Epoch 100/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.3833 - accuracy: 0.8243 - val_loss: 0.6317 - val_accuracy: 0.8418
# Epoch 101/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3793 - accuracy: 0.8351 - val_loss: 0.7845 - val_accuracy: 0.8376
# Epoch 102/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.3998 - accuracy: 0.8243 - val_loss: 0.8238 - val_accuracy: 0.8418
# Epoch 103/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.4046 - accuracy: 0.8170 - val_loss: 0.6824 - val_accuracy: 0.8333
# Epoch 104/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.3740 - accuracy: 0.8288 - val_loss: 0.6166 - val_accuracy: 0.8270
# Epoch 105/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.3726 - accuracy: 0.8261 - val_loss: 0.7963 - val_accuracy: 0.8249
# Epoch 106/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3770 - accuracy: 0.8297 - val_loss: 0.6712 - val_accuracy: 0.8207
# Epoch 107/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3529 - accuracy: 0.8433 - val_loss: 0.6758 - val_accuracy: 0.8228
# Epoch 108/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.3694 - accuracy: 0.8315 - val_loss: 0.7502 - val_accuracy: 0.8418
# Epoch 109/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.3959 - accuracy: 0.8161 - val_loss: 0.7883 - val_accuracy: 0.8333
# Epoch 110/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3510 - accuracy: 0.8496 - val_loss: 0.6639 - val_accuracy: 0.8460
# Epoch 111/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3353 - accuracy: 0.8496 - val_loss: 0.7865 - val_accuracy: 0.8460
# Epoch 112/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3634 - accuracy: 0.8306 - val_loss: 0.7710 - val_accuracy: 0.8376
# Epoch 113/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3629 - accuracy: 0.8279 - val_loss: 0.6535 - val_accuracy: 0.8312
# Epoch 114/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.3591 - accuracy: 0.8415 - val_loss: 0.7603 - val_accuracy: 0.8460
# Epoch 115/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.3298 - accuracy: 0.8533 - val_loss: 0.7649 - val_accuracy: 0.8418
# Epoch 116/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3333 - accuracy: 0.8641 - val_loss: 0.7571 - val_accuracy: 0.8207
# Epoch 117/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3852 - accuracy: 0.8179 - val_loss: 0.7464 - val_accuracy: 0.8354
# Epoch 118/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.3557 - accuracy: 0.8388 - val_loss: 0.6208 - val_accuracy: 0.8439
# Epoch 119/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.3692 - accuracy: 0.8324 - val_loss: 0.7827 - val_accuracy: 0.8165
# Epoch 120/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3700 - accuracy: 0.8252 - val_loss: 0.6439 - val_accuracy: 0.8333
# Epoch 121/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3819 - accuracy: 0.8324 - val_loss: 0.6224 - val_accuracy: 0.8122
# Epoch 122/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.3578 - accuracy: 0.8496 - val_loss: 0.7807 - val_accuracy: 0.8397
# Epoch 123/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.3414 - accuracy: 0.8469 - val_loss: 0.6812 - val_accuracy: 0.8481
# Epoch 124/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.3546 - accuracy: 0.8433 - val_loss: 0.8100 - val_accuracy: 0.8228
# Epoch 125/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3079 - accuracy: 0.8605 - val_loss: 0.7620 - val_accuracy: 0.8333
# Epoch 126/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3101 - accuracy: 0.8623 - val_loss: 0.6332 - val_accuracy: 0.8460
# Epoch 127/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.3548 - accuracy: 0.8442 - val_loss: 0.8206 - val_accuracy: 0.8333
# Epoch 128/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.3378 - accuracy: 0.8442 - val_loss: 0.6645 - val_accuracy: 0.8460
# Epoch 129/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.3188 - accuracy: 0.8587 - val_loss: 0.8280 - val_accuracy: 0.8586
# Epoch 130/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.3228 - accuracy: 0.8524 - val_loss: 0.8083 - val_accuracy: 0.8249
# Epoch 131/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.3383 - accuracy: 0.8424 - val_loss: 0.8691 - val_accuracy: 0.8376
# Epoch 132/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.3396 - accuracy: 0.8451 - val_loss: 0.7313 - val_accuracy: 0.8502
# Epoch 133/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.3567 - accuracy: 0.8315 - val_loss: 0.8802 - val_accuracy: 0.8354
# Epoch 134/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3569 - accuracy: 0.8424 - val_loss: 0.8835 - val_accuracy: 0.8481
# Epoch 135/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.3357 - accuracy: 0.8469 - val_loss: 0.8528 - val_accuracy: 0.8291
# Epoch 136/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3780 - accuracy: 0.8306 - val_loss: 0.7870 - val_accuracy: 0.8354
# Epoch 137/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.3696 - accuracy: 0.8288 - val_loss: 0.9153 - val_accuracy: 0.8143
# Epoch 138/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3279 - accuracy: 0.8533 - val_loss: 1.0336 - val_accuracy: 0.8502
# Epoch 139/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.3458 - accuracy: 0.8442 - val_loss: 0.9794 - val_accuracy: 0.8270
# Epoch 140/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.3412 - accuracy: 0.8433 - val_loss: 0.7665 - val_accuracy: 0.8397
# Epoch 141/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.3408 - accuracy: 0.8514 - val_loss: 0.9181 - val_accuracy: 0.8544
# Epoch 142/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3045 - accuracy: 0.8623 - val_loss: 0.9606 - val_accuracy: 0.8502
# Epoch 143/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3169 - accuracy: 0.8596 - val_loss: 0.9517 - val_accuracy: 0.8312
# Epoch 144/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3331 - accuracy: 0.8533 - val_loss: 1.0669 - val_accuracy: 0.8502
# Epoch 145/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3153 - accuracy: 0.8632 - val_loss: 0.8970 - val_accuracy: 0.8481
# Epoch 146/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.3496 - accuracy: 0.8514 - val_loss: 0.8479 - val_accuracy: 0.8502
# Epoch 147/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.3174 - accuracy: 0.8632 - val_loss: 0.9082 - val_accuracy: 0.8544
# Epoch 148/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.3105 - accuracy: 0.8714 - val_loss: 1.0033 - val_accuracy: 0.8544
# Epoch 149/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.2845 - accuracy: 0.8822 - val_loss: 0.9846 - val_accuracy: 0.8544
# Epoch 150/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.3307 - accuracy: 0.8451 - val_loss: 0.8154 - val_accuracy: 0.8397
# Epoch 151/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.2844 - accuracy: 0.8741 - val_loss: 0.9788 - val_accuracy: 0.8460
# Epoch 152/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.2771 - accuracy: 0.8931 - val_loss: 0.9618 - val_accuracy: 0.8544
# Epoch 153/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.3165 - accuracy: 0.8551 - val_loss: 0.9934 - val_accuracy: 0.8523
# Epoch 154/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3274 - accuracy: 0.8533 - val_loss: 0.9924 - val_accuracy: 0.8586
# Epoch 155/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3257 - accuracy: 0.8578 - val_loss: 0.8301 - val_accuracy: 0.8165
# Epoch 156/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3936 - accuracy: 0.8216 - val_loss: 0.7102 - val_accuracy: 0.8080
# Epoch 157/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.3552 - accuracy: 0.8397 - val_loss: 0.8630 - val_accuracy: 0.8418
# Epoch 158/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.3326 - accuracy: 0.8524 - val_loss: 0.6992 - val_accuracy: 0.8460
# Epoch 159/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.3408 - accuracy: 0.8469 - val_loss: 0.9441 - val_accuracy: 0.8439
# Epoch 160/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.3283 - accuracy: 0.8587 - val_loss: 0.7968 - val_accuracy: 0.8312
# Epoch 161/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.2964 - accuracy: 0.8741 - val_loss: 0.9534 - val_accuracy: 0.8502
# Epoch 162/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.3003 - accuracy: 0.8696 - val_loss: 0.9709 - val_accuracy: 0.8523
# Epoch 163/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.2970 - accuracy: 0.8723 - val_loss: 0.9167 - val_accuracy: 0.8523
# Epoch 164/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.2961 - accuracy: 0.8804 - val_loss: 0.7509 - val_accuracy: 0.8544
# Epoch 165/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.2994 - accuracy: 0.8714 - val_loss: 0.8323 - val_accuracy: 0.8481
# Epoch 166/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3035 - accuracy: 0.8578 - val_loss: 0.7436 - val_accuracy: 0.8565
# Epoch 167/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.3020 - accuracy: 0.8551 - val_loss: 0.8687 - val_accuracy: 0.8460
# Epoch 168/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.2892 - accuracy: 0.8714 - val_loss: 0.7931 - val_accuracy: 0.8565
# Epoch 169/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.2711 - accuracy: 0.8877 - val_loss: 0.9037 - val_accuracy: 0.8523
# Epoch 170/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.3069 - accuracy: 0.8659 - val_loss: 0.8081 - val_accuracy: 0.8460
# Epoch 171/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.2820 - accuracy: 0.8822 - val_loss: 0.7504 - val_accuracy: 0.8418
# Epoch 172/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.2912 - accuracy: 0.8641 - val_loss: 0.7675 - val_accuracy: 0.8523
# Epoch 173/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.3108 - accuracy: 0.8641 - val_loss: 0.9697 - val_accuracy: 0.8502
# Epoch 174/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.3211 - accuracy: 0.8469 - val_loss: 0.8025 - val_accuracy: 0.8460
# Epoch 175/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.2986 - accuracy: 0.8777 - val_loss: 0.9706 - val_accuracy: 0.8544
# Epoch 176/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.2773 - accuracy: 0.8759 - val_loss: 0.8130 - val_accuracy: 0.8439
# Epoch 177/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.3149 - accuracy: 0.8560 - val_loss: 0.7634 - val_accuracy: 0.8608
# Epoch 178/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.2582 - accuracy: 0.8895 - val_loss: 0.7219 - val_accuracy: 0.8481
# Epoch 179/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3068 - accuracy: 0.8741 - val_loss: 0.6322 - val_accuracy: 0.8397
# Epoch 180/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3466 - accuracy: 0.8478 - val_loss: 0.7985 - val_accuracy: 0.8565
# Epoch 181/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3318 - accuracy: 0.8542 - val_loss: 0.7163 - val_accuracy: 0.8460
# Epoch 182/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.2956 - accuracy: 0.8659 - val_loss: 0.8170 - val_accuracy: 0.8523
# Epoch 183/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.2769 - accuracy: 0.8804 - val_loss: 0.7665 - val_accuracy: 0.8502
# Epoch 184/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.2760 - accuracy: 0.8859 - val_loss: 1.0105 - val_accuracy: 0.8544
# Epoch 185/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.2978 - accuracy: 0.8705 - val_loss: 0.7268 - val_accuracy: 0.8397
# Epoch 186/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.3146 - accuracy: 0.8614 - val_loss: 0.7373 - val_accuracy: 0.8418
# Epoch 187/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3062 - accuracy: 0.8696 - val_loss: 0.6886 - val_accuracy: 0.8460
# Epoch 188/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.2797 - accuracy: 0.8741 - val_loss: 1.0596 - val_accuracy: 0.8523
# Epoch 189/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.2516 - accuracy: 0.8986 - val_loss: 1.2087 - val_accuracy: 0.8523
# Epoch 190/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.2724 - accuracy: 0.8741 - val_loss: 0.9351 - val_accuracy: 0.8523
# Epoch 191/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.2811 - accuracy: 0.8759 - val_loss: 0.8628 - val_accuracy: 0.8523
# Epoch 192/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.2655 - accuracy: 0.8886 - val_loss: 1.0707 - val_accuracy: 0.8418
# Epoch 193/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.2821 - accuracy: 0.8822 - val_loss: 1.1390 - val_accuracy: 0.8481
# Epoch 194/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.2773 - accuracy: 0.8850 - val_loss: 1.0771 - val_accuracy: 0.8502
# Epoch 195/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.2713 - accuracy: 0.8822 - val_loss: 0.9915 - val_accuracy: 0.8544
# Epoch 196/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.2325 - accuracy: 0.8958 - val_loss: 0.9580 - val_accuracy: 0.8565
# Epoch 197/200
# 35/35 [==============================] - 6s 166ms/step - loss: 0.2867 - accuracy: 0.8696 - val_loss: 0.7517 - val_accuracy: 0.8460
# Epoch 198/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.2748 - accuracy: 0.8859 - val_loss: 1.0935 - val_accuracy: 0.8439
# Epoch 199/200
# 35/35 [==============================] - 6s 168ms/step - loss: 0.2807 - accuracy: 0.8804 - val_loss: 0.8676 - val_accuracy: 0.8397
# Epoch 200/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.2542 - accuracy: 0.8895 - val_loss: 0.9398 - val_accuracy: 0.8586
# 15/15 [==============================] - 1s 55ms/step - loss: 0.9398 - accuracy: 0.8586
# Test Accuracy: 85.86%

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 3)       30
#
#  resnet50 (Functional)       (None, 5, 5, 2048)        23587712
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 30141857 (114.98 MB)
# Trainable params: 6554145 (25.00 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
num_images_to_display = 10
selected_indices = np.random.choice(len(X_test), num_images_to_display, replace=False)
class_names = ['Benign', 'Malignant', 'Normal']
# Create a subplot grid
num_rows = 2
num_cols = num_images_to_display // num_rows
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display predictions for the selected test images
for i, index in enumerate(selected_indices):
    # Get the test image and true label
    test_image = X_test[index]
    true_label = np.argmax(y_test[index])

    # Preprocess the image
    img_array = np.expand_dims(test_image, axis=0)

    # Make predictions
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)

    # Display the image
    ax = axes[i]
    ax.imshow(test_image.reshape((150, 150)), cmap='gray')
    ax.set_title(f'True: {class_names[true_label]}, Predicted: {class_names[predicted_class]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
plt.savefig('/content/drive/MyDrive/Dataset BUSI with GT/prediction.png')
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model


# Save the trained model
model.save('/content/drive/MyDrive/Dataset BUSI with GT/modelResnet50.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
loaded_model = load_model('/content/drive/MyDrive/Dataset BUSI with GT/modelResnet50.h5')

# Evaluate the model on the test set
y_pred = loaded_model.predict(X_test)

# Convert one-hot encoded labels back to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Plot confusion matrix with seaborn
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant', 'Normal'], yticklabels=['Benign', 'Malignant', 'Normal'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot classification report
class_report = classification_report(y_true_classes, y_pred_classes, target_names=['Benign', 'Malignant', 'Normal'])
print('Classification Report:\n', class_report)
# Out:
# 15/15 [==============================] - 2s 51ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.86      0.94      0.90       268
#    Malignant       0.80      0.76      0.78       126
#       Normal       0.97      0.74      0.84        80
#
#     accuracy                           0.86       474
#    macro avg       0.88      0.81      0.84       474
# weighted avg       0.86      0.86      0.86       474

# %%
# Visualize input-to-output
for i in range(5):  # You can adjust the range based on the number of samples you want to visualize
    input_image = X_test[i].reshape((150, 150))  # Assuming your input shape is (150, 150, 1)
    output_probabilities = y_pred[i]
    predicted_class = np.argmax(output_probabilities)

    plt.figure(figsize=(8, 4))

    # Plot input image
    plt.subplot(1, 2, 1)
    plt.imshow(input_image, cmap='gray')
    plt.title('Input Image')

    # Plot output probabilities
    plt.subplot(1, 2, 2)
    plt.bar(range(len(output_probabilities)), output_probabilities)
    plt.xticks(range(len(output_probabilities)), ['Benign', 'Malignant', 'Normal'])
    plt.title('Output Probabilities')

    plt.show()
