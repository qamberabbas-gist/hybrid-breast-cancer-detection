# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
import os

# Define the path to the dataset directory
dataset_path = "/content/drive/MyDrive/Dataset BUSI with GT"

# Get the list of image files
image_files = []
labels = []

# Iterate over the directories
for class_name in ['benign', 'malignant', 'normal']:
    class_path = os.path.join(dataset_path, class_name)
    for filename in os.listdir(class_path):
        image_path = os.path.join(class_path, filename)
        image_files.append(image_path)
        labels.append(class_name)

# Convert labels to numerical values
from tensorflow.keras.utils import to_categorical

# Convert labels to numerical values
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
# Get the original class labels from the label encoder
original_labels = label_encoder.classes_

# Convert labels to one-hot encoded format
labels = to_categorical(labels)


# Print the mapping between numerical values and original labels
for numerical_value, original_label in enumerate(original_labels):
    print(f"Numerical Value: {numerical_value}, Original Label: {original_label}")
# Out:
# Numerical Value: 0, Original Label: benign
# Numerical Value: 1, Original Label: malignant
# Numerical Value: 2, Original Label: normal

# %% [markdown]
# ### **CNN**

# %%
X_train, X_test, y_train, y_test = train_test_split(image_files, labels, test_size=0.3, random_state=42, stratify=labels)

# %%
# Define a function to load and preprocess the images
def load_preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((150, 150))
#this converts the image to BW
    image = image.convert('L')
    image = np.array(image)
    image = image.reshape((150, 150, 1))
#image normalization
    image = image.astype('float32') / 255.0
    return image

X_train = [str(image_path) for image_path in X_train]
X_test = [str(image_path) for image_path in X_test]

# Load and preprocess the training images and labels
X_train = [load_preprocess_image(image_path) for image_path in X_train]
X_train = np.array(X_train)
y_train= np.array(y_train)

# Load and preprocess the testing images and labels
X_test= [load_preprocess_image(image_path) for image_path in X_test]
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
#Check size and color channels of images and labels
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)

#Show images
images = X_test[:10]  # Assuming X_test contains the image data
labels = y_test[:10]  # Assuming y_test contains the corresponding labels

# Convert them to class indices
class_indices = np.argmax(labels, axis=1)

# Define class labels
class_labels = ['Benign', 'Malignant', 'Normal']

num_rows = 2
num_cols = len(images) // num_rows

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display images with labels in the subplots
for i in range(len(images)):
    ax = axes[i]
    ax.imshow(images[i], cmap='gray')  # Assuming images are 2D arrays (grayscale)
    ax.set_title(f'True Label: {class_labels[class_indices[i]]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# (1104, 150, 150, 1) (1104, 3)
# (474, 150, 150, 1) (474, 3)

# %%
# Load InceptionV3 model without the top (fully connected) layers
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
# Create a Sequential model
model = Sequential()

# Add a custom convolutional layer to handle grayscale input
model.add(Conv2D(3, (3, 3), activation='relu', input_shape=(150, 150, 1), padding='same'))  # Adjust input_shape to (150, 150, 1)

# Add the InceptionV3 base (excluding top layers)
model.add(base_model)

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top of InceptionV3
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes (benign, malignant, normal)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step

# %%
# Train the model and collect the history
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))


# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 35/35 [==============================] - 24s 285ms/step - loss: 0.8713 - accuracy: 0.7418 - val_loss: 0.5178 - val_accuracy: 0.7975
# Epoch 2/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.4043 - accuracy: 0.8442 - val_loss: 0.4071 - val_accuracy: 0.8291
# Epoch 3/200
# 35/35 [==============================] - 3s 80ms/step - loss: 0.3174 - accuracy: 0.8841 - val_loss: 0.4649 - val_accuracy: 0.8291
# Epoch 4/200
# 35/35 [==============================] - 3s 84ms/step - loss: 0.2855 - accuracy: 0.9058 - val_loss: 0.3899 - val_accuracy: 0.8523
# Epoch 5/200
# 35/35 [==============================] - 3s 90ms/step - loss: 0.2410 - accuracy: 0.9112 - val_loss: 0.3721 - val_accuracy: 0.8565
# Epoch 6/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.1934 - accuracy: 0.9212 - val_loss: 0.4033 - val_accuracy: 0.8650
# Epoch 7/200
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1678 - accuracy: 0.9375 - val_loss: 0.3682 - val_accuracy: 0.8544
# Epoch 8/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.1356 - accuracy: 0.9574 - val_loss: 0.3907 - val_accuracy: 0.8734
# Epoch 9/200
# 35/35 [==============================] - 3s 92ms/step - loss: 0.1308 - accuracy: 0.9565 - val_loss: 0.3945 - val_accuracy: 0.8650
# Epoch 10/200
# 35/35 [==============================] - 3s 83ms/step - loss: 0.1054 - accuracy: 0.9611 - val_loss: 0.3820 - val_accuracy: 0.8755
# Epoch 11/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0775 - accuracy: 0.9692 - val_loss: 0.4264 - val_accuracy: 0.8608
# Epoch 12/200
# 35/35 [==============================] - 3s 82ms/step - loss: 0.0768 - accuracy: 0.9728 - val_loss: 0.4657 - val_accuracy: 0.8608
# Epoch 13/200
# 35/35 [==============================] - 3s 90ms/step - loss: 0.0597 - accuracy: 0.9746 - val_loss: 0.3978 - val_accuracy: 0.8755
# Epoch 14/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0472 - accuracy: 0.9882 - val_loss: 0.4152 - val_accuracy: 0.8734
# Epoch 15/200
# 35/35 [==============================] - 3s 84ms/step - loss: 0.0774 - accuracy: 0.9755 - val_loss: 0.3947 - val_accuracy: 0.8755
# Epoch 16/200
# 35/35 [==============================] - 3s 83ms/step - loss: 0.0493 - accuracy: 0.9855 - val_loss: 0.4295 - val_accuracy: 0.8650
# Epoch 17/200
# 35/35 [==============================] - 3s 84ms/step - loss: 0.0840 - accuracy: 0.9710 - val_loss: 0.4546 - val_accuracy: 0.8692
# Epoch 18/200
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0449 - accuracy: 0.9810 - val_loss: 0.5426 - val_accuracy: 0.8565
# Epoch 19/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0495 - accuracy: 0.9792 - val_loss: 0.4207 - val_accuracy: 0.8755
# Epoch 20/200
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0459 - accuracy: 0.9846 - val_loss: 0.4510 - val_accuracy: 0.8734
# Epoch 21/200
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0438 - accuracy: 0.9828 - val_loss: 0.6644 - val_accuracy: 0.8586
# Epoch 22/200
# 35/35 [==============================] - 3s 85ms/step - loss: 0.0781 - accuracy: 0.9755 - val_loss: 0.4932 - val_accuracy: 0.8650
# Epoch 23/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0671 - accuracy: 0.9746 - val_loss: 0.4853 - val_accuracy: 0.8692
# Epoch 24/200
# 35/35 [==============================] - 3s 86ms/step - loss: 0.0362 - accuracy: 0.9864 - val_loss: 0.5459 - val_accuracy: 0.8671
# Epoch 25/200
# 35/35 [==============================] - 3s 86ms/step - loss: 0.0471 - accuracy: 0.9801 - val_loss: 0.5179 - val_accuracy: 0.8713
# Epoch 26/200
# 35/35 [==============================] - 3s 86ms/step - loss: 0.0383 - accuracy: 0.9846 - val_loss: 0.5698 - val_accuracy: 0.8734
# Epoch 27/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0499 - accuracy: 0.9855 - val_loss: 0.5619 - val_accuracy: 0.8671
# Epoch 28/200
# 35/35 [==============================] - 3s 90ms/step - loss: 0.0569 - accuracy: 0.9846 - val_loss: 0.4542 - val_accuracy: 0.8882
# Epoch 29/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0480 - accuracy: 0.9855 - val_loss: 0.5412 - val_accuracy: 0.8734
# Epoch 30/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.1088 - accuracy: 0.9737 - val_loss: 0.7111 - val_accuracy: 0.8586
# Epoch 31/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0557 - accuracy: 0.9819 - val_loss: 0.6186 - val_accuracy: 0.8734
# Epoch 32/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0491 - accuracy: 0.9819 - val_loss: 0.8156 - val_accuracy: 0.8586
# Epoch 33/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.1158 - accuracy: 0.9629 - val_loss: 0.5819 - val_accuracy: 0.8650
# Epoch 34/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0685 - accuracy: 0.9810 - val_loss: 0.5735 - val_accuracy: 0.8840
# Epoch 35/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0341 - accuracy: 0.9900 - val_loss: 0.6738 - val_accuracy: 0.8650
# Epoch 36/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 0.5738 - val_accuracy: 0.8797
# Epoch 37/200
# 35/35 [==============================] - 3s 98ms/step - loss: 0.0666 - accuracy: 0.9819 - val_loss: 0.6313 - val_accuracy: 0.8586
# Epoch 38/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0992 - accuracy: 0.9774 - val_loss: 0.7635 - val_accuracy: 0.8650
# Epoch 39/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0496 - accuracy: 0.9837 - val_loss: 0.6891 - val_accuracy: 0.8713
# Epoch 40/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0780 - accuracy: 0.9819 - val_loss: 0.6384 - val_accuracy: 0.8629
# Epoch 41/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0461 - accuracy: 0.9837 - val_loss: 0.5716 - val_accuracy: 0.8650
# Epoch 42/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0326 - accuracy: 0.9873 - val_loss: 0.6457 - val_accuracy: 0.8671
# Epoch 43/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0442 - accuracy: 0.9873 - val_loss: 0.6685 - val_accuracy: 0.8692
# Epoch 44/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0269 - accuracy: 0.9909 - val_loss: 0.5818 - val_accuracy: 0.8692
# Epoch 45/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0268 - accuracy: 0.9900 - val_loss: 0.5283 - val_accuracy: 0.8776
# Epoch 46/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0196 - accuracy: 0.9918 - val_loss: 0.6455 - val_accuracy: 0.8734
# Epoch 47/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0186 - accuracy: 0.9918 - val_loss: 0.6372 - val_accuracy: 0.8713
# Epoch 48/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0198 - accuracy: 0.9946 - val_loss: 0.5789 - val_accuracy: 0.8713
# Epoch 49/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0218 - accuracy: 0.9891 - val_loss: 0.6248 - val_accuracy: 0.8692
# Epoch 50/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0129 - accuracy: 0.9973 - val_loss: 0.5961 - val_accuracy: 0.8819
# Epoch 51/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0177 - accuracy: 0.9918 - val_loss: 0.6374 - val_accuracy: 0.8713
# Epoch 52/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0176 - accuracy: 0.9937 - val_loss: 0.7599 - val_accuracy: 0.8629
# Epoch 53/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0253 - accuracy: 0.9882 - val_loss: 0.6912 - val_accuracy: 0.8797
# Epoch 54/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0225 - accuracy: 0.9937 - val_loss: 0.6770 - val_accuracy: 0.8903
# Epoch 55/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0615 - accuracy: 0.9819 - val_loss: 0.9121 - val_accuracy: 0.8544
# Epoch 56/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.1110 - accuracy: 0.9728 - val_loss: 0.6564 - val_accuracy: 0.8565
# Epoch 57/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0505 - accuracy: 0.9810 - val_loss: 0.8097 - val_accuracy: 0.8650
# Epoch 58/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0380 - accuracy: 0.9873 - val_loss: 0.5751 - val_accuracy: 0.8776
# Epoch 59/200
# 35/35 [==============================] - 3s 98ms/step - loss: 0.0518 - accuracy: 0.9891 - val_loss: 0.5864 - val_accuracy: 0.8755
# Epoch 60/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0493 - accuracy: 0.9873 - val_loss: 0.6445 - val_accuracy: 0.8713
# Epoch 61/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0595 - accuracy: 0.9846 - val_loss: 0.6664 - val_accuracy: 0.8713
# Epoch 62/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0412 - accuracy: 0.9882 - val_loss: 0.5646 - val_accuracy: 0.8776
# Epoch 63/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0195 - accuracy: 0.9955 - val_loss: 0.6628 - val_accuracy: 0.8755
# Epoch 64/200
# 35/35 [==============================] - 3s 90ms/step - loss: 0.0336 - accuracy: 0.9900 - val_loss: 0.8313 - val_accuracy: 0.8629
# Epoch 65/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0165 - accuracy: 0.9937 - val_loss: 0.9199 - val_accuracy: 0.8650
# Epoch 66/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0393 - accuracy: 0.9873 - val_loss: 0.6993 - val_accuracy: 0.8797
# Epoch 67/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0290 - accuracy: 0.9900 - val_loss: 0.8609 - val_accuracy: 0.8713
# Epoch 68/200
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 0.8748 - val_accuracy: 0.8692
# Epoch 69/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0347 - accuracy: 0.9855 - val_loss: 0.8561 - val_accuracy: 0.8734
# Epoch 70/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0262 - accuracy: 0.9918 - val_loss: 1.0023 - val_accuracy: 0.8671
# Epoch 71/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0390 - accuracy: 0.9855 - val_loss: 0.8831 - val_accuracy: 0.8629
# Epoch 72/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0385 - accuracy: 0.9873 - val_loss: 0.7726 - val_accuracy: 0.8608
# Epoch 73/200
# 35/35 [==============================] - 3s 90ms/step - loss: 0.0216 - accuracy: 0.9918 - val_loss: 0.9153 - val_accuracy: 0.8586
# Epoch 74/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0256 - accuracy: 0.9882 - val_loss: 1.0336 - val_accuracy: 0.8565
# Epoch 75/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0186 - accuracy: 0.9918 - val_loss: 0.8741 - val_accuracy: 0.8713
# Epoch 76/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0164 - accuracy: 0.9964 - val_loss: 0.9172 - val_accuracy: 0.8713
# Epoch 77/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0154 - accuracy: 0.9955 - val_loss: 0.8654 - val_accuracy: 0.8755
# Epoch 78/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.8660 - val_accuracy: 0.8797
# Epoch 79/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.7976 - val_accuracy: 0.8840
# Epoch 80/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0278 - accuracy: 0.9909 - val_loss: 0.9530 - val_accuracy: 0.8713
# Epoch 81/200
# 35/35 [==============================] - 3s 90ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.8136 - val_accuracy: 0.8776
# Epoch 82/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0215 - accuracy: 0.9918 - val_loss: 1.1129 - val_accuracy: 0.8586
# Epoch 83/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0191 - accuracy: 0.9900 - val_loss: 0.8117 - val_accuracy: 0.8776
# Epoch 84/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0088 - accuracy: 0.9955 - val_loss: 0.8303 - val_accuracy: 0.8797
# Epoch 85/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.9785 - val_accuracy: 0.8544
# Epoch 86/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0182 - accuracy: 0.9918 - val_loss: 0.7878 - val_accuracy: 0.8776
# Epoch 87/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0152 - accuracy: 0.9928 - val_loss: 0.7609 - val_accuracy: 0.8713
# Epoch 88/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0192 - accuracy: 0.9928 - val_loss: 0.8793 - val_accuracy: 0.8671
# Epoch 89/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0252 - accuracy: 0.9946 - val_loss: 0.8246 - val_accuracy: 0.8755
# Epoch 90/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0239 - accuracy: 0.9900 - val_loss: 0.7034 - val_accuracy: 0.8840
# Epoch 91/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0313 - accuracy: 0.9873 - val_loss: 0.6844 - val_accuracy: 0.8755
# Epoch 92/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0362 - accuracy: 0.9882 - val_loss: 0.6657 - val_accuracy: 0.8797
# Epoch 93/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0178 - accuracy: 0.9955 - val_loss: 0.6536 - val_accuracy: 0.8776
# Epoch 94/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 0.8749 - val_accuracy: 0.8819
# Epoch 95/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.8657 - val_accuracy: 0.8734
# Epoch 96/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 0.8032 - val_accuracy: 0.8755
# Epoch 97/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.8242 - val_accuracy: 0.8840
# Epoch 98/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0092 - accuracy: 0.9955 - val_loss: 1.0012 - val_accuracy: 0.8671
# Epoch 99/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0126 - accuracy: 0.9937 - val_loss: 0.8562 - val_accuracy: 0.8734
# Epoch 100/200
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0136 - accuracy: 0.9946 - val_loss: 0.6713 - val_accuracy: 0.8713
# Epoch 101/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0195 - accuracy: 0.9909 - val_loss: 0.7090 - val_accuracy: 0.8797
# Epoch 102/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.8013 - val_accuracy: 0.8776
# Epoch 103/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.8312 - val_accuracy: 0.8692
# Epoch 104/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.8841 - val_accuracy: 0.8776
# Epoch 105/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 1.0566 - val_accuracy: 0.8797
# Epoch 106/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0400 - accuracy: 0.9909 - val_loss: 0.8688 - val_accuracy: 0.8734
# Epoch 107/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0399 - accuracy: 0.9864 - val_loss: 0.8134 - val_accuracy: 0.8713
# Epoch 108/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0939 - accuracy: 0.9819 - val_loss: 1.0568 - val_accuracy: 0.8544
# Epoch 109/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.1551 - accuracy: 0.9692 - val_loss: 0.9616 - val_accuracy: 0.8734
# Epoch 110/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0571 - accuracy: 0.9891 - val_loss: 0.7941 - val_accuracy: 0.8586
# Epoch 111/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0497 - accuracy: 0.9828 - val_loss: 0.7210 - val_accuracy: 0.8734
# Epoch 112/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0492 - accuracy: 0.9855 - val_loss: 0.6716 - val_accuracy: 0.8776
# Epoch 113/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0855 - accuracy: 0.9783 - val_loss: 0.8426 - val_accuracy: 0.8797
# Epoch 114/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0503 - accuracy: 0.9846 - val_loss: 0.9144 - val_accuracy: 0.8755
# Epoch 115/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0236 - accuracy: 0.9928 - val_loss: 1.1018 - val_accuracy: 0.8671
# Epoch 116/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.1131 - accuracy: 0.9755 - val_loss: 1.2757 - val_accuracy: 0.8797
# Epoch 117/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0324 - accuracy: 0.9873 - val_loss: 1.2912 - val_accuracy: 0.8692
# Epoch 118/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0642 - accuracy: 0.9882 - val_loss: 1.1648 - val_accuracy: 0.8713
# Epoch 119/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0721 - accuracy: 0.9918 - val_loss: 1.0818 - val_accuracy: 0.8650
# Epoch 120/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0804 - accuracy: 0.9864 - val_loss: 0.9443 - val_accuracy: 0.8713
# Epoch 121/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0259 - accuracy: 0.9900 - val_loss: 0.9853 - val_accuracy: 0.8629
# Epoch 122/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0166 - accuracy: 0.9973 - val_loss: 1.1725 - val_accuracy: 0.8502
# Epoch 123/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0201 - accuracy: 0.9964 - val_loss: 1.0190 - val_accuracy: 0.8713
# Epoch 124/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0239 - accuracy: 0.9918 - val_loss: 0.9992 - val_accuracy: 0.8734
# Epoch 125/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0227 - accuracy: 0.9928 - val_loss: 0.9434 - val_accuracy: 0.8776
# Epoch 126/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0327 - accuracy: 0.9882 - val_loss: 1.0397 - val_accuracy: 0.8734
# Epoch 127/200
# 35/35 [==============================] - 3s 98ms/step - loss: 0.0111 - accuracy: 0.9955 - val_loss: 1.1405 - val_accuracy: 0.8840
# Epoch 128/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0117 - accuracy: 0.9946 - val_loss: 1.0407 - val_accuracy: 0.8776
# Epoch 129/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0319 - accuracy: 0.9918 - val_loss: 1.2170 - val_accuracy: 0.8629
# Epoch 130/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 1.0289 - val_accuracy: 0.8734
# Epoch 131/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0064 - accuracy: 0.9964 - val_loss: 1.1535 - val_accuracy: 0.8671
# Epoch 132/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0109 - accuracy: 0.9955 - val_loss: 1.1444 - val_accuracy: 0.8692
# Epoch 133/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0354 - accuracy: 0.9918 - val_loss: 1.6206 - val_accuracy: 0.8734
# Epoch 134/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0621 - accuracy: 0.9882 - val_loss: 1.3515 - val_accuracy: 0.8671
# Epoch 135/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0596 - accuracy: 0.9909 - val_loss: 1.2482 - val_accuracy: 0.8586
# Epoch 136/200
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0592 - accuracy: 0.9909 - val_loss: 1.0717 - val_accuracy: 0.8819
# Epoch 137/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0185 - accuracy: 0.9909 - val_loss: 1.0451 - val_accuracy: 0.8776
# Epoch 138/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0256 - accuracy: 0.9900 - val_loss: 0.9472 - val_accuracy: 0.8840
# Epoch 139/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0122 - accuracy: 0.9946 - val_loss: 0.9534 - val_accuracy: 0.8819
# Epoch 140/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0368 - accuracy: 0.9891 - val_loss: 1.0151 - val_accuracy: 0.8797
# Epoch 141/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 1.2055 - val_accuracy: 0.8608
# Epoch 142/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0207 - accuracy: 0.9909 - val_loss: 1.0859 - val_accuracy: 0.8776
# Epoch 143/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 1.1618 - val_accuracy: 0.8755
# Epoch 144/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0071 - accuracy: 0.9964 - val_loss: 1.2135 - val_accuracy: 0.8819
# Epoch 145/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0202 - accuracy: 0.9955 - val_loss: 0.9928 - val_accuracy: 0.8882
# Epoch 146/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0163 - accuracy: 0.9946 - val_loss: 1.1094 - val_accuracy: 0.8692
# Epoch 147/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0103 - accuracy: 0.9955 - val_loss: 1.0703 - val_accuracy: 0.8861
# Epoch 148/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 1.0219 - val_accuracy: 0.8861
# Epoch 149/200
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0073 - accuracy: 0.9991 - val_loss: 1.0711 - val_accuracy: 0.8882
# Epoch 150/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 1.0777 - val_accuracy: 0.8840
# Epoch 151/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0051 - accuracy: 0.9973 - val_loss: 1.0631 - val_accuracy: 0.8882
# Epoch 152/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0042 - accuracy: 0.9982 - val_loss: 1.0836 - val_accuracy: 0.8840
# Epoch 153/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 1.2083 - val_accuracy: 0.8819
# Epoch 154/200
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0041 - accuracy: 0.9982 - val_loss: 1.2508 - val_accuracy: 0.8755
# Epoch 155/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0047 - accuracy: 0.9973 - val_loss: 1.2414 - val_accuracy: 0.8797
# Epoch 156/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0100 - accuracy: 0.9946 - val_loss: 1.2654 - val_accuracy: 0.8797
# Epoch 157/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0052 - accuracy: 0.9973 - val_loss: 1.3698 - val_accuracy: 0.8713
# Epoch 158/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0037 - accuracy: 0.9973 - val_loss: 1.3267 - val_accuracy: 0.8734
# Epoch 159/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0069 - accuracy: 0.9964 - val_loss: 1.2423 - val_accuracy: 0.8797
# Epoch 160/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0053 - accuracy: 0.9973 - val_loss: 1.1234 - val_accuracy: 0.8945
# Epoch 161/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0063 - accuracy: 0.9973 - val_loss: 1.3443 - val_accuracy: 0.8797
# Epoch 162/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 1.3133 - val_accuracy: 0.8819
# Epoch 163/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0076 - accuracy: 0.9964 - val_loss: 1.2174 - val_accuracy: 0.8650
# Epoch 164/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 1.2781 - val_accuracy: 0.8734
# Epoch 165/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0146 - accuracy: 0.9928 - val_loss: 1.2077 - val_accuracy: 0.8861
# Epoch 166/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 1.0543 - val_accuracy: 0.8692
# Epoch 167/200
# 35/35 [==============================] - 3s 90ms/step - loss: 0.0097 - accuracy: 0.9955 - val_loss: 0.9940 - val_accuracy: 0.8861
# Epoch 168/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0079 - accuracy: 0.9964 - val_loss: 1.1401 - val_accuracy: 0.8755
# Epoch 169/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0139 - accuracy: 0.9937 - val_loss: 1.3017 - val_accuracy: 0.8629
# Epoch 170/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 1.1839 - val_accuracy: 0.8840
# Epoch 171/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0079 - accuracy: 0.9964 - val_loss: 1.2355 - val_accuracy: 0.8819
# Epoch 172/200
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0086 - accuracy: 0.9955 - val_loss: 1.2504 - val_accuracy: 0.8797
# Epoch 173/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0102 - accuracy: 0.9937 - val_loss: 1.1028 - val_accuracy: 0.8861
# Epoch 174/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 1.1483 - val_accuracy: 0.8776
# Epoch 175/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0080 - accuracy: 0.9955 - val_loss: 1.0496 - val_accuracy: 0.8966
# Epoch 176/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0029 - accuracy: 0.9982 - val_loss: 1.2140 - val_accuracy: 0.8903
# Epoch 177/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 1.2276 - val_accuracy: 0.8924
# Epoch 178/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0280 - accuracy: 0.9891 - val_loss: 1.1010 - val_accuracy: 0.8629
# Epoch 179/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0534 - accuracy: 0.9837 - val_loss: 1.0405 - val_accuracy: 0.8819
# Epoch 180/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0165 - accuracy: 0.9964 - val_loss: 1.2628 - val_accuracy: 0.8629
# Epoch 181/200
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0501 - accuracy: 0.9819 - val_loss: 0.9294 - val_accuracy: 0.8755
# Epoch 182/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0715 - accuracy: 0.9909 - val_loss: 1.1540 - val_accuracy: 0.8734
# Epoch 183/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0398 - accuracy: 0.9864 - val_loss: 1.2216 - val_accuracy: 0.8608
# Epoch 184/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0393 - accuracy: 0.9846 - val_loss: 1.1148 - val_accuracy: 0.8629
# Epoch 185/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0220 - accuracy: 0.9946 - val_loss: 1.1373 - val_accuracy: 0.8734
# Epoch 186/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0269 - accuracy: 0.9928 - val_loss: 1.1124 - val_accuracy: 0.8734
# Epoch 187/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 1.1701 - val_accuracy: 0.8797
# Epoch 188/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0113 - accuracy: 0.9937 - val_loss: 1.2369 - val_accuracy: 0.8755
# Epoch 189/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0106 - accuracy: 0.9946 - val_loss: 1.2178 - val_accuracy: 0.8755
# Epoch 190/200
# 35/35 [==============================] - 3s 97ms/step - loss: 0.0244 - accuracy: 0.9909 - val_loss: 1.2451 - val_accuracy: 0.8713
# Epoch 191/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0184 - accuracy: 0.9928 - val_loss: 1.0457 - val_accuracy: 0.8819
# Epoch 192/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 1.0337 - val_accuracy: 0.8819
# Epoch 193/200
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0165 - accuracy: 0.9937 - val_loss: 1.2228 - val_accuracy: 0.8797
# Epoch 194/200
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0304 - accuracy: 0.9918 - val_loss: 1.1563 - val_accuracy: 0.8755
# Epoch 195/200
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0367 - accuracy: 0.9891 - val_loss: 1.0622 - val_accuracy: 0.8819
# Epoch 196/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0309 - accuracy: 0.9909 - val_loss: 1.1159 - val_accuracy: 0.8734
# Epoch 197/200
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0240 - accuracy: 0.9918 - val_loss: 1.1878 - val_accuracy: 0.8608
# Epoch 198/200
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0382 - accuracy: 0.9837 - val_loss: 1.1383 - val_accuracy: 0.8671
# Epoch 199/200
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0474 - accuracy: 0.9837 - val_loss: 0.8720 - val_accuracy: 0.8966
# Epoch 200/200
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0194 - accuracy: 0.9928 - val_loss: 0.8824 - val_accuracy: 0.8840
# 15/15 [==============================] - 0s 30ms/step - loss: 0.8824 - accuracy: 0.8840
# Test Accuracy: 88.40%

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_94 (Conv2D)          (None, 150, 150, 3)       30
#
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 128)               2359424
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 24162625 (92.17 MB)
# Trainable params: 2359841 (9.00 MB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %%
num_images_to_display = 10
selected_indices = np.random.choice(len(X_test), num_images_to_display, replace=False)
class_names = ['Benign', 'Malignant', 'Normal']
# Create a subplot grid
num_rows = 2
num_cols = num_images_to_display // num_rows
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display predictions for the selected test images
for i, index in enumerate(selected_indices):
    # Get the test image and true label
    test_image = X_test[index]
    true_label = np.argmax(y_test[index])

    # Preprocess the image
    img_array = np.expand_dims(test_image, axis=0)

    # Make predictions
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)

    # Display the image
    ax = axes[i]
    ax.imshow(test_image.reshape((150, 150)), cmap='gray')
    ax.set_title(f'True: {class_names[true_label]}, Predicted: {class_names[predicted_class]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
plt.savefig('/content/drive/MyDrive/Dataset BUSI with GT/prediction.png')
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model


# Save the trained model
model.save('/content/drive/MyDrive/Dataset BUSI with GT/modelInceptionV3.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
loaded_model = load_model('/content/drive/MyDrive/Dataset BUSI with GT/modelInceptionV3.h5')

# Evaluate the model on the test set
y_pred = loaded_model.predict(X_test)

# Convert one-hot encoded labels back to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Plot confusion matrix with seaborn
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant', 'Normal'], yticklabels=['Benign', 'Malignant', 'Normal'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot classification report
class_report = classification_report(y_true_classes, y_pred_classes, target_names=['Benign', 'Malignant', 'Normal'])
print('Classification Report:\n', class_report)
# Out:
# 15/15 [==============================] - 2s 33ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.88      0.94      0.91       268
#    Malignant       0.85      0.81      0.83       126
#       Normal       0.94      0.80      0.86        80
#
#     accuracy                           0.88       474
#    macro avg       0.89      0.85      0.87       474
# weighted avg       0.88      0.88      0.88       474

# %%
# Visualize input-to-output
for i in range(5):  # You can adjust the range based on the number of samples you want to visualize
    input_image = X_test[i].reshape((150, 150))  # Assuming your input shape is (150, 150, 1)
    output_probabilities = y_pred[i]
    predicted_class = np.argmax(output_probabilities)

    plt.figure(figsize=(8, 4))

    # Plot input image
    plt.subplot(1, 2, 1)
    plt.imshow(input_image, cmap='gray')
    plt.title('Input Image')

    # Plot output probabilities
    plt.subplot(1, 2, 2)
    plt.bar(range(len(output_probabilities)), output_probabilities)
    plt.xticks(range(len(output_probabilities)), ['Benign', 'Malignant', 'Normal'])
    plt.title('Output Probabilities')

    plt.show()
