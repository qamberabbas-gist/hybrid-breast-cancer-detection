# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet_v2 import ResNet50V2, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
import os

# Define the path to the dataset directory
dataset_path = "/content/drive/MyDrive/Dataset BUSI with GT"

# Get the list of image files
image_files = []
labels = []

# Iterate over the directories
for class_name in ['benign', 'malignant', 'normal']:
    class_path = os.path.join(dataset_path, class_name)
    for filename in os.listdir(class_path):
        image_path = os.path.join(class_path, filename)
        image_files.append(image_path)
        labels.append(class_name)

# Convert labels to numerical values
from tensorflow.keras.utils import to_categorical

# Convert labels to numerical values
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
# Get the original class labels from the label encoder
original_labels = label_encoder.classes_

# Convert labels to one-hot encoded format
labels = to_categorical(labels)


# Print the mapping between numerical values and original labels
for numerical_value, original_label in enumerate(original_labels):
    print(f"Numerical Value: {numerical_value}, Original Label: {original_label}")
# Out:
# Numerical Value: 0, Original Label: benign
# Numerical Value: 1, Original Label: malignant
# Numerical Value: 2, Original Label: normal

# %% [markdown]
# ### **CNN**

# %%
X_train, X_test, y_train, y_test = train_test_split(image_files, labels, test_size=0.3, random_state=42, stratify=labels)

# %%
# Define a function to load and preprocess the images
def load_preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((150, 150))
#this converts the image to BW
    image = image.convert('L')
    image = np.array(image)
    image = image.reshape((150, 150, 1))
#image normalization
    image = image.astype('float32') / 255.0
    return image

X_train = [str(image_path) for image_path in X_train]
X_test = [str(image_path) for image_path in X_test]

# Load and preprocess the training images and labels
X_train = [load_preprocess_image(image_path) for image_path in X_train]
X_train = np.array(X_train)
y_train= np.array(y_train)

# Load and preprocess the testing images and labels
X_test= [load_preprocess_image(image_path) for image_path in X_test]
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
#Check size and color channels of images and labels
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)

#Show images
images = X_test[:10]  # Assuming X_test contains the image data
labels = y_test[:10]  # Assuming y_test contains the corresponding labels

# Convert them to class indices
class_indices = np.argmax(labels, axis=1)

# Define class labels
class_labels = ['Benign', 'Malignant', 'Normal']

num_rows = 2
num_cols = len(images) // num_rows

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display images with labels in the subplots
for i in range(len(images)):
    ax = axes[i]
    ax.imshow(images[i], cmap='gray')  # Assuming images are 2D arrays (grayscale)
    ax.set_title(f'True Label: {class_labels[class_indices[i]]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# (1104, 150, 150, 1) (1104, 3)
# (474, 150, 150, 1) (474, 3)

# %%
# Load ResNet50V2 model without the top (fully connected) layers
base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

# Create a Sequential model
model = Sequential()

# Add a custom convolutional layer to handle grayscale input
model.add(Conv2D(3, (3, 3), activation='relu', input_shape=(150, 150, 1), padding='same'))  # Adjust input_shape to (150, 150, 1)

# Add the ResNet50v2 base (excluding top layers)
model.add(base_model)

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top of ResNet50v2
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes (benign, malignant, normal)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 5s 0us/step

# %%
# Train the model and collect the history
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))


# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 35/35 [==============================] - 22s 290ms/step - loss: 2.7637 - accuracy: 0.7301 - val_loss: 0.6520 - val_accuracy: 0.8291
# Epoch 2/200
# 35/35 [==============================] - 5s 145ms/step - loss: 0.5833 - accuracy: 0.8415 - val_loss: 0.4103 - val_accuracy: 0.8671
# Epoch 3/200
# 35/35 [==============================] - 5s 132ms/step - loss: 0.3678 - accuracy: 0.8768 - val_loss: 0.5237 - val_accuracy: 0.8608
# Epoch 4/200
# 35/35 [==============================] - 5s 146ms/step - loss: 0.3105 - accuracy: 0.9022 - val_loss: 0.3636 - val_accuracy: 0.8861
# Epoch 5/200
# 35/35 [==============================] - 5s 146ms/step - loss: 0.2008 - accuracy: 0.9158 - val_loss: 0.3375 - val_accuracy: 0.8882
# Epoch 6/200
# 35/35 [==============================] - 5s 132ms/step - loss: 0.1755 - accuracy: 0.9266 - val_loss: 0.4325 - val_accuracy: 0.8924
# Epoch 7/200
# 35/35 [==============================] - 5s 130ms/step - loss: 0.1920 - accuracy: 0.9312 - val_loss: 0.3456 - val_accuracy: 0.8945
# Epoch 8/200
# 35/35 [==============================] - 5s 147ms/step - loss: 0.1794 - accuracy: 0.9402 - val_loss: 0.6748 - val_accuracy: 0.8924
# Epoch 9/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.1953 - accuracy: 0.9357 - val_loss: 0.3949 - val_accuracy: 0.8987
# Epoch 10/200
# 35/35 [==============================] - 5s 148ms/step - loss: 0.2569 - accuracy: 0.9429 - val_loss: 0.3870 - val_accuracy: 0.8987
# Epoch 11/200
# 35/35 [==============================] - 5s 149ms/step - loss: 0.1619 - accuracy: 0.9538 - val_loss: 0.4607 - val_accuracy: 0.8861
# Epoch 12/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.1689 - accuracy: 0.9556 - val_loss: 0.5268 - val_accuracy: 0.8924
# Epoch 13/200
# 35/35 [==============================] - 5s 132ms/step - loss: 0.1382 - accuracy: 0.9529 - val_loss: 0.6548 - val_accuracy: 0.8840
# Epoch 14/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.1531 - accuracy: 0.9411 - val_loss: 0.6608 - val_accuracy: 0.8882
# Epoch 15/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.1170 - accuracy: 0.9556 - val_loss: 0.6095 - val_accuracy: 0.8903
# Epoch 16/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.1208 - accuracy: 0.9611 - val_loss: 0.6030 - val_accuracy: 0.8987
# Epoch 17/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.1043 - accuracy: 0.9638 - val_loss: 0.6694 - val_accuracy: 0.8819
# Epoch 18/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.1220 - accuracy: 0.9556 - val_loss: 0.6543 - val_accuracy: 0.8966
# Epoch 19/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.1273 - accuracy: 0.9574 - val_loss: 0.7736 - val_accuracy: 0.8966
# Epoch 20/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0947 - accuracy: 0.9683 - val_loss: 0.6158 - val_accuracy: 0.8903
# Epoch 21/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.1459 - accuracy: 0.9583 - val_loss: 0.5630 - val_accuracy: 0.8945
# Epoch 22/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0746 - accuracy: 0.9647 - val_loss: 0.6802 - val_accuracy: 0.8840
# Epoch 23/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0964 - accuracy: 0.9629 - val_loss: 0.6680 - val_accuracy: 0.8861
# Epoch 24/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.1459 - accuracy: 0.9638 - val_loss: 0.5464 - val_accuracy: 0.8819
# Epoch 25/200
# 35/35 [==============================] - 5s 150ms/step - loss: 0.0617 - accuracy: 0.9710 - val_loss: 0.5325 - val_accuracy: 0.9008
# Epoch 26/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.0741 - accuracy: 0.9728 - val_loss: 0.5900 - val_accuracy: 0.8945
# Epoch 27/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0715 - accuracy: 0.9683 - val_loss: 0.6581 - val_accuracy: 0.8819
# Epoch 28/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0706 - accuracy: 0.9674 - val_loss: 0.5959 - val_accuracy: 0.8924
# Epoch 29/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0941 - accuracy: 0.9656 - val_loss: 0.5968 - val_accuracy: 0.8903
# Epoch 30/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0678 - accuracy: 0.9710 - val_loss: 0.7868 - val_accuracy: 0.8924
# Epoch 31/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0872 - accuracy: 0.9701 - val_loss: 0.7284 - val_accuracy: 0.8924
# Epoch 32/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0461 - accuracy: 0.9764 - val_loss: 0.6506 - val_accuracy: 0.9051
# Epoch 33/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0714 - accuracy: 0.9638 - val_loss: 0.6868 - val_accuracy: 0.9051
# Epoch 34/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0713 - accuracy: 0.9710 - val_loss: 0.6635 - val_accuracy: 0.9008
# Epoch 35/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0428 - accuracy: 0.9864 - val_loss: 0.9574 - val_accuracy: 0.8945
# Epoch 36/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0592 - accuracy: 0.9746 - val_loss: 0.9033 - val_accuracy: 0.8966
# Epoch 37/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.1649 - accuracy: 0.9674 - val_loss: 0.7178 - val_accuracy: 0.8819
# Epoch 38/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0710 - accuracy: 0.9746 - val_loss: 0.6144 - val_accuracy: 0.8882
# Epoch 39/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0830 - accuracy: 0.9719 - val_loss: 0.5719 - val_accuracy: 0.8903
# Epoch 40/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0580 - accuracy: 0.9746 - val_loss: 0.5895 - val_accuracy: 0.9008
# Epoch 41/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0750 - accuracy: 0.9746 - val_loss: 0.6359 - val_accuracy: 0.8903
# Epoch 42/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0673 - accuracy: 0.9719 - val_loss: 0.6280 - val_accuracy: 0.8903
# Epoch 43/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0473 - accuracy: 0.9746 - val_loss: 0.6622 - val_accuracy: 0.8924
# Epoch 44/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0757 - accuracy: 0.9746 - val_loss: 0.6293 - val_accuracy: 0.8840
# Epoch 45/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0588 - accuracy: 0.9746 - val_loss: 0.6371 - val_accuracy: 0.8840
# Epoch 46/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0607 - accuracy: 0.9764 - val_loss: 0.6952 - val_accuracy: 0.8776
# Epoch 47/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0782 - accuracy: 0.9683 - val_loss: 0.6251 - val_accuracy: 0.8924
# Epoch 48/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0618 - accuracy: 0.9701 - val_loss: 0.6282 - val_accuracy: 0.8987
# Epoch 49/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0604 - accuracy: 0.9746 - val_loss: 0.6823 - val_accuracy: 0.8966
# Epoch 50/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0436 - accuracy: 0.9801 - val_loss: 0.5570 - val_accuracy: 0.8966
# Epoch 51/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0524 - accuracy: 0.9783 - val_loss: 0.6381 - val_accuracy: 0.8945
# Epoch 52/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.0478 - accuracy: 0.9846 - val_loss: 0.6845 - val_accuracy: 0.8945
# Epoch 53/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0417 - accuracy: 0.9810 - val_loss: 0.7366 - val_accuracy: 0.8945
# Epoch 54/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0602 - accuracy: 0.9737 - val_loss: 0.7839 - val_accuracy: 0.8882
# Epoch 55/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0579 - accuracy: 0.9737 - val_loss: 0.6893 - val_accuracy: 0.9030
# Epoch 56/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0647 - accuracy: 0.9774 - val_loss: 0.7888 - val_accuracy: 0.9030
# Epoch 57/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0878 - accuracy: 0.9692 - val_loss: 0.7940 - val_accuracy: 0.8882
# Epoch 58/200
# 35/35 [==============================] - 5s 137ms/step - loss: 0.0918 - accuracy: 0.9692 - val_loss: 0.7573 - val_accuracy: 0.9008
# Epoch 59/200
# 35/35 [==============================] - 5s 133ms/step - loss: 0.0528 - accuracy: 0.9737 - val_loss: 0.8554 - val_accuracy: 0.8924
# Epoch 60/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0781 - accuracy: 0.9755 - val_loss: 0.7993 - val_accuracy: 0.8987
# Epoch 61/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0505 - accuracy: 0.9810 - val_loss: 0.8060 - val_accuracy: 0.8861
# Epoch 62/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0442 - accuracy: 0.9819 - val_loss: 0.9656 - val_accuracy: 0.8819
# Epoch 63/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.1313 - accuracy: 0.9701 - val_loss: 0.8926 - val_accuracy: 0.9030
# Epoch 64/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.1582 - accuracy: 0.9611 - val_loss: 0.9950 - val_accuracy: 0.8861
# Epoch 65/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.2036 - accuracy: 0.9629 - val_loss: 0.5749 - val_accuracy: 0.8882
# Epoch 66/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0976 - accuracy: 0.9728 - val_loss: 0.6289 - val_accuracy: 0.8819
# Epoch 67/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0929 - accuracy: 0.9656 - val_loss: 0.7707 - val_accuracy: 0.8819
# Epoch 68/200
# 35/35 [==============================] - 5s 133ms/step - loss: 0.1110 - accuracy: 0.9710 - val_loss: 0.5806 - val_accuracy: 0.8966
# Epoch 69/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0852 - accuracy: 0.9764 - val_loss: 0.6710 - val_accuracy: 0.8987
# Epoch 70/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0473 - accuracy: 0.9819 - val_loss: 0.8105 - val_accuracy: 0.8861
# Epoch 71/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0661 - accuracy: 0.9701 - val_loss: 0.6049 - val_accuracy: 0.9008
# Epoch 72/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0827 - accuracy: 0.9728 - val_loss: 0.6556 - val_accuracy: 0.8903
# Epoch 73/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0552 - accuracy: 0.9774 - val_loss: 0.7122 - val_accuracy: 0.8987
# Epoch 74/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0937 - accuracy: 0.9674 - val_loss: 0.6954 - val_accuracy: 0.9008
# Epoch 75/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0513 - accuracy: 0.9819 - val_loss: 0.7193 - val_accuracy: 0.9030
# Epoch 76/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0461 - accuracy: 0.9792 - val_loss: 0.8235 - val_accuracy: 0.8861
# Epoch 77/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0632 - accuracy: 0.9719 - val_loss: 0.8631 - val_accuracy: 0.8945
# Epoch 78/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0629 - accuracy: 0.9692 - val_loss: 0.6027 - val_accuracy: 0.8987
# Epoch 79/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0714 - accuracy: 0.9719 - val_loss: 0.7155 - val_accuracy: 0.8776
# Epoch 80/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0442 - accuracy: 0.9764 - val_loss: 0.8133 - val_accuracy: 0.8987
# Epoch 81/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0261 - accuracy: 0.9864 - val_loss: 0.7990 - val_accuracy: 0.8987
# Epoch 82/200
# 35/35 [==============================] - 5s 133ms/step - loss: 0.0360 - accuracy: 0.9846 - val_loss: 0.7270 - val_accuracy: 0.8987
# Epoch 83/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0477 - accuracy: 0.9801 - val_loss: 0.7643 - val_accuracy: 0.8945
# Epoch 84/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0367 - accuracy: 0.9783 - val_loss: 0.7970 - val_accuracy: 0.9030
# Epoch 85/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0559 - accuracy: 0.9810 - val_loss: 0.7942 - val_accuracy: 0.9093
# Epoch 86/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0576 - accuracy: 0.9801 - val_loss: 1.0012 - val_accuracy: 0.8945
# Epoch 87/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.1233 - accuracy: 0.9737 - val_loss: 0.8387 - val_accuracy: 0.9030
# Epoch 88/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0515 - accuracy: 0.9728 - val_loss: 0.8438 - val_accuracy: 0.9114
# Epoch 89/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0376 - accuracy: 0.9783 - val_loss: 0.9004 - val_accuracy: 0.8945
# Epoch 90/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0518 - accuracy: 0.9783 - val_loss: 0.7236 - val_accuracy: 0.9008
# Epoch 91/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0372 - accuracy: 0.9837 - val_loss: 0.8582 - val_accuracy: 0.9072
# Epoch 92/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0377 - accuracy: 0.9774 - val_loss: 0.7971 - val_accuracy: 0.9114
# Epoch 93/200
# 35/35 [==============================] - 5s 137ms/step - loss: 0.0399 - accuracy: 0.9846 - val_loss: 0.8229 - val_accuracy: 0.9030
# Epoch 94/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0302 - accuracy: 0.9855 - val_loss: 0.8807 - val_accuracy: 0.8966
# Epoch 95/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0511 - accuracy: 0.9783 - val_loss: 0.8283 - val_accuracy: 0.9030
# Epoch 96/200
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0307 - accuracy: 0.9873 - val_loss: 0.9176 - val_accuracy: 0.8987
# Epoch 97/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0455 - accuracy: 0.9774 - val_loss: 0.9523 - val_accuracy: 0.9072
# Epoch 98/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0488 - accuracy: 0.9764 - val_loss: 0.8780 - val_accuracy: 0.9030
# Epoch 99/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0410 - accuracy: 0.9783 - val_loss: 0.9902 - val_accuracy: 0.8945
# Epoch 100/200
# 35/35 [==============================] - 5s 133ms/step - loss: 0.0779 - accuracy: 0.9746 - val_loss: 0.9197 - val_accuracy: 0.8966
# Epoch 101/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0477 - accuracy: 0.9728 - val_loss: 0.9453 - val_accuracy: 0.8966
# Epoch 102/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0432 - accuracy: 0.9819 - val_loss: 1.0912 - val_accuracy: 0.8945
# Epoch 103/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0496 - accuracy: 0.9746 - val_loss: 0.7772 - val_accuracy: 0.9008
# Epoch 104/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0546 - accuracy: 0.9774 - val_loss: 0.7133 - val_accuracy: 0.9051
# Epoch 105/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0304 - accuracy: 0.9891 - val_loss: 0.7584 - val_accuracy: 0.9072
# Epoch 106/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0318 - accuracy: 0.9846 - val_loss: 0.8958 - val_accuracy: 0.9030
# Epoch 107/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0387 - accuracy: 0.9819 - val_loss: 1.0067 - val_accuracy: 0.8924
# Epoch 108/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0548 - accuracy: 0.9764 - val_loss: 0.9258 - val_accuracy: 0.9008
# Epoch 109/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0482 - accuracy: 0.9792 - val_loss: 0.9396 - val_accuracy: 0.9030
# Epoch 110/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0295 - accuracy: 0.9837 - val_loss: 1.0575 - val_accuracy: 0.8903
# Epoch 111/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0598 - accuracy: 0.9774 - val_loss: 0.8318 - val_accuracy: 0.8987
# Epoch 112/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0452 - accuracy: 0.9783 - val_loss: 0.7772 - val_accuracy: 0.9072
# Epoch 113/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0368 - accuracy: 0.9792 - val_loss: 0.9124 - val_accuracy: 0.8945
# Epoch 114/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0508 - accuracy: 0.9728 - val_loss: 0.8021 - val_accuracy: 0.8966
# Epoch 115/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0445 - accuracy: 0.9792 - val_loss: 0.8118 - val_accuracy: 0.9030
# Epoch 116/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0290 - accuracy: 0.9873 - val_loss: 0.8251 - val_accuracy: 0.9030
# Epoch 117/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.0273 - accuracy: 0.9909 - val_loss: 0.9633 - val_accuracy: 0.9030
# Epoch 118/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0352 - accuracy: 0.9810 - val_loss: 0.9720 - val_accuracy: 0.8945
# Epoch 119/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0378 - accuracy: 0.9864 - val_loss: 0.9720 - val_accuracy: 0.9030
# Epoch 120/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0428 - accuracy: 0.9864 - val_loss: 1.1487 - val_accuracy: 0.8819
# Epoch 121/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0262 - accuracy: 0.9855 - val_loss: 0.9197 - val_accuracy: 0.9030
# Epoch 122/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0334 - accuracy: 0.9846 - val_loss: 0.9105 - val_accuracy: 0.8966
# Epoch 123/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0535 - accuracy: 0.9774 - val_loss: 1.1746 - val_accuracy: 0.9051
# Epoch 124/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0611 - accuracy: 0.9801 - val_loss: 0.9166 - val_accuracy: 0.9114
# Epoch 125/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0672 - accuracy: 0.9746 - val_loss: 0.9322 - val_accuracy: 0.9135
# Epoch 126/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0689 - accuracy: 0.9719 - val_loss: 0.7604 - val_accuracy: 0.9030
# Epoch 127/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0632 - accuracy: 0.9692 - val_loss: 0.8716 - val_accuracy: 0.8903
# Epoch 128/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0502 - accuracy: 0.9764 - val_loss: 1.0142 - val_accuracy: 0.8966
# Epoch 129/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0714 - accuracy: 0.9837 - val_loss: 0.9541 - val_accuracy: 0.9030
# Epoch 130/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0972 - accuracy: 0.9692 - val_loss: 0.9681 - val_accuracy: 0.8945
# Epoch 131/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0729 - accuracy: 0.9692 - val_loss: 1.0241 - val_accuracy: 0.8882
# Epoch 132/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0900 - accuracy: 0.9719 - val_loss: 0.8326 - val_accuracy: 0.9030
# Epoch 133/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0908 - accuracy: 0.9774 - val_loss: 0.8631 - val_accuracy: 0.9072
# Epoch 134/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0541 - accuracy: 0.9755 - val_loss: 0.8768 - val_accuracy: 0.9008
# Epoch 135/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0636 - accuracy: 0.9819 - val_loss: 0.7912 - val_accuracy: 0.8945
# Epoch 136/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0614 - accuracy: 0.9728 - val_loss: 0.8828 - val_accuracy: 0.9030
# Epoch 137/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0599 - accuracy: 0.9755 - val_loss: 0.8915 - val_accuracy: 0.8924
# Epoch 138/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0454 - accuracy: 0.9855 - val_loss: 0.8310 - val_accuracy: 0.9030
# Epoch 139/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0447 - accuracy: 0.9819 - val_loss: 0.8871 - val_accuracy: 0.9030
# Epoch 140/200
# 35/35 [==============================] - 5s 137ms/step - loss: 0.0398 - accuracy: 0.9828 - val_loss: 0.8418 - val_accuracy: 0.8987
# Epoch 141/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0531 - accuracy: 0.9801 - val_loss: 0.7773 - val_accuracy: 0.9093
# Epoch 142/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0429 - accuracy: 0.9792 - val_loss: 0.7686 - val_accuracy: 0.9030
# Epoch 143/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0387 - accuracy: 0.9801 - val_loss: 0.9456 - val_accuracy: 0.9051
# Epoch 144/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0503 - accuracy: 0.9783 - val_loss: 0.6642 - val_accuracy: 0.8945
# Epoch 145/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0291 - accuracy: 0.9864 - val_loss: 0.8404 - val_accuracy: 0.9008
# Epoch 146/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0608 - accuracy: 0.9746 - val_loss: 0.7748 - val_accuracy: 0.9030
# Epoch 147/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0562 - accuracy: 0.9755 - val_loss: 0.8011 - val_accuracy: 0.8924
# Epoch 148/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0490 - accuracy: 0.9764 - val_loss: 0.8034 - val_accuracy: 0.8945
# Epoch 149/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0348 - accuracy: 0.9801 - val_loss: 0.8338 - val_accuracy: 0.8966
# Epoch 150/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0450 - accuracy: 0.9792 - val_loss: 0.9666 - val_accuracy: 0.8882
# Epoch 151/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0470 - accuracy: 0.9792 - val_loss: 1.0589 - val_accuracy: 0.9030
# Epoch 152/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0552 - accuracy: 0.9755 - val_loss: 0.8646 - val_accuracy: 0.8966
# Epoch 153/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0444 - accuracy: 0.9755 - val_loss: 1.0106 - val_accuracy: 0.8924
# Epoch 154/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0498 - accuracy: 0.9774 - val_loss: 0.8186 - val_accuracy: 0.8987
# Epoch 155/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0392 - accuracy: 0.9828 - val_loss: 0.8571 - val_accuracy: 0.9114
# Epoch 156/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0234 - accuracy: 0.9909 - val_loss: 0.9051 - val_accuracy: 0.9008
# Epoch 157/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0319 - accuracy: 0.9810 - val_loss: 0.9601 - val_accuracy: 0.9030
# Epoch 158/200
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0394 - accuracy: 0.9810 - val_loss: 0.9901 - val_accuracy: 0.8987
# Epoch 159/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0312 - accuracy: 0.9855 - val_loss: 1.0806 - val_accuracy: 0.9008
# Epoch 160/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0321 - accuracy: 0.9855 - val_loss: 0.9103 - val_accuracy: 0.9008
# Epoch 161/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0416 - accuracy: 0.9801 - val_loss: 1.1574 - val_accuracy: 0.8987
# Epoch 162/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0402 - accuracy: 0.9873 - val_loss: 1.1297 - val_accuracy: 0.9072
# Epoch 163/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0323 - accuracy: 0.9846 - val_loss: 1.0288 - val_accuracy: 0.9030
# Epoch 164/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0374 - accuracy: 0.9846 - val_loss: 0.9793 - val_accuracy: 0.9030
# Epoch 165/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0451 - accuracy: 0.9837 - val_loss: 1.0624 - val_accuracy: 0.9030
# Epoch 166/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0404 - accuracy: 0.9837 - val_loss: 1.0744 - val_accuracy: 0.9135
# Epoch 167/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.0477 - accuracy: 0.9783 - val_loss: 1.1321 - val_accuracy: 0.9030
# Epoch 168/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0474 - accuracy: 0.9819 - val_loss: 0.9583 - val_accuracy: 0.9051
# Epoch 169/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0452 - accuracy: 0.9764 - val_loss: 1.1182 - val_accuracy: 0.9030
# Epoch 170/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0492 - accuracy: 0.9792 - val_loss: 1.0452 - val_accuracy: 0.8924
# Epoch 171/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0557 - accuracy: 0.9764 - val_loss: 0.9863 - val_accuracy: 0.8903
# Epoch 172/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0380 - accuracy: 0.9837 - val_loss: 1.4478 - val_accuracy: 0.9008
# Epoch 173/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0567 - accuracy: 0.9728 - val_loss: 1.3770 - val_accuracy: 0.9030
# Epoch 174/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0583 - accuracy: 0.9864 - val_loss: 1.3625 - val_accuracy: 0.8945
# Epoch 175/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0539 - accuracy: 0.9728 - val_loss: 1.1183 - val_accuracy: 0.8987
# Epoch 176/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0307 - accuracy: 0.9810 - val_loss: 1.1191 - val_accuracy: 0.8924
# Epoch 177/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0387 - accuracy: 0.9855 - val_loss: 1.3847 - val_accuracy: 0.8987
# Epoch 178/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0348 - accuracy: 0.9819 - val_loss: 1.4557 - val_accuracy: 0.9051
# Epoch 179/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0450 - accuracy: 0.9774 - val_loss: 1.3339 - val_accuracy: 0.8945
# Epoch 180/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0535 - accuracy: 0.9801 - val_loss: 1.1957 - val_accuracy: 0.9008
# Epoch 181/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0647 - accuracy: 0.9801 - val_loss: 1.0865 - val_accuracy: 0.9051
# Epoch 182/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0688 - accuracy: 0.9810 - val_loss: 0.9482 - val_accuracy: 0.8903
# Epoch 183/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0405 - accuracy: 0.9801 - val_loss: 1.0597 - val_accuracy: 0.9008
# Epoch 184/200
# 35/35 [==============================] - 5s 137ms/step - loss: 0.0692 - accuracy: 0.9710 - val_loss: 0.7853 - val_accuracy: 0.8987
# Epoch 185/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.0529 - accuracy: 0.9710 - val_loss: 0.9962 - val_accuracy: 0.9051
# Epoch 186/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0534 - accuracy: 0.9737 - val_loss: 0.8720 - val_accuracy: 0.9008
# Epoch 187/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0348 - accuracy: 0.9810 - val_loss: 0.9725 - val_accuracy: 0.9008
# Epoch 188/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0455 - accuracy: 0.9764 - val_loss: 0.9650 - val_accuracy: 0.9051
# Epoch 189/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0400 - accuracy: 0.9855 - val_loss: 1.0062 - val_accuracy: 0.9008
# Epoch 190/200
# 35/35 [==============================] - 5s 153ms/step - loss: 0.0431 - accuracy: 0.9828 - val_loss: 1.0412 - val_accuracy: 0.8924
# Epoch 191/200
# 35/35 [==============================] - 5s 135ms/step - loss: 0.0462 - accuracy: 0.9737 - val_loss: 0.8876 - val_accuracy: 0.9072
# Epoch 192/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0425 - accuracy: 0.9774 - val_loss: 1.0258 - val_accuracy: 0.8987
# Epoch 193/200
# 35/35 [==============================] - 5s 136ms/step - loss: 0.0632 - accuracy: 0.9737 - val_loss: 0.9622 - val_accuracy: 0.8903
# Epoch 194/200
# 35/35 [==============================] - 5s 152ms/step - loss: 0.0394 - accuracy: 0.9728 - val_loss: 0.8403 - val_accuracy: 0.8987
# Epoch 195/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0418 - accuracy: 0.9828 - val_loss: 0.8987 - val_accuracy: 0.8924
# Epoch 196/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0463 - accuracy: 0.9792 - val_loss: 0.9989 - val_accuracy: 0.8945
# Epoch 197/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0420 - accuracy: 0.9774 - val_loss: 0.9334 - val_accuracy: 0.8966
# Epoch 198/200
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0463 - accuracy: 0.9783 - val_loss: 0.8561 - val_accuracy: 0.9030
# Epoch 199/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0433 - accuracy: 0.9783 - val_loss: 0.9921 - val_accuracy: 0.9030
# Epoch 200/200
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0926 - accuracy: 0.9819 - val_loss: 0.9163 - val_accuracy: 0.8966
# 15/15 [==============================] - 1s 50ms/step - loss: 0.9163 - accuracy: 0.8966
# Test Accuracy: 89.66%

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 3)       30
#
#  resnet50v2 (Functional)     (None, 5, 5, 2048)        23564800
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 128)               6553728
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 30118945 (114.89 MB)
# Trainable params: 6554145 (25.00 MB)
# Non-trainable params: 23564800 (89.89 MB)
# _________________________________________________________________

# %%
num_images_to_display = 10
selected_indices = np.random.choice(len(X_test), num_images_to_display, replace=False)
class_names = ['Benign', 'Malignant', 'Normal']
# Create a subplot grid
num_rows = 2
num_cols = num_images_to_display // num_rows
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display predictions for the selected test images
for i, index in enumerate(selected_indices):
    # Get the test image and true label
    test_image = X_test[index]
    true_label = np.argmax(y_test[index])

    # Preprocess the image
    img_array = np.expand_dims(test_image, axis=0)

    # Make predictions
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)

    # Display the image
    ax = axes[i]
    ax.imshow(test_image.reshape((150, 150)), cmap='gray')
    ax.set_title(f'True: {class_names[true_label]}, Predicted: {class_names[predicted_class]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
plt.savefig('/content/drive/MyDrive/Dataset BUSI with GT/prediction.png')
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model


# Save the trained model
model.save('/content/drive/MyDrive/Dataset BUSI with GT/modelResnet50v2.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
loaded_model = load_model('/content/drive/MyDrive/Dataset BUSI with GT/modelResnet50v2.h5')

# Evaluate the model on the test set
y_pred = loaded_model.predict(X_test)

# Convert one-hot encoded labels back to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Plot confusion matrix with seaborn
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant', 'Normal'], yticklabels=['Benign', 'Malignant', 'Normal'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot classification report
class_report = classification_report(y_true_classes, y_pred_classes, target_names=['Benign', 'Malignant', 'Normal'])
print('Classification Report:\n', class_report)
# Out:
# 15/15 [==============================] - 2s 49ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.91      0.94      0.92       268
#    Malignant       0.87      0.85      0.86       126
#       Normal       0.91      0.84      0.87        80
#
#     accuracy                           0.90       474
#    macro avg       0.89      0.87      0.88       474
# weighted avg       0.90      0.90      0.90       474

# %%
# Visualize input-to-output
for i in range(5):  # You can adjust the range based on the number of samples you want to visualize
    input_image = X_test[i].reshape((150, 150))  # Assuming your input shape is (150, 150, 1)
    output_probabilities = y_pred[i]
    predicted_class = np.argmax(output_probabilities)

    plt.figure(figsize=(8, 4))

    # Plot input image
    plt.subplot(1, 2, 1)
    plt.imshow(input_image, cmap='gray')
    plt.title('Input Image')

    # Plot output probabilities
    plt.subplot(1, 2, 2)
    plt.bar(range(len(output_probabilities)), output_probabilities)
    plt.xticks(range(len(output_probabilities)), ['Benign', 'Malignant', 'Normal'])
    plt.title('Output Probabilities')

    plt.show()
