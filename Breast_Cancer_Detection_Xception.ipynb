# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import Xception, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
import os

# Define the path to the dataset directory
dataset_path = "/content/drive/MyDrive/Dataset BUSI with GT"

# Get the list of image files
image_files = []
labels = []

# Iterate over the directories
for class_name in ['benign', 'malignant', 'normal']:
    class_path = os.path.join(dataset_path, class_name)
    for filename in os.listdir(class_path):
        image_path = os.path.join(class_path, filename)
        image_files.append(image_path)
        labels.append(class_name)

# Convert labels to numerical values
from tensorflow.keras.utils import to_categorical

# Convert labels to numerical values
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
# Get the original class labels from the label encoder
original_labels = label_encoder.classes_

# Convert labels to one-hot encoded format
labels = to_categorical(labels)


# Print the mapping between numerical values and original labels
for numerical_value, original_label in enumerate(original_labels):
    print(f"Numerical Value: {numerical_value}, Original Label: {original_label}")
# Out:
# Numerical Value: 0, Original Label: benign
# Numerical Value: 1, Original Label: malignant
# Numerical Value: 2, Original Label: normal

# %% [markdown]
# ### **CNN**

# %%
X_train, X_test, y_train, y_test = train_test_split(image_files, labels, test_size=0.3, random_state=42, stratify=labels)

# %%
# Define a function to load and preprocess the images
def load_preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((150, 150))
#this converts the image to BW
    image = image.convert('L')
    image = np.array(image)
    image = image.reshape((150, 150, 1))
#image normalization
    image = image.astype('float32') / 255.0
    return image

X_train = [str(image_path) for image_path in X_train]
X_test = [str(image_path) for image_path in X_test]

# Load and preprocess the training images and labels
X_train = [load_preprocess_image(image_path) for image_path in X_train]
X_train = np.array(X_train)
y_train= np.array(y_train)

# Load and preprocess the testing images and labels
X_test= [load_preprocess_image(image_path) for image_path in X_test]
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
#Check size and color channels of images and labels
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)

#Show images
images = X_test[:10]  # Assuming X_test contains the image data
labels = y_test[:10]  # Assuming y_test contains the corresponding labels

# Convert them to class indices
class_indices = np.argmax(labels, axis=1)

# Define class labels
class_labels = ['Benign', 'Malignant', 'Normal']

num_rows = 2
num_cols = len(images) // num_rows

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display images with labels in the subplots
for i in range(len(images)):
    ax = axes[i]
    ax.imshow(images[i], cmap='gray')  # Assuming images are 2D arrays (grayscale)
    ax.set_title(f'True Label: {class_labels[class_indices[i]]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# (1104, 150, 150, 1) (1104, 3)
# (474, 150, 150, 1) (474, 3)

# %%
# Load Xception model without the top (fully connected) layers
base_model = Xception(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
# Create a Sequential model
model = Sequential()

# Add a custom convolutional layer to handle grayscale input
model.add(Conv2D(3, (3, 3), activation='relu', input_shape=(150, 150, 1), padding='same'))  # Adjust input_shape to (150, 150, 1)

# Add the Xception base (excluding top layers)
model.add(base_model)

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top of Xception
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes (benign, malignant, normal)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 3s 0us/step

# %%
# Train the model and collect the history
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))


# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 35/35 [==============================] - 26s 400ms/step - loss: 1.3824 - accuracy: 0.6848 - val_loss: 0.5193 - val_accuracy: 0.8333
# Epoch 2/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.5670 - accuracy: 0.7726 - val_loss: 0.4313 - val_accuracy: 0.8291
# Epoch 3/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.4467 - accuracy: 0.8252 - val_loss: 0.3865 - val_accuracy: 0.8481
# Epoch 4/200
# 35/35 [==============================] - 6s 183ms/step - loss: 0.3631 - accuracy: 0.8397 - val_loss: 0.3744 - val_accuracy: 0.8586
# Epoch 5/200
# 35/35 [==============================] - 6s 184ms/step - loss: 0.3626 - accuracy: 0.8370 - val_loss: 0.3645 - val_accuracy: 0.8692
# Epoch 6/200
# 35/35 [==============================] - 6s 184ms/step - loss: 0.3036 - accuracy: 0.8759 - val_loss: 0.3499 - val_accuracy: 0.8650
# Epoch 7/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.3003 - accuracy: 0.8777 - val_loss: 0.3394 - val_accuracy: 0.8882
# Epoch 8/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.2706 - accuracy: 0.8877 - val_loss: 0.3236 - val_accuracy: 0.8819
# Epoch 9/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.2627 - accuracy: 0.8886 - val_loss: 0.3285 - val_accuracy: 0.8882
# Epoch 10/200
# 35/35 [==============================] - 7s 189ms/step - loss: 0.2267 - accuracy: 0.9112 - val_loss: 0.3367 - val_accuracy: 0.8692
# Epoch 11/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.2119 - accuracy: 0.9158 - val_loss: 0.3278 - val_accuracy: 0.8819
# Epoch 12/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.2112 - accuracy: 0.9176 - val_loss: 0.3180 - val_accuracy: 0.8924
# Epoch 13/200
# 35/35 [==============================] - 7s 190ms/step - loss: 0.1885 - accuracy: 0.9230 - val_loss: 0.3271 - val_accuracy: 0.8903
# Epoch 14/200
# 35/35 [==============================] - 7s 193ms/step - loss: 0.1888 - accuracy: 0.9284 - val_loss: 0.3413 - val_accuracy: 0.8903
# Epoch 15/200
# 35/35 [==============================] - 6s 181ms/step - loss: 0.1702 - accuracy: 0.9402 - val_loss: 0.3392 - val_accuracy: 0.8882
# Epoch 16/200
# 35/35 [==============================] - 7s 195ms/step - loss: 0.1497 - accuracy: 0.9420 - val_loss: 0.3505 - val_accuracy: 0.8987
# Epoch 17/200
# 35/35 [==============================] - 7s 195ms/step - loss: 0.1444 - accuracy: 0.9402 - val_loss: 0.3129 - val_accuracy: 0.8840
# Epoch 18/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.1281 - accuracy: 0.9502 - val_loss: 0.3736 - val_accuracy: 0.8924
# Epoch 19/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.1327 - accuracy: 0.9457 - val_loss: 0.3835 - val_accuracy: 0.8903
# Epoch 20/200
# 35/35 [==============================] - 7s 199ms/step - loss: 0.1173 - accuracy: 0.9511 - val_loss: 0.3307 - val_accuracy: 0.8861
# Epoch 21/200
# 35/35 [==============================] - 7s 188ms/step - loss: 0.1648 - accuracy: 0.9411 - val_loss: 0.3773 - val_accuracy: 0.8924
# Epoch 22/200
# 35/35 [==============================] - 7s 188ms/step - loss: 0.1460 - accuracy: 0.9402 - val_loss: 0.5166 - val_accuracy: 0.8692
# Epoch 23/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.1338 - accuracy: 0.9565 - val_loss: 0.3645 - val_accuracy: 0.8903
# Epoch 24/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.1103 - accuracy: 0.9466 - val_loss: 0.3126 - val_accuracy: 0.9051
# Epoch 25/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.1049 - accuracy: 0.9574 - val_loss: 0.3863 - val_accuracy: 0.8776
# Epoch 26/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.1571 - accuracy: 0.9393 - val_loss: 0.3763 - val_accuracy: 0.8945
# Epoch 27/200
# 35/35 [==============================] - 6s 183ms/step - loss: 0.1255 - accuracy: 0.9466 - val_loss: 0.3648 - val_accuracy: 0.8966
# Epoch 28/200
# 35/35 [==============================] - 6s 184ms/step - loss: 0.1006 - accuracy: 0.9620 - val_loss: 0.3817 - val_accuracy: 0.8966
# Epoch 29/200
# 35/35 [==============================] - 7s 195ms/step - loss: 0.1146 - accuracy: 0.9592 - val_loss: 0.3565 - val_accuracy: 0.8966
# Epoch 30/200
# 35/35 [==============================] - 7s 195ms/step - loss: 0.0885 - accuracy: 0.9683 - val_loss: 0.3716 - val_accuracy: 0.8861
# Epoch 31/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.1029 - accuracy: 0.9538 - val_loss: 0.3930 - val_accuracy: 0.8882
# Epoch 32/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0756 - accuracy: 0.9728 - val_loss: 0.4360 - val_accuracy: 0.8882
# Epoch 33/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.1119 - accuracy: 0.9583 - val_loss: 0.3784 - val_accuracy: 0.8734
# Epoch 34/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0861 - accuracy: 0.9701 - val_loss: 0.4907 - val_accuracy: 0.8903
# Epoch 35/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0857 - accuracy: 0.9683 - val_loss: 0.3770 - val_accuracy: 0.8819
# Epoch 36/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.1076 - accuracy: 0.9565 - val_loss: 0.3917 - val_accuracy: 0.8819
# Epoch 37/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.1091 - accuracy: 0.9601 - val_loss: 0.3765 - val_accuracy: 0.8861
# Epoch 38/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0969 - accuracy: 0.9638 - val_loss: 0.4166 - val_accuracy: 0.8692
# Epoch 39/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0815 - accuracy: 0.9701 - val_loss: 0.3780 - val_accuracy: 0.8903
# Epoch 40/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0834 - accuracy: 0.9737 - val_loss: 0.4937 - val_accuracy: 0.8819
# Epoch 41/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0785 - accuracy: 0.9656 - val_loss: 0.4116 - val_accuracy: 0.8840
# Epoch 42/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0752 - accuracy: 0.9674 - val_loss: 0.4861 - val_accuracy: 0.8734
# Epoch 43/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0815 - accuracy: 0.9629 - val_loss: 0.4434 - val_accuracy: 0.8776
# Epoch 44/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0759 - accuracy: 0.9737 - val_loss: 0.4088 - val_accuracy: 0.8840
# Epoch 45/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0659 - accuracy: 0.9737 - val_loss: 0.4125 - val_accuracy: 0.8903
# Epoch 46/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0792 - accuracy: 0.9656 - val_loss: 0.4091 - val_accuracy: 0.8882
# Epoch 47/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0625 - accuracy: 0.9719 - val_loss: 0.4356 - val_accuracy: 0.8882
# Epoch 48/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0604 - accuracy: 0.9746 - val_loss: 0.4429 - val_accuracy: 0.9008
# Epoch 49/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0811 - accuracy: 0.9656 - val_loss: 0.4086 - val_accuracy: 0.8861
# Epoch 50/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0687 - accuracy: 0.9665 - val_loss: 0.4897 - val_accuracy: 0.8924
# Epoch 51/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0575 - accuracy: 0.9728 - val_loss: 0.6670 - val_accuracy: 0.8945
# Epoch 52/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0665 - accuracy: 0.9710 - val_loss: 0.5551 - val_accuracy: 0.8924
# Epoch 53/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0731 - accuracy: 0.9710 - val_loss: 0.4206 - val_accuracy: 0.8966
# Epoch 54/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0696 - accuracy: 0.9764 - val_loss: 0.8516 - val_accuracy: 0.8629
# Epoch 55/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.2271 - accuracy: 0.9393 - val_loss: 0.5443 - val_accuracy: 0.8692
# Epoch 56/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.1359 - accuracy: 0.9583 - val_loss: 0.4899 - val_accuracy: 0.8776
# Epoch 57/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0978 - accuracy: 0.9638 - val_loss: 0.4989 - val_accuracy: 0.8840
# Epoch 58/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.1546 - accuracy: 0.9601 - val_loss: 0.6897 - val_accuracy: 0.8713
# Epoch 59/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0862 - accuracy: 0.9665 - val_loss: 0.6218 - val_accuracy: 0.8882
# Epoch 60/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0887 - accuracy: 0.9601 - val_loss: 0.4631 - val_accuracy: 0.8776
# Epoch 61/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0871 - accuracy: 0.9592 - val_loss: 0.4081 - val_accuracy: 0.8776
# Epoch 62/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0859 - accuracy: 0.9683 - val_loss: 0.4548 - val_accuracy: 0.8755
# Epoch 63/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0763 - accuracy: 0.9674 - val_loss: 0.4948 - val_accuracy: 0.8966
# Epoch 64/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0722 - accuracy: 0.9674 - val_loss: 0.4660 - val_accuracy: 0.8840
# Epoch 65/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0603 - accuracy: 0.9701 - val_loss: 0.4524 - val_accuracy: 0.8840
# Epoch 66/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0622 - accuracy: 0.9701 - val_loss: 0.5139 - val_accuracy: 0.8819
# Epoch 67/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0768 - accuracy: 0.9683 - val_loss: 0.5112 - val_accuracy: 0.8945
# Epoch 68/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0912 - accuracy: 0.9638 - val_loss: 0.4616 - val_accuracy: 0.8945
# Epoch 69/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0673 - accuracy: 0.9728 - val_loss: 0.6120 - val_accuracy: 0.9008
# Epoch 70/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0560 - accuracy: 0.9764 - val_loss: 0.5461 - val_accuracy: 0.8924
# Epoch 71/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0692 - accuracy: 0.9656 - val_loss: 0.5495 - val_accuracy: 0.8924
# Epoch 72/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0711 - accuracy: 0.9692 - val_loss: 0.6268 - val_accuracy: 0.8734
# Epoch 73/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0614 - accuracy: 0.9746 - val_loss: 0.5539 - val_accuracy: 0.8861
# Epoch 74/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0594 - accuracy: 0.9683 - val_loss: 0.5451 - val_accuracy: 0.8861
# Epoch 75/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0485 - accuracy: 0.9783 - val_loss: 0.6002 - val_accuracy: 0.8903
# Epoch 76/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0495 - accuracy: 0.9801 - val_loss: 0.5148 - val_accuracy: 0.8755
# Epoch 77/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0641 - accuracy: 0.9737 - val_loss: 0.5705 - val_accuracy: 0.8755
# Epoch 78/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0801 - accuracy: 0.9683 - val_loss: 0.5185 - val_accuracy: 0.8819
# Epoch 79/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0571 - accuracy: 0.9755 - val_loss: 0.4953 - val_accuracy: 0.8819
# Epoch 80/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0512 - accuracy: 0.9755 - val_loss: 0.5402 - val_accuracy: 0.8861
# Epoch 81/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0541 - accuracy: 0.9746 - val_loss: 0.6074 - val_accuracy: 0.8924
# Epoch 82/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0538 - accuracy: 0.9746 - val_loss: 0.5668 - val_accuracy: 0.8861
# Epoch 83/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0653 - accuracy: 0.9746 - val_loss: 0.7465 - val_accuracy: 0.8882
# Epoch 84/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0907 - accuracy: 0.9647 - val_loss: 0.6615 - val_accuracy: 0.8819
# Epoch 85/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0558 - accuracy: 0.9737 - val_loss: 0.6408 - val_accuracy: 0.8882
# Epoch 86/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0606 - accuracy: 0.9701 - val_loss: 0.5529 - val_accuracy: 0.8945
# Epoch 87/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0821 - accuracy: 0.9746 - val_loss: 0.6734 - val_accuracy: 0.8882
# Epoch 88/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0779 - accuracy: 0.9638 - val_loss: 0.6757 - val_accuracy: 0.8882
# Epoch 89/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0568 - accuracy: 0.9710 - val_loss: 0.5721 - val_accuracy: 0.8840
# Epoch 90/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0678 - accuracy: 0.9737 - val_loss: 0.5293 - val_accuracy: 0.8903
# Epoch 91/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0645 - accuracy: 0.9683 - val_loss: 0.5678 - val_accuracy: 0.8861
# Epoch 92/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0508 - accuracy: 0.9764 - val_loss: 0.6904 - val_accuracy: 0.8882
# Epoch 93/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0773 - accuracy: 0.9665 - val_loss: 0.5743 - val_accuracy: 0.8945
# Epoch 94/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0668 - accuracy: 0.9701 - val_loss: 0.5612 - val_accuracy: 0.8966
# Epoch 95/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0617 - accuracy: 0.9746 - val_loss: 0.5827 - val_accuracy: 0.8819
# Epoch 96/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0436 - accuracy: 0.9792 - val_loss: 0.5701 - val_accuracy: 0.8882
# Epoch 97/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0554 - accuracy: 0.9764 - val_loss: 0.6719 - val_accuracy: 0.8903
# Epoch 98/200
# 35/35 [==============================] - 6s 187ms/step - loss: 0.0503 - accuracy: 0.9764 - val_loss: 0.7329 - val_accuracy: 0.8819
# Epoch 99/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0623 - accuracy: 0.9701 - val_loss: 0.5297 - val_accuracy: 0.8861
# Epoch 100/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0456 - accuracy: 0.9755 - val_loss: 0.6554 - val_accuracy: 0.8903
# Epoch 101/200
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0598 - accuracy: 0.9755 - val_loss: 0.5524 - val_accuracy: 0.8840
# Epoch 102/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0482 - accuracy: 0.9774 - val_loss: 0.6654 - val_accuracy: 0.8924
# Epoch 103/200
# 35/35 [==============================] - 7s 195ms/step - loss: 0.0511 - accuracy: 0.9810 - val_loss: 0.6592 - val_accuracy: 0.8903
# Epoch 104/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0498 - accuracy: 0.9755 - val_loss: 0.6336 - val_accuracy: 0.8840
# Epoch 105/200
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0446 - accuracy: 0.9819 - val_loss: 0.5730 - val_accuracy: 0.8924
# Epoch 106/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0392 - accuracy: 0.9801 - val_loss: 0.6642 - val_accuracy: 0.8882
# Epoch 107/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0432 - accuracy: 0.9774 - val_loss: 0.6147 - val_accuracy: 0.8840
# Epoch 108/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0371 - accuracy: 0.9864 - val_loss: 0.6698 - val_accuracy: 0.8861
# Epoch 109/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0226 - accuracy: 0.9918 - val_loss: 0.7463 - val_accuracy: 0.8903
# Epoch 110/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0355 - accuracy: 0.9846 - val_loss: 0.6962 - val_accuracy: 0.8840
# Epoch 111/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0286 - accuracy: 0.9873 - val_loss: 0.6162 - val_accuracy: 0.8840
# Epoch 112/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0576 - accuracy: 0.9737 - val_loss: 0.6619 - val_accuracy: 0.8734
# Epoch 113/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0456 - accuracy: 0.9810 - val_loss: 0.6313 - val_accuracy: 0.8903
# Epoch 114/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0341 - accuracy: 0.9837 - val_loss: 0.6225 - val_accuracy: 0.8776
# Epoch 115/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0378 - accuracy: 0.9801 - val_loss: 0.6273 - val_accuracy: 0.8903
# Epoch 116/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0372 - accuracy: 0.9819 - val_loss: 0.6466 - val_accuracy: 0.8840
# Epoch 117/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0483 - accuracy: 0.9774 - val_loss: 0.7477 - val_accuracy: 0.8924
# Epoch 118/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0363 - accuracy: 0.9819 - val_loss: 0.6445 - val_accuracy: 0.8861
# Epoch 119/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0393 - accuracy: 0.9792 - val_loss: 0.6121 - val_accuracy: 0.8882
# Epoch 120/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0376 - accuracy: 0.9819 - val_loss: 0.6252 - val_accuracy: 0.8945
# Epoch 121/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0589 - accuracy: 0.9764 - val_loss: 0.6159 - val_accuracy: 0.8903
# Epoch 122/200
# 35/35 [==============================] - 7s 199ms/step - loss: 0.0363 - accuracy: 0.9810 - val_loss: 0.6077 - val_accuracy: 0.8861
# Epoch 123/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0340 - accuracy: 0.9837 - val_loss: 0.6762 - val_accuracy: 0.8924
# Epoch 124/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0377 - accuracy: 0.9810 - val_loss: 0.6221 - val_accuracy: 0.8903
# Epoch 125/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0385 - accuracy: 0.9819 - val_loss: 0.6065 - val_accuracy: 0.8924
# Epoch 126/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0330 - accuracy: 0.9873 - val_loss: 0.6177 - val_accuracy: 0.8903
# Epoch 127/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0535 - accuracy: 0.9792 - val_loss: 0.6529 - val_accuracy: 0.8734
# Epoch 128/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0707 - accuracy: 0.9620 - val_loss: 0.5707 - val_accuracy: 0.8945
# Epoch 129/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0420 - accuracy: 0.9801 - val_loss: 0.6465 - val_accuracy: 0.8924
# Epoch 130/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0483 - accuracy: 0.9792 - val_loss: 0.7448 - val_accuracy: 0.8966
# Epoch 131/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0569 - accuracy: 0.9728 - val_loss: 0.6990 - val_accuracy: 0.8945
# Epoch 132/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.1100 - accuracy: 0.9638 - val_loss: 0.7203 - val_accuracy: 0.8882
# Epoch 133/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0849 - accuracy: 0.9656 - val_loss: 0.5484 - val_accuracy: 0.8903
# Epoch 134/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0463 - accuracy: 0.9801 - val_loss: 0.5883 - val_accuracy: 0.9008
# Epoch 135/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0572 - accuracy: 0.9746 - val_loss: 0.5603 - val_accuracy: 0.8966
# Epoch 136/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0658 - accuracy: 0.9674 - val_loss: 0.5703 - val_accuracy: 0.8819
# Epoch 137/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0653 - accuracy: 0.9683 - val_loss: 0.6146 - val_accuracy: 0.8903
# Epoch 138/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0679 - accuracy: 0.9755 - val_loss: 0.6885 - val_accuracy: 0.8924
# Epoch 139/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0479 - accuracy: 0.9783 - val_loss: 0.5460 - val_accuracy: 0.8797
# Epoch 140/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0485 - accuracy: 0.9855 - val_loss: 0.6283 - val_accuracy: 0.8734
# Epoch 141/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0592 - accuracy: 0.9737 - val_loss: 0.7066 - val_accuracy: 0.8987
# Epoch 142/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0593 - accuracy: 0.9755 - val_loss: 0.6533 - val_accuracy: 0.8861
# Epoch 143/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.1005 - accuracy: 0.9665 - val_loss: 0.9290 - val_accuracy: 0.8755
# Epoch 144/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0806 - accuracy: 0.9647 - val_loss: 0.5608 - val_accuracy: 0.8840
# Epoch 145/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0447 - accuracy: 0.9846 - val_loss: 0.8048 - val_accuracy: 0.8882
# Epoch 146/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0572 - accuracy: 0.9737 - val_loss: 0.7872 - val_accuracy: 0.8776
# Epoch 147/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0376 - accuracy: 0.9819 - val_loss: 0.6906 - val_accuracy: 0.8924
# Epoch 148/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0431 - accuracy: 0.9783 - val_loss: 0.8517 - val_accuracy: 0.8903
# Epoch 149/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0380 - accuracy: 0.9864 - val_loss: 0.7673 - val_accuracy: 0.8945
# Epoch 150/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0623 - accuracy: 0.9746 - val_loss: 0.6950 - val_accuracy: 0.9008
# Epoch 151/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0719 - accuracy: 0.9692 - val_loss: 0.7000 - val_accuracy: 0.9030
# Epoch 152/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0831 - accuracy: 0.9764 - val_loss: 0.7408 - val_accuracy: 0.8966
# Epoch 153/200
# 35/35 [==============================] - 7s 188ms/step - loss: 0.0781 - accuracy: 0.9764 - val_loss: 0.5801 - val_accuracy: 0.8903
# Epoch 154/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0528 - accuracy: 0.9837 - val_loss: 0.7605 - val_accuracy: 0.8882
# Epoch 155/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0454 - accuracy: 0.9783 - val_loss: 0.7370 - val_accuracy: 0.9008
# Epoch 156/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0370 - accuracy: 0.9882 - val_loss: 0.7530 - val_accuracy: 0.9030
# Epoch 157/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0273 - accuracy: 0.9873 - val_loss: 0.7557 - val_accuracy: 0.8861
# Epoch 158/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0467 - accuracy: 0.9846 - val_loss: 0.7934 - val_accuracy: 0.8924
# Epoch 159/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0489 - accuracy: 0.9810 - val_loss: 0.7100 - val_accuracy: 0.8861
# Epoch 160/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0241 - accuracy: 0.9891 - val_loss: 0.8515 - val_accuracy: 0.8924
# Epoch 161/200
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0392 - accuracy: 0.9864 - val_loss: 0.7386 - val_accuracy: 0.8882
# Epoch 162/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0379 - accuracy: 0.9855 - val_loss: 0.8948 - val_accuracy: 0.8776
# Epoch 163/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0338 - accuracy: 0.9819 - val_loss: 0.8063 - val_accuracy: 0.8776
# Epoch 164/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0351 - accuracy: 0.9837 - val_loss: 0.8709 - val_accuracy: 0.8797
# Epoch 165/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0299 - accuracy: 0.9900 - val_loss: 0.7981 - val_accuracy: 0.8819
# Epoch 166/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0362 - accuracy: 0.9882 - val_loss: 0.9208 - val_accuracy: 0.8776
# Epoch 167/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0458 - accuracy: 0.9864 - val_loss: 0.7264 - val_accuracy: 0.8776
# Epoch 168/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0592 - accuracy: 0.9755 - val_loss: 0.9468 - val_accuracy: 0.8819
# Epoch 169/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0522 - accuracy: 0.9764 - val_loss: 0.7697 - val_accuracy: 0.8776
# Epoch 170/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0441 - accuracy: 0.9855 - val_loss: 0.7927 - val_accuracy: 0.8882
# Epoch 171/200
# 35/35 [==============================] - 7s 195ms/step - loss: 0.0683 - accuracy: 0.9719 - val_loss: 0.7321 - val_accuracy: 0.8903
# Epoch 172/200
# 35/35 [==============================] - 6s 187ms/step - loss: 0.0486 - accuracy: 0.9837 - val_loss: 0.7233 - val_accuracy: 0.8903
# Epoch 173/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0444 - accuracy: 0.9783 - val_loss: 0.7127 - val_accuracy: 0.8840
# Epoch 174/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0427 - accuracy: 0.9810 - val_loss: 0.7941 - val_accuracy: 0.8882
# Epoch 175/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0303 - accuracy: 0.9855 - val_loss: 0.7568 - val_accuracy: 0.8861
# Epoch 176/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0411 - accuracy: 0.9819 - val_loss: 0.7324 - val_accuracy: 0.8945
# Epoch 177/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0691 - accuracy: 0.9719 - val_loss: 0.6514 - val_accuracy: 0.9051
# Epoch 178/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0322 - accuracy: 0.9819 - val_loss: 0.6849 - val_accuracy: 0.8861
# Epoch 179/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0414 - accuracy: 0.9783 - val_loss: 0.7853 - val_accuracy: 0.8966
# Epoch 180/200
# 35/35 [==============================] - 6s 187ms/step - loss: 0.0344 - accuracy: 0.9828 - val_loss: 0.8575 - val_accuracy: 0.8945
# Epoch 181/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0362 - accuracy: 0.9837 - val_loss: 0.7877 - val_accuracy: 0.8924
# Epoch 182/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0431 - accuracy: 0.9828 - val_loss: 0.9718 - val_accuracy: 0.8861
# Epoch 183/200
# 35/35 [==============================] - 7s 195ms/step - loss: 0.0589 - accuracy: 0.9837 - val_loss: 0.9306 - val_accuracy: 0.9008
# Epoch 184/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0352 - accuracy: 0.9828 - val_loss: 0.6917 - val_accuracy: 0.8882
# Epoch 185/200
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0326 - accuracy: 0.9873 - val_loss: 0.7986 - val_accuracy: 0.8882
# Epoch 186/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0484 - accuracy: 0.9846 - val_loss: 0.5694 - val_accuracy: 0.9051
# Epoch 187/200
# 35/35 [==============================] - 6s 184ms/step - loss: 0.0298 - accuracy: 0.9864 - val_loss: 0.9569 - val_accuracy: 0.9051
# Epoch 188/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0354 - accuracy: 0.9810 - val_loss: 0.8600 - val_accuracy: 0.9008
# Epoch 189/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0393 - accuracy: 0.9837 - val_loss: 0.7149 - val_accuracy: 0.8966
# Epoch 190/200
# 35/35 [==============================] - 6s 187ms/step - loss: 0.0280 - accuracy: 0.9873 - val_loss: 0.9607 - val_accuracy: 0.8987
# Epoch 191/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0304 - accuracy: 0.9864 - val_loss: 0.8729 - val_accuracy: 0.8903
# Epoch 192/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0591 - accuracy: 0.9764 - val_loss: 0.5445 - val_accuracy: 0.8966
# Epoch 193/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0454 - accuracy: 0.9774 - val_loss: 0.6436 - val_accuracy: 0.8966
# Epoch 194/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0388 - accuracy: 0.9792 - val_loss: 0.9391 - val_accuracy: 0.8903
# Epoch 195/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0347 - accuracy: 0.9828 - val_loss: 0.6893 - val_accuracy: 0.9072
# Epoch 196/200
# 35/35 [==============================] - 7s 187ms/step - loss: 0.0364 - accuracy: 0.9810 - val_loss: 0.7686 - val_accuracy: 0.8945
# Epoch 197/200
# 35/35 [==============================] - 6s 186ms/step - loss: 0.0441 - accuracy: 0.9764 - val_loss: 0.8814 - val_accuracy: 0.8903
# Epoch 198/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0402 - accuracy: 0.9792 - val_loss: 0.6356 - val_accuracy: 0.8987
# Epoch 199/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0404 - accuracy: 0.9783 - val_loss: 0.6166 - val_accuracy: 0.9030
# Epoch 200/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0392 - accuracy: 0.9882 - val_loss: 0.8406 - val_accuracy: 0.8966
# 15/15 [==============================] - 1s 64ms/step - loss: 0.8406 - accuracy: 0.8966
# Test Accuracy: 89.66%

# %%
model.summary()

# %%
num_images_to_display = 10
selected_indices = np.random.choice(len(X_test), num_images_to_display, replace=False)
class_names = ['Benign', 'Malignant', 'Normal']
# Create a subplot grid
num_rows = 2
num_cols = num_images_to_display // num_rows
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display predictions for the selected test images
for i, index in enumerate(selected_indices):
    # Get the test image and true label
    test_image = X_test[index]
    true_label = np.argmax(y_test[index])

    # Preprocess the image
    img_array = np.expand_dims(test_image, axis=0)

    # Make predictions
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)

    # Display the image
    ax = axes[i]
    ax.imshow(test_image.reshape((150, 150)), cmap='gray')
    ax.set_title(f'True: {class_names[true_label]}, Predicted: {class_names[predicted_class]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
plt.savefig('/content/drive/MyDrive/Dataset BUSI with GT/prediction.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model


# Save the trained model
model.save('/content/drive/MyDrive/Dataset BUSI with GT/modelXception.h5')

# %%
# Load the model
loaded_model = load_model('/content/drive/MyDrive/Dataset BUSI with GT/modelXception.h5')

# Evaluate the model on the test set
y_pred = loaded_model.predict(X_test)

# Convert one-hot encoded labels back to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Plot confusion matrix with seaborn
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant', 'Normal'], yticklabels=['Benign', 'Malignant', 'Normal'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot classification report
class_report = classification_report(y_true_classes, y_pred_classes, target_names=['Benign', 'Malignant', 'Normal'])
print('Classification Report:\n', class_report)
# Out:
# 15/15 [==============================] - 2s 62ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.88      0.96      0.92       268
#    Malignant       0.90      0.81      0.85       126
#       Normal       0.94      0.84      0.89        80
#
#     accuracy                           0.90       474
#    macro avg       0.91      0.87      0.89       474
# weighted avg       0.90      0.90      0.90       474

# %%
# Visualize input-to-output
for i in range(5):  # You can adjust the range based on the number of samples you want to visualize
    input_image = X_test[i].reshape((150, 150))  # Assuming your input shape is (150, 150, 1)
    output_probabilities = y_pred[i]
    predicted_class = np.argmax(output_probabilities)

    plt.figure(figsize=(8, 4))

    # Plot input image
    plt.subplot(1, 2, 1)
    plt.imshow(input_image, cmap='gray')
    plt.title('Input Image')

    # Plot output probabilities
    plt.subplot(1, 2, 2)
    plt.bar(range(len(output_probabilities)), output_probabilities)
    plt.xticks(range(len(output_probabilities)), ['Benign', 'Malignant', 'Normal'])
    plt.title('Output Probabilities')

    plt.show()
