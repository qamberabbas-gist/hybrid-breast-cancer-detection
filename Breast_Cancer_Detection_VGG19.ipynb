# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG19
from tensorflow.keras.optimizers import Adam

# %%
import os

# Define the path to the dataset directory
dataset_path = "/content/drive/MyDrive/Dataset BUSI with GT"

# Get the list of image files
image_files = []
labels = []

# Iterate over the directories
for class_name in ['benign', 'malignant', 'normal']:
    class_path = os.path.join(dataset_path, class_name)
    for filename in os.listdir(class_path):
        image_path = os.path.join(class_path, filename)
        image_files.append(image_path)
        labels.append(class_name)

# Convert labels to numerical values
from tensorflow.keras.utils import to_categorical

# Convert labels to numerical values
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
# Get the original class labels from the label encoder
original_labels = label_encoder.classes_

# Convert labels to one-hot encoded format
labels = to_categorical(labels)


# Print the mapping between numerical values and original labels
for numerical_value, original_label in enumerate(original_labels):
    print(f"Numerical Value: {numerical_value}, Original Label: {original_label}")
# Out:
# Numerical Value: 0, Original Label: benign
# Numerical Value: 1, Original Label: malignant
# Numerical Value: 2, Original Label: normal

# %% [markdown]
# ### **CNN**

# %%
X_train, X_test, y_train, y_test = train_test_split(image_files, labels, test_size=0.3, random_state=42, stratify=labels)

# %%
# Define a function to load and preprocess the images
def load_preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((150, 150))
#this converts the image to BW
    image = image.convert('L')
    image = np.array(image)
    image = image.reshape((150, 150, 1))
#image normalization
    image = image.astype('float32') / 255.0
    return image

X_train = [str(image_path) for image_path in X_train]
X_test = [str(image_path) for image_path in X_test]

# Load and preprocess the training images and labels
X_train = [load_preprocess_image(image_path) for image_path in X_train]
X_train = np.array(X_train)
y_train= np.array(y_train)

# Load and preprocess the testing images and labels
X_test= [load_preprocess_image(image_path) for image_path in X_test]
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
#Check size and color channels of images and labels
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)

#Show images
images = X_test[:10]  # Assuming X_test contains the image data
labels = y_test[:10]  # Assuming y_test contains the corresponding labels

# Convert them to class indices
class_indices = np.argmax(labels, axis=1)

# Define class labels
class_labels = ['Benign', 'Malignant', 'Normal']

num_rows = 2
num_cols = len(images) // num_rows

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display images with labels in the subplots
for i in range(len(images)):
    ax = axes[i]
    ax.imshow(images[i], cmap='gray')  # Assuming images are 2D arrays (grayscale)
    ax.set_title(f'True Label: {class_labels[class_indices[i]]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# (1104, 150, 150, 1) (1104, 3)
# (474, 150, 150, 1) (474, 3)

# %%
from keras.applications import VGG19
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, Dense, Dropout

# Load the VGG19 base (excluding top layers)
vgg19_base = VGG19(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

# Create a Sequential model
model = Sequential()

# Add a custom convolutional layer to handle grayscale input
model.add(Conv2D(3, (3, 3), activation='relu', input_shape=(150, 150, 1), padding='same'))  # Adjust input_shape to (150, 150, 1)

# Add the VGG19 base (excluding top layers)
model.add(vgg19_base)

# Freeze the VGG19 layers
for layer in vgg19_base.layers:
    layer.trainable = False

# Add custom layers on top of VGG19
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes (benign, malignant, normal)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %%
# Train the model and collect the history
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))


# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 35/35 [==============================] - 29s 459ms/step - loss: 0.9478 - accuracy: 0.6196 - val_loss: 0.6064 - val_accuracy: 0.7321
# Epoch 2/200
# 35/35 [==============================] - 7s 190ms/step - loss: 0.6161 - accuracy: 0.7364 - val_loss: 0.5001 - val_accuracy: 0.8207
# Epoch 3/200
# 35/35 [==============================] - 7s 192ms/step - loss: 0.5400 - accuracy: 0.7654 - val_loss: 0.4797 - val_accuracy: 0.7996
# Epoch 4/200
# 35/35 [==============================] - 7s 192ms/step - loss: 0.4730 - accuracy: 0.8025 - val_loss: 0.4272 - val_accuracy: 0.8017
# Epoch 5/200
# 35/35 [==============================] - 7s 196ms/step - loss: 0.4487 - accuracy: 0.8188 - val_loss: 0.4075 - val_accuracy: 0.8143
# Epoch 6/200
# 35/35 [==============================] - 7s 191ms/step - loss: 0.4088 - accuracy: 0.8424 - val_loss: 0.3548 - val_accuracy: 0.8418
# Epoch 7/200
# 35/35 [==============================] - 7s 197ms/step - loss: 0.3791 - accuracy: 0.8397 - val_loss: 0.3562 - val_accuracy: 0.8565
# Epoch 8/200
# 35/35 [==============================] - 7s 193ms/step - loss: 0.3557 - accuracy: 0.8533 - val_loss: 0.3332 - val_accuracy: 0.8776
# Epoch 9/200
# 35/35 [==============================] - 7s 200ms/step - loss: 0.3559 - accuracy: 0.8596 - val_loss: 0.3214 - val_accuracy: 0.8650
# Epoch 10/200
# 35/35 [==============================] - 7s 198ms/step - loss: 0.2962 - accuracy: 0.8877 - val_loss: 0.3161 - val_accuracy: 0.8819
# Epoch 11/200
# 35/35 [==============================] - 7s 203ms/step - loss: 0.2769 - accuracy: 0.8850 - val_loss: 0.2925 - val_accuracy: 0.8819
# Epoch 12/200
# 35/35 [==============================] - 7s 202ms/step - loss: 0.2610 - accuracy: 0.8958 - val_loss: 0.2926 - val_accuracy: 0.8671
# Epoch 13/200
# 35/35 [==============================] - 7s 203ms/step - loss: 0.2772 - accuracy: 0.8841 - val_loss: 0.2856 - val_accuracy: 0.8819
# Epoch 14/200
# 35/35 [==============================] - 7s 205ms/step - loss: 0.2407 - accuracy: 0.9085 - val_loss: 0.2715 - val_accuracy: 0.8861
# Epoch 15/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.2437 - accuracy: 0.9049 - val_loss: 0.2827 - val_accuracy: 0.8840
# Epoch 16/200
# 35/35 [==============================] - 7s 211ms/step - loss: 0.2073 - accuracy: 0.9239 - val_loss: 0.2945 - val_accuracy: 0.8840
# Epoch 17/200
# 35/35 [==============================] - 7s 213ms/step - loss: 0.1968 - accuracy: 0.9248 - val_loss: 0.2852 - val_accuracy: 0.8776
# Epoch 18/200
# 35/35 [==============================] - 7s 215ms/step - loss: 0.2119 - accuracy: 0.9167 - val_loss: 0.2688 - val_accuracy: 0.8987
# Epoch 19/200
# 35/35 [==============================] - 7s 212ms/step - loss: 0.2087 - accuracy: 0.9176 - val_loss: 0.2748 - val_accuracy: 0.9051
# Epoch 20/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0
200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0364 - accuracy: 0.9846 - val_loss: 0.5396 - val_accuracy: 0.9008
# Epoch 145/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0426 - accuracy: 0.9819 - val_loss: 0.6377 - val_accuracy: 0.9030
# Epoch 146/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0299 - accuracy: 0.9837 - val_loss: 0.5882 - val_accuracy: 0.9072
# Epoch 147/200
# 35/35 [==============================] - 7s 207ms/step - loss: 0.0405 - accuracy: 0.9837 - val_loss: 0.5779 - val_accuracy: 0.9072
# Epoch 148/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0272 - accuracy: 0.9882 - val_loss: 0.6503 - val_accuracy: 0.9008
# Epoch 149/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0379 - accuracy: 0.9846 - val_loss: 0.5912 - val_accuracy: 0.8966
# Epoch 150/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0499 - accuracy: 0.9846 - val_loss: 0.5259 - val_accuracy: 0.8882
# Epoch 151/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0587 - accuracy: 0.9764 - val_loss: 0.7461 - val_accuracy: 0.8924
# Epoch 152/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0473 - accuracy: 0.9837 - val_loss: 0.6308 - val_accuracy: 0.9114
# Epoch 153/200
# 35/35 [==============================] - 7s 207ms/step - loss: 0.0437 - accuracy: 0.9855 - val_loss: 0.6897 - val_accuracy: 0.9008
# Epoch 154/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0574 - accuracy: 0.9746 - val_loss: 0.4878 - val_accuracy: 0.9093
# Epoch 155/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0480 - accuracy: 0.9810 - val_loss: 0.6964 - val_accuracy: 0.9093
# Epoch 156/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0447 - accuracy: 0.9837 - val_loss: 0.5968 - val_accuracy: 0.8987
# Epoch 157/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0427 - accuracy: 0.9837 - val_loss: 0.5820 - val_accuracy: 0.9135
# Epoch 158/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0498 - accuracy: 0.9828 - val_loss: 0.6273 - val_accuracy: 0.9030
# Epoch 159/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0503 - accuracy: 0.9792 - val_loss: 0.6805 - val_accuracy: 0.9008
# Epoch 160/200
# 35/35 [==============================] - 7s 211ms/step - loss: 0.0656 - accuracy: 0.9692 - val_loss: 0.5284 - val_accuracy: 0.8924
# Epoch 161/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0621 - accuracy: 0.9728 - val_loss: 0.6927 - val_accuracy: 0.8903
# Epoch 162/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.1080 - accuracy: 0.9583 - val_loss: 0.4446 - val_accuracy: 0.9030
# Epoch 163/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0666 - accuracy: 0.9692 - val_loss: 0.4753 - val_accuracy: 0.8987
# Epoch 164/200
# 35/35 [==============================] - 7s 211ms/step - loss: 0.0395 - accuracy: 0.9846 - val_loss: 0.6009 - val_accuracy: 0.9008
# Epoch 165/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0419 - accuracy: 0.9819 - val_loss: 0.6001 - val_accuracy: 0.8903
# Epoch 166/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0458 - accuracy: 0.9774 - val_loss: 0.5110 - val_accuracy: 0.9030
# Epoch 167/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0431 - accuracy: 0.9837 - val_loss: 0.5428 - val_accuracy: 0.9008
# Epoch 168/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0606 - accuracy: 0.9764 - val_loss: 0.5114 - val_accuracy: 0.8882
# Epoch 169/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0533 - accuracy: 0.9774 - val_loss: 0.5838 - val_accuracy: 0.9072
# Epoch 170/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0616 - accuracy: 0.9746 - val_loss: 0.6899 - val_accuracy: 0.9008
# Epoch 171/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0464 - accuracy: 0.9764 - val_loss: 0.5098 - val_accuracy: 0.9008
# Epoch 172/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0600 - accuracy: 0.9792 - val_loss: 0.6875 - val_accuracy: 0.8966
# Epoch 173/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0477 - accuracy: 0.9828 - val_loss: 0.6083 - val_accuracy: 0.8903
# Epoch 174/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0493 - accuracy: 0.9801 - val_loss: 0.7994 - val_accuracy: 0.8987
# Epoch 175/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0344 - accuracy: 0.9873 - val_loss: 0.8162 - val_accuracy: 0.8924
# Epoch 176/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0562 - accuracy: 0.9737 - val_loss: 0.5199 - val_accuracy: 0.8966
# Epoch 177/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0538 - accuracy: 0.9774 - val_loss: 0.5562 - val_accuracy: 0.9030
# Epoch 178/200
# 35/35 [==============================] - 7s 211ms/step - loss: 0.0474 - accuracy: 0.9792 - val_loss: 0.6229 - val_accuracy: 0.9030
# Epoch 179/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0361 - accuracy: 0.9864 - val_loss: 0.6789 - val_accuracy: 0.9030
# Epoch 180/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0416 - accuracy: 0.9810 - val_loss: 0.6497 - val_accuracy: 0.9030
# Epoch 181/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0431 - accuracy: 0.9828 - val_loss: 0.5914 - val_accuracy: 0.8966
# Epoch 182/200
# 35/35 [==============================] - 7s 211ms/step - loss: 0.0353 - accuracy: 0.9882 - val_loss: 1.0116 - val_accuracy: 0.8945
# Epoch 183/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0476 - accuracy: 0.9828 - val_loss: 0.5852 - val_accuracy: 0.9030
# Epoch 184/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0575 - accuracy: 0.9764 - val_loss: 0.6422 - val_accuracy: 0.9051
# Epoch 185/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0390 - accuracy: 0.9864 - val_loss: 0.7509 - val_accuracy: 0.8966
# Epoch 186/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0325 - accuracy: 0.9846 - val_loss: 0.7098 - val_accuracy: 0.9051
# Epoch 187/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0521 - accuracy: 0.9774 - val_loss: 0.6965 - val_accuracy: 0.9030
# Epoch 188/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0474 - accuracy: 0.9783 - val_loss: 0.7464 - val_accuracy: 0.9008
# Epoch 189/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0601 - accuracy: 0.9764 - val_loss: 0.6043 - val_accuracy: 0.9008
# Epoch 190/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0607 - accuracy: 0.9737 - val_loss: 0.5398 - val_accuracy: 0.9030
# Epoch 191/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0626 - accuracy: 0.9764 - val_loss: 0.5789 - val_accuracy: 0.8924
# Epoch 192/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0510 - accuracy: 0.9764 - val_loss: 0.5331 - val_accuracy: 0.8966
# Epoch 193/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0567 - accuracy: 0.9746 - val_loss: 0.6304 - val_accuracy: 0.9030
# Epoch 194/200
# 35/35 [==============================] - 7s 211ms/step - loss: 0.0679 - accuracy: 0.9719 - val_loss: 0.5478 - val_accuracy: 0.9051
# Epoch 195/200
# 35/35 [==============================] - 7s 209ms/step - loss: 0.0582 - accuracy: 0.9719 - val_loss: 0.7259 - val_accuracy: 0.8882
# Epoch 196/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0378 - accuracy: 0.9864 - val_loss: 0.6336 - val_accuracy: 0.9008
# Epoch 197/200
# 35/35 [==============================] - 7s 208ms/step - loss: 0.0257 - accuracy: 0.9900 - val_loss: 0.7092 - val_accuracy: 0.8924
# Epoch 198/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0502 - accuracy: 0.9792 - val_loss: 0.5000 - val_accuracy: 0.9093
# Epoch 199/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0394 - accuracy: 0.9792 - val_loss: 0.6729 - val_accuracy: 0.9030
# Epoch 200/200
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0351 - accuracy: 0.9855 - val_loss: 0.6978 - val_accuracy: 0.8987
# 15/15 [==============================] - 1s 82ms/step - loss: 0.6978 - accuracy: 0.8987
# Test Accuracy: 89.87%

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 3)       30
#
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 21073505 (80.39 MB)
# Trainable params: 1049121 (4.00 MB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
num_images_to_display = 10
selected_indices = np.random.choice(len(X_test), num_images_to_display, replace=False)
class_names = ['Benign', 'Malignant', 'Normal']
# Create a subplot grid
num_rows = 2
num_cols = num_images_to_display // num_rows
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display predictions for the selected test images
for i, index in enumerate(selected_indices):
    # Get the test image and true label
    test_image = X_test[index]
    true_label = np.argmax(y_test[index])

    # Preprocess the image
    img_array = np.expand_dims(test_image, axis=0)

    # Make predictions
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)

    # Display the image
    ax = axes[i]
    ax.imshow(test_image.reshape((150, 150)), cmap='gray')
    ax.set_title(f'True: {class_names[true_label]}, Predicted: {class_names[predicted_class]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
plt.savefig('/content/drive/MyDrive/Dataset BUSI with GT/prediction.png')
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model


# Save the trained model
model.save('/content/drive/MyDrive/Dataset BUSI with GT/modelvgg19.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
loaded_model = load_model('/content/drive/MyDrive/Dataset BUSI with GT/modelvgg19.h5')

# Evaluate the model on the test set
y_pred = loaded_model.predict(X_test)

# Convert one-hot encoded labels back to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Plot confusion matrix with seaborn
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant', 'Normal'], yticklabels=['Benign', 'Malignant', 'Normal'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot classification report
class_report = classification_report(y_true_classes, y_pred_classes, target_names=['Benign', 'Malignant', 'Normal'])
print('Classification Report:\n', class_report)
# Out:
# 15/15 [==============================] - 1s 83ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.92      0.93      0.92       268
#    Malignant       0.84      0.90      0.87       126
#       Normal       0.94      0.81      0.87        80
#
#     accuracy                           0.90       474
#    macro avg       0.90      0.88      0.89       474
# weighted avg       0.90      0.90      0.90       474

# %%
# Visualize input-to-output
for i in range(5):  # You can adjust the range based on the number of samples you want to visualize
    input_image = X_test[i].reshape((150, 150))  # Assuming your input shape is (150, 150, 1)
    output_probabilities = y_pred[i]
    predicted_class = np.argmax(output_probabilities)

    plt.figure(figsize=(8, 4))

    # Plot input image
    plt.subplot(1, 2, 1)
    plt.imshow(input_image, cmap='gray')
    plt.title('Input Image')

    # Plot output probabilities
    plt.subplot(1, 2, 2)
    plt.bar(range(len(output_probabilities)), output_probabilities)
    plt.xticks(range(len(output_probabilities)), ['Benign', 'Malignant', 'Normal'])
    plt.title('Output Probabilities')

    plt.show()
