# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.optimizers import Adam

# %%
import os

# Define the path to the dataset directory
dataset_path = "/content/drive/MyDrive/Dataset BUSI with GT"

# Get the list of image files
image_files = []
labels = []

# Iterate over the directories
for class_name in ['benign', 'malignant', 'normal']:
    class_path = os.path.join(dataset_path, class_name)
    for filename in os.listdir(class_path):
        image_path = os.path.join(class_path, filename)
        image_files.append(image_path)
        labels.append(class_name)

# Convert labels to numerical values
from tensorflow.keras.utils import to_categorical

# Convert labels to numerical values
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
# Get the original class labels from the label encoder
original_labels = label_encoder.classes_

# Convert labels to one-hot encoded format
labels = to_categorical(labels)


# Print the mapping between numerical values and original labels
for numerical_value, original_label in enumerate(original_labels):
    print(f"Numerical Value: {numerical_value}, Original Label: {original_label}")
# Out:
# Numerical Value: 0, Original Label: benign
# Numerical Value: 1, Original Label: malignant
# Numerical Value: 2, Original Label: normal

# %% [markdown]
# ### **CNN**

# %%
X_train, X_test, y_train, y_test = train_test_split(image_files, labels, test_size=0.3, random_state=42, stratify=labels)

# %%
# Define a function to load and preprocess the images
def load_preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((150, 150))
#this converts the image to BW
    image = image.convert('L')
    image = np.array(image)
    image = image.reshape((150, 150, 1))
#image normalization
    image = image.astype('float32') / 255.0
    return image

X_train = [str(image_path) for image_path in X_train]
X_test = [str(image_path) for image_path in X_test]

# Load and preprocess the training images and labels
X_train = [load_preprocess_image(image_path) for image_path in X_train]
X_train = np.array(X_train)
y_train= np.array(y_train)

# Load and preprocess the testing images and labels
X_test= [load_preprocess_image(image_path) for image_path in X_test]
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
#Check size and color channels of images and labels
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)

#Show images
images = X_test[:10]  # Assuming X_test contains the image data
labels = y_test[:10]  # Assuming y_test contains the corresponding labels

# Convert them to class indices
class_indices = np.argmax(labels, axis=1)

# Define class labels
class_labels = ['Benign', 'Malignant', 'Normal']

num_rows = 2
num_cols = len(images) // num_rows

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display images with labels in the subplots
for i in range(len(images)):
    ax = axes[i]
    ax.imshow(images[i], cmap='gray')  # Assuming images are 2D arrays (grayscale)
    ax.set_title(f'True Label: {class_labels[class_indices[i]]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# (1104, 150, 150, 1) (1104, 3)
# (474, 150, 150, 1) (474, 3)

# %%
# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes (benign, malignant, normal)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model and collect the history
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))


# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 35/35 [==============================] - 3s 35ms/step - loss: 0.8549 - accuracy: 0.5897 - val_loss: 0.7660 - val_accuracy: 0.6540
# Epoch 2/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.7041 - accuracy: 0.6848 - val_loss: 0.7105 - val_accuracy: 0.6857
# Epoch 3/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.6422 - accuracy: 0.7165 - val_loss: 0.6899 - val_accuracy: 0.6751
# Epoch 4/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.5842 - accuracy: 0.7274 - val_loss: 0.6649 - val_accuracy: 0.6899
# Epoch 5/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.5016 - accuracy: 0.7763 - val_loss: 0.6606 - val_accuracy: 0.7300
# Epoch 6/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.4375 - accuracy: 0.8107 - val_loss: 0.6114 - val_accuracy: 0.7532
# Epoch 7/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.3529 - accuracy: 0.8578 - val_loss: 0.6961 - val_accuracy: 0.7257
# Epoch 8/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.3153 - accuracy: 0.8795 - val_loss: 0.7620 - val_accuracy: 0.7637
# Epoch 9/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.2319 - accuracy: 0.9149 - val_loss: 0.9491 - val_accuracy: 0.7700
# Epoch 10/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.1912 - accuracy: 0.9185 - val_loss: 1.1140 - val_accuracy: 0.7236
# Epoch 11/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.1711 - accuracy: 0.9375 - val_loss: 1.1041 - val_accuracy: 0.7532
# Epoch 12/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.1552 - accuracy: 0.9447 - val_loss: 1.1212 - val_accuracy: 0.7637
# Epoch 13/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.1260 - accuracy: 0.9583 - val_loss: 1.0661 - val_accuracy: 0.7827
# Epoch 14/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0979 - accuracy: 0.9710 - val_loss: 1.2462 - val_accuracy: 0.7785
# Epoch 15/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0626 - accuracy: 0.9855 - val_loss: 1.3722 - val_accuracy: 0.7764
# Epoch 16/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0696 - accuracy: 0.9746 - val_loss: 1.3010 - val_accuracy: 0.7911
# Epoch 17/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0577 - accuracy: 0.9792 - val_loss: 1.3698 - val_accuracy: 0.7869
# Epoch 18/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0696 - accuracy: 0.9819 - val_loss: 1.4270 - val_accuracy: 0.8017
# Epoch 19/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0714 - accuracy: 0.9764 - val_loss: 1.3528 - val_accuracy: 0.7996
# Epoch 20/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0907 - accuracy: 0.9764 - val_loss: 1.3006 - val_accuracy: 0.7764
# Epoch 21/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0613 - accuracy: 0.9819 - val_loss: 1.3894 - val_accuracy: 0.7932
# Epoch 22/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0460 - accuracy: 0.9837 - val_loss: 1.4093 - val_accuracy: 0.7869
# Epoch 23/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0552 - accuracy: 0.9855 - val_loss: 1.5181 - val_accuracy: 0.7890
# Epoch 24/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0518 - accuracy: 0.9819 - val_loss: 1.4347 - val_accuracy: 0.7827
# Epoch 25/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0566 - accuracy: 0.9810 - val_loss: 1.2820 - val_accuracy: 0.7954
# Epoch 26/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0274 - accuracy: 0.9891 - val_loss: 1.3274 - val_accuracy: 0.7975
# Epoch 27/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0210 - accuracy: 0.9946 - val_loss: 1.6729 - val_accuracy: 0.7785
# Epoch 28/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0234 - accuracy: 0.9918 - val_loss: 1.6657 - val_accuracy: 0.7954
# Epoch 29/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0551 - accuracy: 0.9909 - val_loss: 1.4811 - val_accuracy: 0.7890
# Epoch 30/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0282 - accuracy: 0.9900 - val_loss: 2.0426 - val_accuracy: 0.7848
# Epoch 31/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0278 - accuracy: 0.9909 - val_loss: 1.7462 - val_accuracy: 0.7785
# Epoch 32/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0341 - accuracy: 0.9882 - val_loss: 1.7696 - val_accuracy: 0.7806
# Epoch 33/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 1.9376 - val_accuracy: 0.7827
# Epoch 34/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0183 - accuracy: 0.9955 - val_loss: 1.7375 - val_accuracy: 0.7785
# Epoch 35/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 1.8690 - val_accuracy: 0.7827
# Epoch 36/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0190 - accuracy: 0.9946 - val_loss: 2.1105 - val_accuracy: 0.7890
# Epoch 37/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0218 - accuracy: 0.9918 - val_loss: 1.9899 - val_accuracy: 0.7890
# Epoch 38/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0213 - accuracy: 0.9918 - val_loss: 1.8691 - val_accuracy: 0.7806
# Epoch 39/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0308 - accuracy: 0.9900 - val_loss: 1.9580 - val_accuracy: 0.7806
# Epoch 40/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 1.8349 - val_accuracy: 0.7848
# Epoch 41/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 1.8524 - val_accuracy: 0.7848
# Epoch 42/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0178 - accuracy: 0.9964 - val_loss: 2.1192 - val_accuracy: 0.7827
# Epoch 43/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0136 - accuracy: 0.9964 - val_loss: 2.1295 - val_accuracy: 0.7848
# Epoch 44/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0281 - accuracy: 0.9918 - val_loss: 2.1834 - val_accuracy: 0.7679
# Epoch 45/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 2.3767 - val_accuracy: 0.7785
# Epoch 46/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0202 - accuracy: 0.9918 - val_loss: 1.9787 - val_accuracy: 0.7911
# Epoch 47/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0266 - accuracy: 0.9946 - val_loss: 1.9953 - val_accuracy: 0.7827
# Epoch 48/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0325 - accuracy: 0.9891 - val_loss: 1.9607 - val_accuracy: 0.7911
# Epoch 49/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0201 - accuracy: 0.9937 - val_loss: 2.1739 - val_accuracy: 0.7932
# Epoch 50/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0325 - accuracy: 0.9928 - val_loss: 2.2755 - val_accuracy: 0.7848
# Epoch 51/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0280 - accuracy: 0.9937 - val_loss: 2.0881 - val_accuracy: 0.7911
# Epoch 52/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0238 - accuracy: 0.9955 - val_loss: 1.9126 - val_accuracy: 0.7975
# Epoch 53/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0244 - accuracy: 0.9928 - val_loss: 1.8733 - val_accuracy: 0.7954
# Epoch 54/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0219 - accuracy: 0.9928 - val_loss: 2.0642 - val_accuracy: 0.7954
# Epoch 55/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0104 - accuracy: 0.9964 - val_loss: 2.1874 - val_accuracy: 0.7954
# Epoch 56/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0324 - accuracy: 0.9891 - val_loss: 2.0069 - val_accuracy: 0.8080
# Epoch 57/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0097 - accuracy: 0.9982 - val_loss: 2.1612 - val_accuracy: 0.8038
# Epoch 58/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 2.2458 - val_accuracy: 0.7890
# Epoch 59/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0188 - accuracy: 0.9946 - val_loss: 2.2620 - val_accuracy: 0.7932
# Epoch 60/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 2.3505 - val_accuracy: 0.7848
# Epoch 61/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0252 - accuracy: 0.9909 - val_loss: 2.0952 - val_accuracy: 0.7700
# Epoch 62/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 2.0832 - val_accuracy: 0.7743
# Epoch 63/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0172 - accuracy: 0.9946 - val_loss: 2.1186 - val_accuracy: 0.7869
# Epoch 64/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0149 - accuracy: 0.9973 - val_loss: 1.8913 - val_accuracy: 0.8038
# Epoch 65/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 2.0129 - val_accuracy: 0.7932
# Epoch 66/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0191 - accuracy: 0.9928 - val_loss: 2.2764 - val_accuracy: 0.7785
# Epoch 67/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 2.6823 - val_accuracy: 0.7700
# Epoch 68/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0404 - accuracy: 0.9864 - val_loss: 2.0858 - val_accuracy: 0.7911
# Epoch 69/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0361 - accuracy: 0.9900 - val_loss: 1.7746 - val_accuracy: 0.8017
# Epoch 70/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 1.7501 - val_accuracy: 0.7869
# Epoch 71/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0132 - accuracy: 0.9964 - val_loss: 2.2622 - val_accuracy: 0.7932
# Epoch 72/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0360 - accuracy: 0.9900 - val_loss: 2.1402 - val_accuracy: 0.8038
# Epoch 73/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0143 - accuracy: 0.9937 - val_loss: 2.1462 - val_accuracy: 0.7954
# Epoch 74/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0124 - accuracy: 0.9964 - val_loss: 2.3311 - val_accuracy: 0.7679
# Epoch 75/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0062 - accuracy: 0.9964 - val_loss: 2.0762 - val_accuracy: 0.7869
# Epoch 76/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0140 - accuracy: 0.9928 - val_loss: 2.1221 - val_accuracy: 0.7806
# Epoch 77/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0261 - accuracy: 0.9918 - val_loss: 2.1720 - val_accuracy: 0.7911
# Epoch 78/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0199 - accuracy: 0.9918 - val_loss: 2.2743 - val_accuracy: 0.7658
# Epoch 79/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0306 - accuracy: 0.9909 - val_loss: 2.1151 - val_accuracy: 0.7827
# Epoch 80/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0168 - accuracy: 0.9918 - val_loss: 2.1373 - val_accuracy: 0.7869
# Epoch 81/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0209 - accuracy: 0.9928 - val_loss: 2.1324 - val_accuracy: 0.7869
# Epoch 82/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 2.2499 - val_accuracy: 0.7848
# Epoch 83/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0104 - accuracy: 0.9964 - val_loss: 2.3187 - val_accuracy: 0.7890
# Epoch 84/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0176 - accuracy: 0.9946 - val_loss: 2.1900 - val_accuracy: 0.7806
# Epoch 85/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 2.1473 - val_accuracy: 0.7848
# Epoch 86/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0147 - accuracy: 0.9973 - val_loss: 2.3583 - val_accuracy: 0.7806
# Epoch 87/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 2.1979 - val_accuracy: 0.7764
# Epoch 88/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0058 - accuracy: 0.9973 - val_loss: 2.4289 - val_accuracy: 0.7785
# Epoch 89/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0221 - accuracy: 0.9973 - val_loss: 2.0797 - val_accuracy: 0.7764
# Epoch 90/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0066 - accuracy: 0.9964 - val_loss: 2.2414 - val_accuracy: 0.7848
# Epoch 91/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0141 - accuracy: 0.9946 - val_loss: 2.2689 - val_accuracy: 0.7785
# Epoch 92/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0143 - accuracy: 0.9964 - val_loss: 2.0664 - val_accuracy: 0.7890
# Epoch 93/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 2.4563 - val_accuracy: 0.7911
# Epoch 94/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 2.8232 - val_accuracy: 0.7700
# Epoch 95/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 2.2134 - val_accuracy: 0.7975
# Epoch 96/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 2.5149 - val_accuracy: 0.7722
# Epoch 97/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0092 - accuracy: 0.9982 - val_loss: 2.4724 - val_accuracy: 0.7764
# Epoch 98/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0139 - accuracy: 0.9946 - val_loss: 2.5721 - val_accuracy: 0.7700
# Epoch 99/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0252 - accuracy: 0.9937 - val_loss: 2.1538 - val_accuracy: 0.7679
# Epoch 100/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 2.6994 - val_accuracy: 0.7637
# Epoch 101/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0066 - accuracy: 0.9964 - val_loss: 2.7436 - val_accuracy: 0.7679
# Epoch 102/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 2.7089 - val_accuracy: 0.7764
# Epoch 103/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0113 - accuracy: 0.9973 - val_loss: 2.0848 - val_accuracy: 0.7911
# Epoch 104/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 2.4668 - val_accuracy: 0.7869
# Epoch 105/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0085 - accuracy: 0.9964 - val_loss: 2.5997 - val_accuracy: 0.7848
# Epoch 106/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0105 - accuracy: 0.9955 - val_loss: 2.4884 - val_accuracy: 0.7658
# Epoch 107/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0075 - accuracy: 0.9964 - val_loss: 2.6331 - val_accuracy: 0.7785
# Epoch 108/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0141 - accuracy: 0.9937 - val_loss: 2.9416 - val_accuracy: 0.7975
# Epoch 109/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0134 - accuracy: 0.9973 - val_loss: 2.3541 - val_accuracy: 0.7827
# Epoch 110/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 2.5661 - val_accuracy: 0.7764
# Epoch 111/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0082 - accuracy: 0.9955 - val_loss: 2.5576 - val_accuracy: 0.7827
# Epoch 112/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0153 - accuracy: 0.9955 - val_loss: 2.2207 - val_accuracy: 0.7869
# Epoch 113/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 2.1487 - val_accuracy: 0.7743
# Epoch 114/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0251 - accuracy: 0.9909 - val_loss: 2.3351 - val_accuracy: 0.7574
# Epoch 115/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0252 - accuracy: 0.9928 - val_loss: 2.6452 - val_accuracy: 0.7890
# Epoch 116/200
# 35/35 [==============================] - 1s 32ms/step - loss: 0.0182 - accuracy: 0.9955 - val_loss: 2.6976 - val_accuracy: 0.7722
# Epoch 117/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0127 - accuracy: 0.9973 - val_loss: 2.7489 - val_accuracy: 0.7848
# Epoch 118/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0065 - accuracy: 0.9964 - val_loss: 2.7534 - val_accuracy: 0.7785
# Epoch 119/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 3.2943 - val_accuracy: 0.7890
# Epoch 120/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 2.5959 - val_accuracy: 0.7722
# Epoch 121/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0275 - accuracy: 0.9928 - val_loss: 2.9826 - val_accuracy: 0.7722
# Epoch 122/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 3.0298 - val_accuracy: 0.7806
# Epoch 123/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0204 - accuracy: 0.9946 - val_loss: 2.4652 - val_accuracy: 0.7574
# Epoch 124/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0131 - accuracy: 0.9937 - val_loss: 2.5638 - val_accuracy: 0.7595
# Epoch 125/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 2.6848 - val_accuracy: 0.7658
# Epoch 126/200
# 35/35 [==============================] - 1s 30ms/step - loss: 0.0112 - accuracy: 0.9955 - val_loss: 2.8680 - val_accuracy: 0.7722
# Epoch 127/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 2.9952 - val_accuracy: 0.7722
# Epoch 128/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 2.6600 - val_accuracy: 0.7700
# Epoch 129/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 2.6099 - val_accuracy: 0.7637
# Epoch 130/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 2.7666 - val_accuracy: 0.7679
# Epoch 131/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0115 - accuracy: 0.9973 - val_loss: 2.8383 - val_accuracy: 0.7785
# Epoch 132/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 2.8248 - val_accuracy: 0.7700
# Epoch 133/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0058 - accuracy: 0.9964 - val_loss: 3.1095 - val_accuracy: 0.7827
# Epoch 134/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 3.1518 - val_accuracy: 0.7806
# Epoch 135/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 2.3236 - val_accuracy: 0.7553
# Epoch 136/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0066 - accuracy: 0.9964 - val_loss: 2.5707 - val_accuracy: 0.7743
# Epoch 137/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0070 - accuracy: 0.9964 - val_loss: 2.4882 - val_accuracy: 0.7764
# Epoch 138/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 2.6195 - val_accuracy: 0.7764
# Epoch 139/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0058 - accuracy: 0.9973 - val_loss: 2.9419 - val_accuracy: 0.7848
# Epoch 140/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0138 - accuracy: 0.9964 - val_loss: 2.5936 - val_accuracy: 0.7827
# Epoch 141/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 2.5850 - val_accuracy: 0.7595
# Epoch 142/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0124 - accuracy: 0.9973 - val_loss: 3.1620 - val_accuracy: 0.7468
# Epoch 143/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 2.9931 - val_accuracy: 0.7722
# Epoch 144/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0061 - accuracy: 0.9973 - val_loss: 2.9560 - val_accuracy: 0.7616
# Epoch 145/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0062 - accuracy: 0.9964 - val_loss: 3.1524 - val_accuracy: 0.7785
# Epoch 146/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 3.3296 - val_accuracy: 0.7785
# Epoch 147/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 3.4948 - val_accuracy: 0.7743
# Epoch 148/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0050 - accuracy: 0.9973 - val_loss: 3.5719 - val_accuracy: 0.7722
# Epoch 149/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0112 - accuracy: 0.9982 - val_loss: 3.4083 - val_accuracy: 0.7785
# Epoch 150/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 2.5643 - val_accuracy: 0.7553
# Epoch 151/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 2.4905 - val_accuracy: 0.7637
# Epoch 152/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 2.6333 - val_accuracy: 0.7553
# Epoch 153/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 2.9638 - val_accuracy: 0.7679
# Epoch 154/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 3.0332 - val_accuracy: 0.7637
# Epoch 155/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 3.0347 - val_accuracy: 0.7658
# Epoch 156/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 2.8958 - val_accuracy: 0.7722
# Epoch 157/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 3.2611 - val_accuracy: 0.7785
# Epoch 158/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.1385 - val_accuracy: 0.7574
# Epoch 159/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0063 - accuracy: 0.9973 - val_loss: 3.1169 - val_accuracy: 0.7574
# Epoch 160/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0112 - accuracy: 0.9973 - val_loss: 3.3222 - val_accuracy: 0.7637
# Epoch 161/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0114 - accuracy: 0.9955 - val_loss: 2.9596 - val_accuracy: 0.7489
# Epoch 162/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 3.5405 - val_accuracy: 0.7532
# Epoch 163/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 3.4595 - val_accuracy: 0.7553
# Epoch 164/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0111 - accuracy: 0.9946 - val_loss: 3.2114 - val_accuracy: 0.7764
# Epoch 165/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 2.9060 - val_accuracy: 0.7679
# Epoch 166/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0164 - accuracy: 0.9964 - val_loss: 3.0841 - val_accuracy: 0.7658
# Epoch 167/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0231 - accuracy: 0.9982 - val_loss: 2.8814 - val_accuracy: 0.7679
# Epoch 168/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0033 - accuracy: 0.9982 - val_loss: 2.9646 - val_accuracy: 0.7764
# Epoch 169/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0054 - accuracy: 0.9973 - val_loss: 3.1356 - val_accuracy: 0.7679
# Epoch 170/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 2.4102 - val_accuracy: 0.7743
# Epoch 171/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0101 - accuracy: 0.9982 - val_loss: 2.7255 - val_accuracy: 0.7806
# Epoch 172/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0247 - accuracy: 0.9955 - val_loss: 2.8353 - val_accuracy: 0.7700
# Epoch 173/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0248 - accuracy: 0.9946 - val_loss: 2.6199 - val_accuracy: 0.7700
# Epoch 174/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0152 - accuracy: 0.9973 - val_loss: 2.5457 - val_accuracy: 0.7722
# Epoch 175/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0078 - accuracy: 0.9964 - val_loss: 3.5325 - val_accuracy: 0.7848
# Epoch 176/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 3.2227 - val_accuracy: 0.7764
# Epoch 177/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0117 - accuracy: 0.9973 - val_loss: 3.3377 - val_accuracy: 0.7700
# Epoch 178/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 3.0539 - val_accuracy: 0.7743
# Epoch 179/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0031 - accuracy: 0.9982 - val_loss: 3.0192 - val_accuracy: 0.7722
# Epoch 180/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0130 - accuracy: 0.9973 - val_loss: 2.9558 - val_accuracy: 0.7658
# Epoch 181/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 2.9486 - val_accuracy: 0.7743
# Epoch 182/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 2.7641 - val_accuracy: 0.7785
# Epoch 183/200
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 2.9019 - val_accuracy: 0.7764
# Epoch 184/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 2.9585 - val_accuracy: 0.7806
# Epoch 185/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0297 - accuracy: 0.9964 - val_loss: 2.4685 - val_accuracy: 0.7700
# Epoch 186/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 2.7634 - val_accuracy: 0.7764
# Epoch 187/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0062 - accuracy: 0.9964 - val_loss: 2.8091 - val_accuracy: 0.7785
# Epoch 188/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 2.7889 - val_accuracy: 0.7764
# Epoch 189/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0093 - accuracy: 0.9982 - val_loss: 2.9572 - val_accuracy: 0.7700
# Epoch 190/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 3.1582 - val_accuracy: 0.7743
# Epoch 191/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0028 - accuracy: 0.9982 - val_loss: 3.4959 - val_accuracy: 0.7679
# Epoch 192/200
# 35/35 [==============================] - 1s 26ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 3.4237 - val_accuracy: 0.7700
# Epoch 193/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 3.3357 - val_accuracy: 0.7700
# Epoch 194/200
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 3.3453 - val_accuracy: 0.7764
# Epoch 195/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0042 - accuracy: 0.9964 - val_loss: 3.7174 - val_accuracy: 0.7700
# Epoch 196/200
# 35/35 [==============================] - 1s 29ms/step - loss: 0.0156 - accuracy: 0.9964 - val_loss: 3.1071 - val_accuracy: 0.7511
# Epoch 197/200
# 35/35 [==============================] - 1s 28ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 2.6474 - val_accuracy: 0.7658
# Epoch 198/200
# 35/35 [==============================] - 1s 27ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 2.8066 - val_accuracy: 0.7700
# Epoch 199/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 2.8643 - val_accuracy: 0.7827
# Epoch 200/200
# 35/35 [==============================] - 1s 25ms/step - loss: 0.0057 - accuracy: 0.9973 - val_loss: 2.8855 - val_accuracy: 0.7764
# 15/15 [==============================] - 0s 9ms/step - loss: 2.8855 - accuracy: 0.7764
# Test Accuracy: 77.64%

# %%
num_images_to_display = 10
selected_indices = np.random.choice(len(X_test), num_images_to_display, replace=False)
class_names = ['Benign', 'Malignant', 'Normal']
# Create a subplot grid
num_rows = 2
num_cols = num_images_to_display // num_rows
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display predictions for the selected test images
for i, index in enumerate(selected_indices):
    # Get the test image and true label
    test_image = X_test[index]
    true_label = np.argmax(y_test[index])

    # Preprocess the image
    img_array = np.expand_dims(test_image, axis=0)

    # Make predictions
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)

    # Display the image
    ax = axes[i]
    ax.imshow(test_image.reshape((150, 150)), cmap='gray')
    ax.set_title(f'True: {class_names[true_label]}, Predicted: {class_names[predicted_class]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
plt.savefig('/content/drive/MyDrive/Dataset BUSI with GT/prediction.png')
# Out:
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model


# Save the trained model
model.save('/content/drive/MyDrive/Dataset BUSI with GT/modelcnn.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
loaded_model = load_model('/content/drive/MyDrive/Dataset BUSI with GT/modelcnn.h5')

# Evaluate the model on the test set
y_pred = loaded_model.predict(X_test)

# Convert one-hot encoded labels back to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Plot confusion matrix with seaborn
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant', 'Normal'], yticklabels=['Benign', 'Malignant', 'Normal'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot classification report
class_report = classification_report(y_true_classes, y_pred_classes, target_names=['Benign', 'Malignant', 'Normal'])
print('Classification Report:\n', class_report)
# Out:
# 15/15 [==============================] - 0s 10ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.79      0.88      0.83       268
#    Malignant       0.70      0.59      0.64       126
#       Normal       0.84      0.74      0.79        80
#
#     accuracy                           0.78       474
#    macro avg       0.78      0.73      0.75       474
# weighted avg       0.77      0.78      0.77       474

# %%
# Visualize input-to-output
for i in range(5):  # You can adjust the range based on the number of samples you want to visualize
    input_image = X_test[i].reshape((150, 150))  # Assuming your input shape is (150, 150, 1)
    output_probabilities = y_pred[i]
    predicted_class = np.argmax(output_probabilities)

    plt.figure(figsize=(8, 4))

    # Plot input image
    plt.subplot(1, 2, 1)
    plt.imshow(input_image, cmap='gray')
    plt.title('Input Image')

    # Plot output probabilities
    plt.subplot(1, 2, 2)
    plt.bar(range(len(output_probabilities)), output_probabilities)
    plt.xticks(range(len(output_probabilities)), ['Benign', 'Malignant', 'Normal'])
    plt.title('Output Probabilities')

    plt.show()
