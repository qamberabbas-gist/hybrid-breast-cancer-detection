# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
import os

# Define the path to the dataset directory
dataset_path = "/content/drive/MyDrive/Dataset BUSI with GT"

# Get the list of image files
image_files = []
labels = []

# Iterate over the directories
for class_name in ['benign', 'malignant', 'normal']:
    class_path = os.path.join(dataset_path, class_name)
    for filename in os.listdir(class_path):
        image_path = os.path.join(class_path, filename)
        image_files.append(image_path)
        labels.append(class_name)

# Convert labels to numerical values
from tensorflow.keras.utils import to_categorical

# Convert labels to numerical values
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
# Get the original class labels from the label encoder
original_labels = label_encoder.classes_

# Convert labels to one-hot encoded format
labels = to_categorical(labels)


# Print the mapping between numerical values and original labels
for numerical_value, original_label in enumerate(original_labels):
    print(f"Numerical Value: {numerical_value}, Original Label: {original_label}")
# Out:
# Numerical Value: 0, Original Label: benign
# Numerical Value: 1, Original Label: malignant
# Numerical Value: 2, Original Label: normal

# %% [markdown]
# ### **CNN**

# %%
X_train, X_test, y_train, y_test = train_test_split(image_files, labels, test_size=0.3, random_state=42, stratify=labels)

# %%
# Define a function to load and preprocess the images
def load_preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((150, 150))
#this converts the image to BW
    image = image.convert('L')
    image = np.array(image)
    image = image.reshape((150, 150, 1))
#image normalization
    image = image.astype('float32') / 255.0
    return image

X_train = [str(image_path) for image_path in X_train]
X_test = [str(image_path) for image_path in X_test]

# Load and preprocess the training images and labels
X_train = [load_preprocess_image(image_path) for image_path in X_train]
X_train = np.array(X_train)
y_train= np.array(y_train)

# Load and preprocess the testing images and labels
X_test= [load_preprocess_image(image_path) for image_path in X_test]
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
#Check size and color channels of images and labels
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)

#Show images
images = X_test[:10]  # Assuming X_test contains the image data
labels = y_test[:10]  # Assuming y_test contains the corresponding labels

# Convert them to class indices
class_indices = np.argmax(labels, axis=1)

# Define class labels
class_labels = ['Benign', 'Malignant', 'Normal']

num_rows = 2
num_cols = len(images) // num_rows

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display images with labels in the subplots
for i in range(len(images)):
    ax = axes[i]
    ax.imshow(images[i], cmap='gray')  # Assuming images are 2D arrays (grayscale)
    ax.set_title(f'True Label: {class_labels[class_indices[i]]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# (1104, 150, 150, 1) (1104, 3)
# (474, 150, 150, 1) (474, 3)

# %%
# Load DenseNet121 model without the top (fully connected) layers
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
# Create a Sequential model
model = Sequential()

# Add a custom convolutional layer to handle grayscale input
model.add(Conv2D(3, (3, 3), activation='relu', input_shape=(150, 150, 1), padding='same'))  # Adjust input_shape to (150, 150, 1)

# Add the DenseNet121 base (excluding top layers)
model.add(base_model)

# Freeze the pre-trained layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers on top of DenseNet121
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes (benign, malignant, normal)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model and collect the history
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))


# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 35/35 [==============================] - 32s 482ms/step - loss: 1.6554 - accuracy: 0.6775 - val_loss: 0.4036 - val_accuracy: 0.8101
# Epoch 2/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.4172 - accuracy: 0.7953 - val_loss: 0.3854 - val_accuracy: 0.8333
# Epoch 3/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.3555 - accuracy: 0.8433 - val_loss: 0.3557 - val_accuracy: 0.8397
# Epoch 4/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.3503 - accuracy: 0.8505 - val_loss: 0.3337 - val_accuracy: 0.8439
# Epoch 5/200
# 35/35 [==============================] - 6s 177ms/step - loss: 0.2999 - accuracy: 0.8714 - val_loss: 0.2950 - val_accuracy: 0.8755
# Epoch 6/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.2821 - accuracy: 0.8759 - val_loss: 0.3082 - val_accuracy: 0.8776
# Epoch 7/200
# 35/35 [==============================] - 6s 177ms/step - loss: 0.2942 - accuracy: 0.8813 - val_loss: 0.3207 - val_accuracy: 0.8650
# Epoch 8/200
# 35/35 [==============================] - 6s 158ms/step - loss: 0.2442 - accuracy: 0.8922 - val_loss: 0.2835 - val_accuracy: 0.8861
# Epoch 9/200
# 35/35 [==============================] - 5s 158ms/step - loss: 0.2124 - accuracy: 0.9176 - val_loss: 0.2579 - val_accuracy: 0.8987
# Epoch 10/200
# 35/35 [==============================] - 7s 190ms/step - loss: 0.1711 - accuracy: 0.9284 - val_loss: 0.2757 - val_accuracy: 0.8861
# Epoch 11/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.1690 - accuracy: 0.9248 - val_loss: 0.2826 - val_accuracy: 0.8861
# Epoch 12/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.1802 - accuracy: 0.9303 - val_loss: 0.2742 - val_accuracy: 0.8966
# Epoch 13/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.1382 - accuracy: 0.9438 - val_loss: 0.2778 - val_accuracy: 0.8987
# Epoch 14/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.1478 - accuracy: 0.9447 - val_loss: 0.3498 - val_accuracy: 0.8797
# Epoch 15/200
# 35/35 [==============================] - 6s 159ms/step - loss: 0.1480 - accuracy: 0.9357 - val_loss: 0.2739 - val_accuracy: 0.9008
# Epoch 16/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.1500 - accuracy: 0.9330 - val_loss: 0.3494 - val_accuracy: 0.8840
# Epoch 17/200
# 35/35 [==============================] - 5s 158ms/step - loss: 0.1283 - accuracy: 0.9520 - val_loss: 0.3515 - val_accuracy: 0.8987
# Epoch 18/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.1039 - accuracy: 0.9647 - val_loss: 0.3588 - val_accuracy: 0.8966
# Epoch 19/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.1208 - accuracy: 0.9484 - val_loss: 0.3166 - val_accuracy: 0.8882
# Epoch 20/200
# 35/35 [==============================] - 6s 159ms/step - loss: 0.1050 - accuracy: 0.9556 - val_loss: 0.3381 - val_accuracy: 0.8903
# Epoch 21/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0793 - accuracy: 0.9683 - val_loss: 0.3647 - val_accuracy: 0.8987
# Epoch 22/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0851 - accuracy: 0.9674 - val_loss: 0.3087 - val_accuracy: 0.9051
# Epoch 23/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0814 - accuracy: 0.9656 - val_loss: 0.3494 - val_accuracy: 0.9030
# Epoch 24/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.1169 - accuracy: 0.9556 - val_loss: 0.3109 - val_accuracy: 0.9051
# Epoch 25/200
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0859 - accuracy: 0.9656 - val_loss: 0.3283 - val_accuracy: 0.8987
# Epoch 26/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.1009 - accuracy: 0.9629 - val_loss: 0.3314 - val_accuracy: 0.8987
# Epoch 27/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0743 - accuracy: 0.9692 - val_loss: 0.3289 - val_accuracy: 0.9072
# Epoch 28/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0856 - accuracy: 0.9683 - val_loss: 0.3453 - val_accuracy: 0.9114
# Epoch 29/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0799 - accuracy: 0.9665 - val_loss: 0.3500 - val_accuracy: 0.9030
# Epoch 30/200
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0599 - accuracy: 0.9774 - val_loss: 0.4170 - val_accuracy: 0.8987
# Epoch 31/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0704 - accuracy: 0.9710 - val_loss: 0.3374 - val_accuracy: 0.9114
# Epoch 32/200
# 35/35 [==============================] - 6s 158ms/step - loss: 0.0724 - accuracy: 0.9737 - val_loss: 0.3913 - val_accuracy: 0.9093
# Epoch 33/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0536 - accuracy: 0.9755 - val_loss: 0.4262 - val_accuracy: 0.9030
# Epoch 34/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0665 - accuracy: 0.9746 - val_loss: 0.4430 - val_accuracy: 0.8987
# Epoch 35/200
# 35/35 [==============================] - 6s 160ms/step - loss: 0.0818 - accuracy: 0.9638 - val_loss: 0.3652 - val_accuracy: 0.9008
# Epoch 36/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0819 - accuracy: 0.9565 - val_loss: 0.3991 - val_accuracy: 0.8966
# Epoch 37/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0908 - accuracy: 0.9629 - val_loss: 0.4325 - val_accuracy: 0.8966
# Epoch 38/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0578 - accuracy: 0.9801 - val_loss: 0.3513 - val_accuracy: 0.9072
# Epoch 39/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0747 - accuracy: 0.9629 - val_loss: 0.3612 - val_accuracy: 0.8987
# Epoch 40/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0686 - accuracy: 0.9701 - val_loss: 0.3940 - val_accuracy: 0.8966
# Epoch 41/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0720 - accuracy: 0.9692 - val_loss: 0.3809 - val_accuracy: 0.9093
# Epoch 42/200
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0822 - accuracy: 0.9674 - val_loss: 0.3372 - val_accuracy: 0.9008
# Epoch 43/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0970 - accuracy: 0.9574 - val_loss: 0.4903 - val_accuracy: 0.8797
# Epoch 44/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0885 - accuracy: 0.9638 - val_loss: 0.3405 - val_accuracy: 0.8987
# Epoch 45/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0716 - accuracy: 0.9746 - val_loss: 0.4700 - val_accuracy: 0.9051
# Epoch 46/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0563 - accuracy: 0.9737 - val_loss: 0.3842 - val_accuracy: 0.9051
# Epoch 47/200
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0628 - accuracy: 0.9746 - val_loss: 0.3912 - val_accuracy: 0.9093
# Epoch 48/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0489 - accuracy: 0.9783 - val_loss: 0.4148 - val_accuracy: 0.9030
# Epoch 49/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0610 - accuracy: 0.9746 - val_loss: 0.4389 - val_accuracy: 0.9008
# Epoch 50/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0601 - accuracy: 0.9764 - val_loss: 0.4502 - val_accuracy: 0.9051
# Epoch 51/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0549 - accuracy: 0.9764 - val_loss: 0.4501 - val_accuracy: 0.9072
# Epoch 52/200
# 35/35 [==============================] - 6s 160ms/step - loss: 0.0714 - accuracy: 0.9656 - val_loss: 0.4214 - val_accuracy: 0.9051
# Epoch 53/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0822 - accuracy: 0.9674 - val_loss: 0.4443 - val_accuracy: 0.9008
# Epoch 54/200
# 35/35 [==============================] - 6s 158ms/step - loss: 0.0753 - accuracy: 0.9683 - val_loss: 0.3974 - val_accuracy: 0.9072
# Epoch 55/200
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0760 - accuracy: 0.9728 - val_loss: 0.5442 - val_accuracy: 0.9008
# Epoch 56/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0949 - accuracy: 0.9647 - val_loss: 0.4063 - val_accuracy: 0.9008
# Epoch 57/200
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0685 - accuracy: 0.9692 - val_loss: 0.4808 - val_accuracy: 0.9072
# Epoch 58/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0641 - accuracy: 0.9710 - val_loss: 0.4630 - val_accuracy: 0.9030
# Epoch 59/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0631 - accuracy: 0.9665 - val_loss: 0.3923 - val_accuracy: 0.9072
# Epoch 60/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0626 - accuracy: 0.9701 - val_loss: 0.4767 - val_accuracy: 0.8987
# Epoch 61/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0861 - accuracy: 0.9764 - val_loss: 0.5625 - val_accuracy: 0.9051
# Epoch 62/200
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0663 - accuracy: 0.9719 - val_loss: 0.5244 - val_accuracy: 0.9072
# Epoch 63/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0760 - accuracy: 0.9737 - val_loss: 0.5215 - val_accuracy: 0.8945
# Epoch 64/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0895 - accuracy: 0.9701 - val_loss: 0.5024 - val_accuracy: 0.9030
# Epoch 65/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0959 - accuracy: 0.9737 - val_loss: 0.5802 - val_accuracy: 0.9093
# Epoch 66/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0646 - accuracy: 0.9710 - val_loss: 0.5146 - val_accuracy: 0.9030
# Epoch 67/200
# 35/35 [==============================] - 6s 158ms/step - loss: 0.0815 - accuracy: 0.9629 - val_loss: 0.5464 - val_accuracy: 0.8945
# Epoch 68/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0615 - accuracy: 0.9746 - val_loss: 0.4740 - val_accuracy: 0.9051
# Epoch 69/200
# 35/35 [==============================] - 6s 160ms/step - loss: 0.0713 - accuracy: 0.9701 - val_loss: 0.5567 - val_accuracy: 0.9008
# Epoch 70/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0784 - accuracy: 0.9647 - val_loss: 0.4529 - val_accuracy: 0.9093
# Epoch 71/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0677 - accuracy: 0.9656 - val_loss: 0.4863 - val_accuracy: 0.8966
# Epoch 72/200
# 35/35 [==============================] - 6s 158ms/step - loss: 0.0599 - accuracy: 0.9683 - val_loss: 0.4797 - val_accuracy: 0.9135
# Epoch 73/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0584 - accuracy: 0.9728 - val_loss: 0.4052 - val_accuracy: 0.9093
# Epoch 74/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0808 - accuracy: 0.9656 - val_loss: 0.4554 - val_accuracy: 0.8966
# Epoch 75/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0672 - accuracy: 0.9674 - val_loss: 0.3981 - val_accuracy: 0.8903
# Epoch 76/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0559 - accuracy: 0.9701 - val_loss: 0.5980 - val_accuracy: 0.8903
# Epoch 77/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0524 - accuracy: 0.9783 - val_loss: 0.5304 - val_accuracy: 0.8882
# Epoch 78/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0610 - accuracy: 0.9728 - val_loss: 0.5447 - val_accuracy: 0.9008
# Epoch 79/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0376 - accuracy: 0.9864 - val_loss: 0.6792 - val_accuracy: 0.9030
# Epoch 80/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0603 - accuracy: 0.9728 - val_loss: 0.6121 - val_accuracy: 0.9072
# Epoch 81/200
# 35/35 [==============================] - 5s 158ms/step - loss: 0.0391 - accuracy: 0.9873 - val_loss: 0.6732 - val_accuracy: 0.8903
# Epoch 82/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0553 - accuracy: 0.9692 - val_loss: 0.5712 - val_accuracy: 0.9030
# Epoch 83/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0555 - accuracy: 0.9719 - val_loss: 0.5545 - val_accuracy: 0.8945
# Epoch 84/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0648 - accuracy: 0.9710 - val_loss: 0.5684 - val_accuracy: 0.8987
# Epoch 85/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0668 - accuracy: 0.9728 - val_loss: 0.5076 - val_accuracy: 0.9093
# Epoch 86/200
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0634 - accuracy: 0.9665 - val_loss: 0.5149 - val_accuracy: 0.9072
# Epoch 87/200
# 35/35 [==============================] - 6s 158ms/step - loss: 0.0502 - accuracy: 0.9828 - val_loss: 0.4339 - val_accuracy: 0.9135
# Epoch 88/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0473 - accuracy: 0.9792 - val_loss: 0.6126 - val_accuracy: 0.9072
# Epoch 89/200
# 35/35 [==============================] - 6s 161ms/step - loss: 0.0501 - accuracy: 0.9810 - val_loss: 0.6516 - val_accuracy: 0.9051
# Epoch 90/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0381 - accuracy: 0.9810 - val_loss: 0.6035 - val_accuracy: 0.9072
# Epoch 91/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0487 - accuracy: 0.9755 - val_loss: 0.4781 - val_accuracy: 0.9114
# Epoch 92/200
# 35/35 [==============================] - 6s 158ms/step - loss: 0.0502 - accuracy: 0.9828 - val_loss: 0.6328 - val_accuracy: 0.9093
# Epoch 93/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0527 - accuracy: 0.9719 - val_loss: 0.5671 - val_accuracy: 0.8987
# Epoch 94/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0420 - accuracy: 0.9846 - val_loss: 0.8121 - val_accuracy: 0.8945
# Epoch 95/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0609 - accuracy: 0.9755 - val_loss: 0.5491 - val_accuracy: 0.9051
# Epoch 96/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0431 - accuracy: 0.9828 - val_loss: 0.7749 - val_accuracy: 0.8987
# Epoch 97/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0808 - accuracy: 0.9701 - val_loss: 0.5085 - val_accuracy: 0.9072
# Epoch 98/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0916 - accuracy: 0.9547 - val_loss: 0.5561 - val_accuracy: 0.9030
# Epoch 99/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0524 - accuracy: 0.9737 - val_loss: 0.5408 - val_accuracy: 0.9135
# Epoch 100/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0588 - accuracy: 0.9746 - val_loss: 0.6033 - val_accuracy: 0.9093
# Epoch 101/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0642 - accuracy: 0.9692 - val_loss: 0.5337 - val_accuracy: 0.9051
# Epoch 102/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0476 - accuracy: 0.9755 - val_loss: 0.7035 - val_accuracy: 0.9030
# Epoch 103/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0659 - accuracy: 0.9719 - val_loss: 0.5522 - val_accuracy: 0.8945
# Epoch 104/200
# 35/35 [==============================] - 5s 158ms/step - loss: 0.0581 - accuracy: 0.9746 - val_loss: 0.7169 - val_accuracy: 0.9008
# Epoch 105/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0480 - accuracy: 0.9755 - val_loss: 0.6453 - val_accuracy: 0.9030
# Epoch 106/200
# 35/35 [==============================] - 6s 160ms/step - loss: 0.0471 - accuracy: 0.9828 - val_loss: 0.8632 - val_accuracy: 0.8924
# Epoch 107/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0627 - accuracy: 0.9701 - val_loss: 0.4881 - val_accuracy: 0.9114
# Epoch 108/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0540 - accuracy: 0.9728 - val_loss: 0.4943 - val_accuracy: 0.9008
# Epoch 109/200
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0550 - accuracy: 0.9746 - val_loss: 0.5885 - val_accuracy: 0.9135
# Epoch 110/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0550 - accuracy: 0.9737 - val_loss: 0.6503 - val_accuracy: 0.9114
# Epoch 111/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0341 - accuracy: 0.9846 - val_loss: 0.7506 - val_accuracy: 0.9072
# Epoch 112/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0543 - accuracy: 0.9801 - val_loss: 0.7571 - val_accuracy: 0.9072
# Epoch 113/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0522 - accuracy: 0.9755 - val_loss: 0.5565 - val_accuracy: 0.9093
# Epoch 114/200
# 35/35 [==============================] - 6s 158ms/step - loss: 0.0481 - accuracy: 0.9828 - val_loss: 0.7109 - val_accuracy: 0.9093
# Epoch 115/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0413 - accuracy: 0.9846 - val_loss: 0.6581 - val_accuracy: 0.9051
# Epoch 116/200
# 35/35 [==============================] - 6s 158ms/step - loss: 0.0483 - accuracy: 0.9746 - val_loss: 0.6510 - val_accuracy: 0.9051
# Epoch 117/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0532 - accuracy: 0.9737 - val_loss: 0.6430 - val_accuracy: 0.9177
# Epoch 118/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0567 - accuracy: 0.9746 - val_loss: 0.6425 - val_accuracy: 0.9135
# Epoch 119/200
# 35/35 [==============================] - 6s 160ms/step - loss: 0.0496 - accuracy: 0.9737 - val_loss: 0.4877 - val_accuracy: 0.9135
# Epoch 120/200
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0735 - accuracy: 0.9629 - val_loss: 0.6175 - val_accuracy: 0.9008
# Epoch 121/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0736 - accuracy: 0.9647 - val_loss: 0.7420 - val_accuracy: 0.8861
# Epoch 122/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0870 - accuracy: 0.9574 - val_loss: 0.5233 - val_accuracy: 0.8987
# Epoch 123/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0630 - accuracy: 0.9692 - val_loss: 0.5298 - val_accuracy: 0.9008
# Epoch 124/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0660 - accuracy: 0.9665 - val_loss: 0.6034 - val_accuracy: 0.9072
# Epoch 125/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0871 - accuracy: 0.9620 - val_loss: 0.6882 - val_accuracy: 0.8945
# Epoch 126/200
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0612 - accuracy: 0.9719 - val_loss: 0.5431 - val_accuracy: 0.9030
# Epoch 127/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0648 - accuracy: 0.9665 - val_loss: 0.4875 - val_accuracy: 0.8903
# Epoch 128/200
# 35/35 [==============================] - 5s 158ms/step - loss: 0.0557 - accuracy: 0.9647 - val_loss: 0.8394 - val_accuracy: 0.8945
# Epoch 129/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0625 - accuracy: 0.9665 - val_loss: 0.5811 - val_accuracy: 0.9008
# Epoch 130/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0774 - accuracy: 0.9611 - val_loss: 0.4544 - val_accuracy: 0.9072
# Epoch 131/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0521 - accuracy: 0.9710 - val_loss: 0.5731 - val_accuracy: 0.8987
# Epoch 132/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0495 - accuracy: 0.9764 - val_loss: 0.6691 - val_accuracy: 0.9030
# Epoch 133/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0484 - accuracy: 0.9755 - val_loss: 0.5983 - val_accuracy: 0.9008
# Epoch 134/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0541 - accuracy: 0.9710 - val_loss: 0.5192 - val_accuracy: 0.9114
# Epoch 135/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0533 - accuracy: 0.9710 - val_loss: 0.5250 - val_accuracy: 0.9114
# Epoch 136/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0560 - accuracy: 0.9774 - val_loss: 0.4830 - val_accuracy: 0.9072
# Epoch 137/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0433 - accuracy: 0.9837 - val_loss: 0.8257 - val_accuracy: 0.8924
# Epoch 138/200
# 35/35 [==============================] - 6s 161ms/step - loss: 0.0463 - accuracy: 0.9801 - val_loss: 0.6515 - val_accuracy: 0.9135
# Epoch 139/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0555 - accuracy: 0.9783 - val_loss: 0.6018 - val_accuracy: 0.9030
# Epoch 140/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0640 - accuracy: 0.9792 - val_loss: 0.6325 - val_accuracy: 0.9093
# Epoch 141/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0503 - accuracy: 0.9764 - val_loss: 0.5235 - val_accuracy: 0.9093
# Epoch 142/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0490 - accuracy: 0.9746 - val_loss: 0.6281 - val_accuracy: 0.9072
# Epoch 143/200
# 35/35 [==============================] - 6s 160ms/step - loss: 0.0367 - accuracy: 0.9792 - val_loss: 0.7705 - val_accuracy: 0.8945
# Epoch 144/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0299 - accuracy: 0.9846 - val_loss: 0.9000 - val_accuracy: 0.9051
# Epoch 145/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0525 - accuracy: 0.9755 - val_loss: 0.6959 - val_accuracy: 0.9030
# Epoch 146/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0552 - accuracy: 0.9755 - val_loss: 0.8606 - val_accuracy: 0.8945
# Epoch 147/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0656 - accuracy: 0.9755 - val_loss: 0.7140 - val_accuracy: 0.9051
# Epoch 148/200
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0505 - accuracy: 0.9774 - val_loss: 0.6832 - val_accuracy: 0.8966
# Epoch 149/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0491 - accuracy: 0.9737 - val_loss: 0.7244 - val_accuracy: 0.8966
# Epoch 150/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0469 - accuracy: 0.9774 - val_loss: 0.7087 - val_accuracy: 0.8903
# Epoch 151/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0536 - accuracy: 0.9783 - val_loss: 0.5939 - val_accuracy: 0.9114
# Epoch 152/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0517 - accuracy: 0.9710 - val_loss: 0.7448 - val_accuracy: 0.8924
# Epoch 153/200
# 35/35 [==============================] - 6s 160ms/step - loss: 0.0600 - accuracy: 0.9719 - val_loss: 0.5838 - val_accuracy: 0.9114
# Epoch 154/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0551 - accuracy: 0.9701 - val_loss: 0.6932 - val_accuracy: 0.8882
# Epoch 155/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0503 - accuracy: 0.9737 - val_loss: 0.6141 - val_accuracy: 0.9093
# Epoch 156/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0587 - accuracy: 0.9755 - val_loss: 0.6609 - val_accuracy: 0.9051
# Epoch 157/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0474 - accuracy: 0.9737 - val_loss: 0.5758 - val_accuracy: 0.9030
# Epoch 158/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0494 - accuracy: 0.9801 - val_loss: 0.8353 - val_accuracy: 0.9008
# Epoch 159/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0558 - accuracy: 0.9792 - val_loss: 0.5939 - val_accuracy: 0.8966
# Epoch 160/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0716 - accuracy: 0.9801 - val_loss: 0.6053 - val_accuracy: 0.9030
# Epoch 161/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0746 - accuracy: 0.9728 - val_loss: 0.6104 - val_accuracy: 0.8966
# Epoch 162/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0798 - accuracy: 0.9701 - val_loss: 0.5390 - val_accuracy: 0.8987
# Epoch 163/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0624 - accuracy: 0.9719 - val_loss: 0.7695 - val_accuracy: 0.9030
# Epoch 164/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0699 - accuracy: 0.9674 - val_loss: 0.7008 - val_accuracy: 0.8945
# Epoch 165/200
# 35/35 [==============================] - 5s 158ms/step - loss: 0.0555 - accuracy: 0.9755 - val_loss: 0.7876 - val_accuracy: 0.8966
# Epoch 166/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0376 - accuracy: 0.9837 - val_loss: 0.7250 - val_accuracy: 0.8966
# Epoch 167/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0554 - accuracy: 0.9819 - val_loss: 0.7350 - val_accuracy: 0.9008
# Epoch 168/200
# 35/35 [==============================] - 6s 161ms/step - loss: 0.0426 - accuracy: 0.9837 - val_loss: 0.7484 - val_accuracy: 0.9030
# Epoch 169/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0440 - accuracy: 0.9801 - val_loss: 0.6977 - val_accuracy: 0.9030
# Epoch 170/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0627 - accuracy: 0.9774 - val_loss: 0.7375 - val_accuracy: 0.9030
# Epoch 171/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0649 - accuracy: 0.9801 - val_loss: 0.6630 - val_accuracy: 0.9008
# Epoch 172/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0572 - accuracy: 0.9801 - val_loss: 0.7806 - val_accuracy: 0.9008
# Epoch 173/200
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0652 - accuracy: 0.9719 - val_loss: 0.7423 - val_accuracy: 0.9008
# Epoch 174/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0535 - accuracy: 0.9728 - val_loss: 0.7693 - val_accuracy: 0.9051
# Epoch 175/200
# 35/35 [==============================] - 5s 156ms/step - loss: 0.0644 - accuracy: 0.9710 - val_loss: 0.6196 - val_accuracy: 0.8987
# Epoch 176/200
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0860 - accuracy: 0.9719 - val_loss: 0.5860 - val_accuracy: 0.8945
# Epoch 177/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0566 - accuracy: 0.9728 - val_loss: 0.6792 - val_accuracy: 0.9072
# Epoch 178/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0468 - accuracy: 0.9792 - val_loss: 0.7566 - val_accuracy: 0.9072
# Epoch 179/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0504 - accuracy: 0.9783 - val_loss: 0.7400 - val_accuracy: 0.8966
# Epoch 180/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0363 - accuracy: 0.9837 - val_loss: 0.8275 - val_accuracy: 0.9030
# Epoch 181/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0818 - accuracy: 0.9710 - val_loss: 0.6528 - val_accuracy: 0.8987
# Epoch 182/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0721 - accuracy: 0.9692 - val_loss: 0.7845 - val_accuracy: 0.8966
# Epoch 183/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0579 - accuracy: 0.9819 - val_loss: 0.6784 - val_accuracy: 0.8966
# Epoch 184/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0427 - accuracy: 0.9801 - val_loss: 0.6604 - val_accuracy: 0.8987
# Epoch 185/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0566 - accuracy: 0.9755 - val_loss: 0.8278 - val_accuracy: 0.8882
# Epoch 186/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0468 - accuracy: 0.9846 - val_loss: 0.9233 - val_accuracy: 0.8882
# Epoch 187/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0888 - accuracy: 0.9764 - val_loss: 0.8864 - val_accuracy: 0.8903
# Epoch 188/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0412 - accuracy: 0.9837 - val_loss: 0.7644 - val_accuracy: 0.8966
# Epoch 189/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0457 - accuracy: 0.9792 - val_loss: 0.7000 - val_accuracy: 0.9093
# Epoch 190/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0529 - accuracy: 0.9792 - val_loss: 0.9237 - val_accuracy: 0.9072
# Epoch 191/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0410 - accuracy: 0.9819 - val_loss: 0.7611 - val_accuracy: 0.9093
# Epoch 192/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0361 - accuracy: 0.9828 - val_loss: 0.9236 - val_accuracy: 0.9072
# Epoch 193/200
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0391 - accuracy: 0.9810 - val_loss: 0.7256 - val_accuracy: 0.8966
# Epoch 194/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0321 - accuracy: 0.9846 - val_loss: 0.8674 - val_accuracy: 0.8987
# Epoch 195/200
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0381 - accuracy: 0.9828 - val_loss: 0.8461 - val_accuracy: 0.9030
# Epoch 196/200
# 35/35 [==============================] - 5s 155ms/step - loss: 0.0468 - accuracy: 0.9783 - val_loss: 0.8550 - val_accuracy: 0.9093
# Epoch 197/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0361 - accuracy: 0.9864 - val_loss: 0.8785 - val_accuracy: 0.9008
# Epoch 198/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.0321 - accuracy: 0.9882 - val_loss: 0.7161 - val_accuracy: 0.9093
# Epoch 199/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0300 - accuracy: 0.9882 - val_loss: 1.3203 - val_accuracy: 0.8945
# Epoch 200/200
# 35/35 [==============================] - 6s 161ms/step - loss: 0.0575 - accuracy: 0.9774 - val_loss: 0.7754 - val_accuracy: 0.8924
# 15/15 [==============================] - 1s 46ms/step - loss: 0.7754 - accuracy: 0.8924
# Test Accuracy: 89.24%

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 3)       30
#
#  densenet121 (Functional)    (None, 4, 4, 1024)        7037504
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 9135201 (34.85 MB)
# Trainable params: 2097697 (8.00 MB)
# Non-trainable params: 7037504 (26.85 MB)
# _________________________________________________________________

# %%
num_images_to_display = 10
selected_indices = np.random.choice(len(X_test), num_images_to_display, replace=False)
class_names = ['Benign', 'Malignant', 'Normal']
# Create a subplot grid
num_rows = 2
num_cols = num_images_to_display // num_rows
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display predictions for the selected test images
for i, index in enumerate(selected_indices):
    # Get the test image and true label
    test_image = X_test[index]
    true_label = np.argmax(y_test[index])

    # Preprocess the image
    img_array = np.expand_dims(test_image, axis=0)

    # Make predictions
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)

    # Display the image
    ax = axes[i]
    ax.imshow(test_image.reshape((150, 150)), cmap='gray')
    ax.set_title(f'True: {class_names[true_label]}, Predicted: {class_names[predicted_class]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
plt.savefig('/content/drive/MyDrive/Dataset BUSI with GT/prediction.png')
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model


# Save the trained model
model.save('/content/drive/MyDrive/Dataset BUSI with GT/modelDenseNet121.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
loaded_model = load_model('/content/drive/MyDrive/Dataset BUSI with GT/modelDenseNet121.h5')

# Evaluate the model on the test set
y_pred = loaded_model.predict(X_test)

# Convert one-hot encoded labels back to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Plot confusion matrix with seaborn
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant', 'Normal'], yticklabels=['Benign', 'Malignant', 'Normal'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot classification report
class_report = classification_report(y_true_classes, y_pred_classes, target_names=['Benign', 'Malignant', 'Normal'])
print('Classification Report:\n', class_report)
# Out:
# 15/15 [==============================] - 2s 50ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.88      0.96      0.92       268
#    Malignant       0.86      0.84      0.85       126
#       Normal       1.00      0.76      0.87        80
#
#     accuracy                           0.89       474
#    macro avg       0.91      0.85      0.88       474
# weighted avg       0.90      0.89      0.89       474

# %%
# Visualize input-to-output
for i in range(5):  # You can adjust the range based on the number of samples you want to visualize
    input_image = X_test[i].reshape((150, 150))  # Assuming your input shape is (150, 150, 1)
    output_probabilities = y_pred[i]
    predicted_class = np.argmax(output_probabilities)

    plt.figure(figsize=(8, 4))

    # Plot input image
    plt.subplot(1, 2, 1)
    plt.imshow(input_image, cmap='gray')
    plt.title('Input Image')

    # Plot output probabilities
    plt.subplot(1, 2, 2)
    plt.bar(range(len(output_probabilities)), output_probabilities)
    plt.xticks(range(len(output_probabilities)), ['Benign', 'Malignant', 'Normal'])
    plt.title('Output Probabilities')

    plt.show()
