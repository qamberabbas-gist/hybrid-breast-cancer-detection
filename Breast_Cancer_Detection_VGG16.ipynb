# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam

# %%
import os

# Define the path to the dataset directory
dataset_path = "/content/drive/MyDrive/Dataset BUSI with GT"

# Get the list of image files
image_files = []
labels = []

# Iterate over the directories
for class_name in ['benign', 'malignant', 'normal']:
    class_path = os.path.join(dataset_path, class_name)
    for filename in os.listdir(class_path):
        image_path = os.path.join(class_path, filename)
        image_files.append(image_path)
        labels.append(class_name)

# Convert labels to numerical values
from tensorflow.keras.utils import to_categorical

# Convert labels to numerical values
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(labels)
# Get the original class labels from the label encoder
original_labels = label_encoder.classes_

# Convert labels to one-hot encoded format
labels = to_categorical(labels)


# Print the mapping between numerical values and original labels
for numerical_value, original_label in enumerate(original_labels):
    print(f"Numerical Value: {numerical_value}, Original Label: {original_label}")
# Out:
# Numerical Value: 0, Original Label: benign
# Numerical Value: 1, Original Label: malignant
# Numerical Value: 2, Original Label: normal

# %% [markdown]
# ### **CNN**

# %%
X_train, X_test, y_train, y_test = train_test_split(image_files, labels, test_size=0.3, random_state=42, stratify=labels)

# %%
# Define a function to load and preprocess the images
def load_preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((150, 150))
#this converts the image to BW
    image = image.convert('L')
    image = np.array(image)
    image = image.reshape((150, 150, 1))
#image normalization
    image = image.astype('float32') / 255.0
    return image

X_train = [str(image_path) for image_path in X_train]
X_test = [str(image_path) for image_path in X_test]

# Load and preprocess the training images and labels
X_train = [load_preprocess_image(image_path) for image_path in X_train]
X_train = np.array(X_train)
y_train= np.array(y_train)

# Load and preprocess the testing images and labels
X_test= [load_preprocess_image(image_path) for image_path in X_test]
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
#Check size and color channels of images and labels
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)

#Show images
images = X_test[:10]  # Assuming X_test contains the image data
labels = y_test[:10]  # Assuming y_test contains the corresponding labels

# Convert them to class indices
class_indices = np.argmax(labels, axis=1)

# Define class labels
class_labels = ['Benign', 'Malignant', 'Normal']

num_rows = 2
num_cols = len(images) // num_rows

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display images with labels in the subplots
for i in range(len(images)):
    ax = axes[i]
    ax.imshow(images[i], cmap='gray')  # Assuming images are 2D arrays (grayscale)
    ax.set_title(f'True Label: {class_labels[class_indices[i]]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
# Out:
# (1104, 150, 150, 1) (1104, 3)
# (474, 150, 150, 1) (474, 3)

# %%
from keras.applications import VGG16
from keras.models import Sequential
from keras.layers import Conv2D, Flatten, Dense, Dropout

# Load the VGG16 base (excluding top layers)
vgg16_base = VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))

# Create a Sequential model
model = Sequential()

# Add a custom convolutional layer to handle grayscale input
model.add(Conv2D(3, (3, 3), activation='relu', input_shape=(150, 150, 1), padding='same'))  # Adjust input_shape to (150, 150, 1)

# Add the VGG16 base (excluding top layers)
model.add(vgg16_base)

# Freeze the VGG16 layers
for layer in vgg16_base.layers:
    layer.trainable = False

# Add custom layers on top of VGG16
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # 3 classes (benign, malignant, normal)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model and collect the history
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))


# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/200
# 35/35 [==============================] - 27s 430ms/step - loss: 0.9497 - accuracy: 0.6159 - val_loss: 0.6812 - val_accuracy: 0.7321
# Epoch 2/200
# 35/35 [==============================] - 6s 162ms/step - loss: 0.6374 - accuracy: 0.7346 - val_loss: 0.5923 - val_accuracy: 0.7511
# Epoch 3/200
# 35/35 [==============================] - 6s 162ms/step - loss: 0.5521 - accuracy: 0.7591 - val_loss: 0.4977 - val_accuracy: 0.7785
# Epoch 4/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.5050 - accuracy: 0.7908 - val_loss: 0.4402 - val_accuracy: 0.8312
# Epoch 5/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.4541 - accuracy: 0.7980 - val_loss: 0.4566 - val_accuracy: 0.8017
# Epoch 6/200
# 35/35 [==============================] - 6s 165ms/step - loss: 0.4461 - accuracy: 0.8143 - val_loss: 0.3773 - val_accuracy: 0.8523
# Epoch 7/200
# 35/35 [==============================] - 6s 176ms/step - loss: 0.3917 - accuracy: 0.8397 - val_loss: 0.3943 - val_accuracy: 0.8397
# Epoch 8/200
# 35/35 [==============================] - 6s 167ms/step - loss: 0.3696 - accuracy: 0.8514 - val_loss: 0.3662 - val_accuracy: 0.8544
# Epoch 9/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.3381 - accuracy: 0.8650 - val_loss: 0.3424 - val_accuracy: 0.8629
# Epoch 10/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.3202 - accuracy: 0.8723 - val_loss: 0.3327 - val_accuracy: 0.8671
# Epoch 11/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.3088 - accuracy: 0.8723 - val_loss: 0.3219 - val_accuracy: 0.8650
# Epoch 12/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.2678 - accuracy: 0.8995 - val_loss: 0.3313 - val_accuracy: 0.8586
# Epoch 13/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.2710 - accuracy: 0.8913 - val_loss: 0.3125 - val_accuracy: 0.8713
# Epoch 14/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.2606 - accuracy: 0.9004 - val_loss: 0.3060 - val_accuracy: 0.8692
# Epoch 15/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.2351 - accuracy: 0.9112 - val_loss: 0.3199 - val_accuracy: 0.8945
# Epoch 16/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.2359 - accuracy: 0.9121 - val_loss: 0.2868 - val_accuracy: 0.8819
# Epoch 17/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.2285 - accuracy: 0.9076 - val_loss: 0.2971 - val_accuracy: 0.8903
# Epoch 18/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.2044 - accuracy: 0.9194 - val_loss: 0.2864 - val_accuracy: 0.8903
# Epoch 19/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.1849 - accuracy: 0.9339 - val_loss: 0.3244 - val_accuracy: 0.8692
# Epoch 20/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.1817 - accuracy: 0.9275 - val_loss: 0.2952 - val_accuracy: 0.8797
# Epoch 21/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.1877 - accuracy: 0.9293 - val_loss: 0.2840 - val_accuracy: 0.8861
# Epoch 22/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.1668 - accuracy: 0.9330 - val_loss: 0.3060 - val_accuracy: 0.8882
# Epoch 23/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.1646 - accuracy: 0.9348 - val_loss: 0.3139 - val_accuracy: 0.8819
# Epoch 24/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.1381 - accuracy: 0.9475 - val_loss: 0.2907 - val_accuracy: 0.8924
# Epoch 25/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.1312 - accuracy: 0.9475 - val_loss: 0.2814 - val_accuracy: 0.8924
# Epoch 26/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.1481 - accuracy: 0.9447 - val_loss: 0.2844 - val_accuracy: 0.8903
# Epoch 27/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.1604 - accuracy: 0.9303 - val_loss: 0.2683 - val_accuracy: 0.8966
# Epoch 28/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.1334 - accuracy: 0.9529 - val_loss: 0.2641 - val_accuracy: 0.9030
# Epoch 29/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.1364 - accuracy: 0.9484 - val_loss: 0.2573 - val_accuracy: 0.8966
# Epoch 30/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.1112 - accuracy: 0.9547 - val_loss: 0.3095 - val_accuracy: 0.8882
# Epoch 31/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.1114 - accuracy: 0.9565 - val_loss: 0.2799 - val_accuracy: 0.8966
# Epoch 32/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.1046 - accuracy: 0.9611 - val_loss: 0.3026 - val_accuracy: 0.8945
# Epoch 33/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0874 - accuracy: 0.9647 - val_loss: 0.2884 - val_accuracy: 0.8945
# Epoch 34/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0934 - accuracy: 0.9701 - val_loss: 0.3248 - val_accuracy: 0.8903
# Epoch 35/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.1002 - accuracy: 0.9611 - val_loss: 0.3004 - val_accuracy: 0.8903
# Epoch 36/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0910 - accuracy: 0.9683 - val_loss: 0.3024 - val_accuracy: 0.8987
# Epoch 37/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.0980 - accuracy: 0.9674 - val_loss: 0.2935 - val_accuracy: 0.8903
# Epoch 38/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0882 - accuracy: 0.9683 - val_loss: 0.2981 - val_accuracy: 0.9072
# Epoch 39/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0838 - accuracy: 0.9665 - val_loss: 0.3653 - val_accuracy: 0.8861
# Epoch 40/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0925 - accuracy: 0.9601 - val_loss: 0.2941 - val_accuracy: 0.9051
# Epoch 41/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0907 - accuracy: 0.9674 - val_loss: 0.2866 - val_accuracy: 0.9008
# Epoch 42/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0705 - accuracy: 0.9710 - val_loss: 0.3106 - val_accuracy: 0.9072
# Epoch 43/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0781 - accuracy: 0.9746 - val_loss: 0.3692 - val_accuracy: 0.8987
# Epoch 44/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0743 - accuracy: 0.9774 - val_loss: 0.3781 - val_accuracy: 0.8945
# Epoch 45/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0740 - accuracy: 0.9746 - val_loss: 0.3290 - val_accuracy: 0.8966
# Epoch 46/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0786 - accuracy: 0.9683 - val_loss: 0.3474 - val_accuracy: 0.8987
# Epoch 47/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0761 - accuracy: 0.9692 - val_loss: 0.3090 - val_accuracy: 0.8966
# Epoch 48/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0794 - accuracy: 0.9710 - val_loss: 0.3511 - val_accuracy: 0.8924
# Epoch 49/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0744 - accuracy: 0.9728 - val_loss: 0.3507 - val_accuracy: 0.8966
# Epoch 50/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0675 - accuracy: 0.9701 - val_loss: 0.3888 - val_accuracy: 0.8966
# Epoch 51/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0697 - accuracy: 0.9755 - val_loss: 0.2905 - val_accuracy: 0.8924
# Epoch 52/200
# 35/35 [==============================] - 6s 169ms/step - loss: 0.0631 - accuracy: 0.9746 - val_loss: 0.3946 - val_accuracy: 0.8966
# Epoch 53/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0505 - accuracy: 0.9828 - val_loss: 0.3631 - val_accuracy: 0.8882
# Epoch 54/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0575 - accuracy: 0.9801 - val_loss: 0.3682 - val_accuracy: 0.8987
# Epoch 55/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0716 - accuracy: 0.9728 - val_loss: 0.3301 - val_accuracy: 0.8987
# Epoch 56/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0718 - accuracy: 0.9710 - val_loss: 0.3145 - val_accuracy: 0.9030
# Epoch 57/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0685 - accuracy: 0.9774 - val_loss: 0.3493 - val_accuracy: 0.8945
# Epoch 58/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0596 - accuracy: 0.9783 - val_loss: 0.3790 - val_accuracy: 0.8903
# Epoch 59/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0549 - accuracy: 0.9828 - val_loss: 0.4994 - val_accuracy: 0.8882
# Epoch 60/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0558 - accuracy: 0.9837 - val_loss: 0.4307 - val_accuracy: 0.8924
# Epoch 61/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0665 - accuracy: 0.9746 - val_loss: 0.3885 - val_accuracy: 0.8945
# Epoch 62/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0538 - accuracy: 0.9828 - val_loss: 0.4394 - val_accuracy: 0.8966
# Epoch 63/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0508 - accuracy: 0.9810 - val_loss: 0.4124 - val_accuracy: 0.8924
# Epoch 64/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0734 - accuracy: 0.9728 - val_loss: 0.5306 - val_accuracy: 0.8924
# Epoch 65/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0539 - accuracy: 0.9855 - val_loss: 0.4371 - val_accuracy: 0.9030
# Epoch 66/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0727 - accuracy: 0.9719 - val_loss: 0.3671 - val_accuracy: 0.9008
# Epoch 67/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0682 - accuracy: 0.9764 - val_loss: 0.4514 - val_accuracy: 0.8903
# Epoch 68/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0559 - accuracy: 0.9774 - val_loss: 0.4673 - val_accuracy: 0.8945
# Epoch 69/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0419 - accuracy: 0.9846 - val_loss: 0.4171 - val_accuracy: 0.8945
# Epoch 70/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0545 - accuracy: 0.9755 - val_loss: 0.4609 - val_accuracy: 0.8882
# Epoch 71/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0530 - accuracy: 0.9801 - val_loss: 0.4375 - val_accuracy: 0.8882
# Epoch 72/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0420 - accuracy: 0.9864 - val_loss: 0.5094 - val_accuracy: 0.8966
# Epoch 73/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0557 - accuracy: 0.9755 - val_loss: 0.4362 - val_accuracy: 0.8945
# Epoch 74/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0406 - accuracy: 0.9846 - val_loss: 0.4686 - val_accuracy: 0.8903
# Epoch 75/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0355 - accuracy: 0.9864 - val_loss: 0.4740 - val_accuracy: 0.8945
# Epoch 76/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0435 - accuracy: 0.9846 - val_loss: 0.4068 - val_accuracy: 0.8924
# Epoch 77/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0639 - accuracy: 0.9774 - val_loss: 0.4349 - val_accuracy: 0.9008
# Epoch 78/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0426 - accuracy: 0.9837 - val_loss: 0.4948 - val_accuracy: 0.8924
# Epoch 79/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0484 - accuracy: 0.9819 - val_loss: 0.5324 - val_accuracy: 0.8966
# Epoch 80/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0507 - accuracy: 0.9846 - val_loss: 0.4644 - val_accuracy: 0.8945
# Epoch 81/200
# 35/35 [==============================] - 6s 181ms/step - loss: 0.0561 - accuracy: 0.9783 - val_loss: 0.4871 - val_accuracy: 0.8882
# Epoch 82/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0453 - accuracy: 0.9828 - val_loss: 0.5524 - val_accuracy: 0.8966
# Epoch 83/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0424 - accuracy: 0.9864 - val_loss: 0.5869 - val_accuracy: 0.8861
# Epoch 84/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0356 - accuracy: 0.9882 - val_loss: 0.5476 - val_accuracy: 0.8903
# Epoch 85/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0378 - accuracy: 0.9846 - val_loss: 0.5735 - val_accuracy: 0.8861
# Epoch 86/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.6064 - val_accuracy: 0.8882
# Epoch 87/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0502 - accuracy: 0.9819 - val_loss: 0.5568 - val_accuracy: 0.8924
# Epoch 88/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0339 - accuracy: 0.9909 - val_loss: 0.5828 - val_accuracy: 0.8924
# Epoch 89/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0370 - accuracy: 0.9873 - val_loss: 0.5102 - val_accuracy: 0.8966
# Epoch 90/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0253 - accuracy: 0.9909 - val_loss: 0.5902 - val_accuracy: 0.8966
# Epoch 91/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0315 - accuracy: 0.9882 - val_loss: 0.6099 - val_accuracy: 0.8861
# Epoch 92/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0421 - accuracy: 0.9828 - val_loss: 0.5597 - val_accuracy: 0.8945
# Epoch 93/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0467 - accuracy: 0.9801 - val_loss: 0.5192 - val_accuracy: 0.8987
# Epoch 94/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0319 - accuracy: 0.9891 - val_loss: 0.5619 - val_accuracy: 0.9008
# Epoch 95/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0360 - accuracy: 0.9846 - val_loss: 0.5551 - val_accuracy: 0.8924
# Epoch 96/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0364 - accuracy: 0.9846 - val_loss: 0.5481 - val_accuracy: 0.8966
# Epoch 97/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0340 - accuracy: 0.9873 - val_loss: 0.5573 - val_accuracy: 0.8903
# Epoch 98/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0336 - accuracy: 0.9873 - val_loss: 0.5916 - val_accuracy: 0.8945
# Epoch 99/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0312 - accuracy: 0.9873 - val_loss: 0.4823 - val_accuracy: 0.8924
# Epoch 100/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0524 - accuracy: 0.9792 - val_loss: 0.4392 - val_accuracy: 0.9008
# Epoch 101/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0520 - accuracy: 0.9764 - val_loss: 0.5226 - val_accuracy: 0.8903
# Epoch 102/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0424 - accuracy: 0.9846 - val_loss: 0.6557 - val_accuracy: 0.8903
# Epoch 103/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0334 - accuracy: 0.9900 - val_loss: 0.5877 - val_accuracy: 0.8945
# Epoch 104/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0371 - accuracy: 0.9855 - val_loss: 0.6469 - val_accuracy: 0.8861
# Epoch 105/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0423 - accuracy: 0.9828 - val_loss: 0.6319 - val_accuracy: 0.8819
# Epoch 106/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0572 - accuracy: 0.9764 - val_loss: 0.4480 - val_accuracy: 0.8861
# Epoch 107/200
# 35/35 [==============================] - 6s 181ms/step - loss: 0.0568 - accuracy: 0.9810 - val_loss: 0.5474 - val_accuracy: 0.8903
# Epoch 108/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0519 - accuracy: 0.9792 - val_loss: 0.5358 - val_accuracy: 0.8924
# Epoch 109/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0486 - accuracy: 0.9783 - val_loss: 0.6848 - val_accuracy: 0.8797
# Epoch 110/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0512 - accuracy: 0.9837 - val_loss: 0.4373 - val_accuracy: 0.8840
# Epoch 111/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0482 - accuracy: 0.9828 - val_loss: 0.6909 - val_accuracy: 0.8776
# Epoch 112/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0623 - accuracy: 0.9792 - val_loss: 0.5308 - val_accuracy: 0.8903
# Epoch 113/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0435 - accuracy: 0.9837 - val_loss: 0.6532 - val_accuracy: 0.8924
# Epoch 114/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0381 - accuracy: 0.9846 - val_loss: 0.5627 - val_accuracy: 0.8966
# Epoch 115/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0341 - accuracy: 0.9873 - val_loss: 0.5810 - val_accuracy: 0.8966
# Epoch 116/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0369 - accuracy: 0.9873 - val_loss: 0.6879 - val_accuracy: 0.8924
# Epoch 117/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0467 - accuracy: 0.9819 - val_loss: 0.5002 - val_accuracy: 0.8861
# Epoch 118/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0361 - accuracy: 0.9846 - val_loss: 0.5509 - val_accuracy: 0.9008
# Epoch 119/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0479 - accuracy: 0.9801 - val_loss: 0.5210 - val_accuracy: 0.8987
# Epoch 120/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0565 - accuracy: 0.9755 - val_loss: 0.6519 - val_accuracy: 0.8840
# Epoch 121/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0495 - accuracy: 0.9783 - val_loss: 0.4633 - val_accuracy: 0.8903
# Epoch 122/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0512 - accuracy: 0.9792 - val_loss: 0.5427 - val_accuracy: 0.8945
# Epoch 123/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0646 - accuracy: 0.9728 - val_loss: 0.6206 - val_accuracy: 0.8882
# Epoch 124/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0493 - accuracy: 0.9801 - val_loss: 0.5918 - val_accuracy: 0.8840
# Epoch 125/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0555 - accuracy: 0.9801 - val_loss: 0.5395 - val_accuracy: 0.9008
# Epoch 126/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0431 - accuracy: 0.9837 - val_loss: 0.5076 - val_accuracy: 0.8882
# Epoch 127/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0355 - accuracy: 0.9855 - val_loss: 0.5408 - val_accuracy: 0.8966
# Epoch 128/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0350 - accuracy: 0.9864 - val_loss: 0.6123 - val_accuracy: 0.8987
# Epoch 129/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0377 - accuracy: 0.9828 - val_loss: 0.5704 - val_accuracy: 0.8924
# Epoch 130/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0396 - accuracy: 0.9837 - val_loss: 0.5281 - val_accuracy: 0.8987
# Epoch 131/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0425 - accuracy: 0.9837 - val_loss: 0.5073 - val_accuracy: 0.9008
# Epoch 132/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0397 - accuracy: 0.9828 - val_loss: 0.6892 - val_accuracy: 0.8861
# Epoch 133/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0362 - accuracy: 0.9873 - val_loss: 0.7188 - val_accuracy: 0.8903
# Epoch 134/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0293 - accuracy: 0.9882 - val_loss: 0.6611 - val_accuracy: 0.8945
# Epoch 135/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0371 - accuracy: 0.9873 - val_loss: 0.7663 - val_accuracy: 0.8861
# Epoch 136/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0429 - accuracy: 0.9828 - val_loss: 0.8121 - val_accuracy: 0.8819
# Epoch 137/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0289 - accuracy: 0.9882 - val_loss: 0.8110 - val_accuracy: 0.8924
# Epoch 138/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0487 - accuracy: 0.9774 - val_loss: 0.5782 - val_accuracy: 0.8945
# Epoch 139/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0375 - accuracy: 0.9828 - val_loss: 0.8300 - val_accuracy: 0.8819
# Epoch 140/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0283 - accuracy: 0.9882 - val_loss: 0.6727 - val_accuracy: 0.8987
# Epoch 141/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0420 - accuracy: 0.9819 - val_loss: 0.5819 - val_accuracy: 0.8945
# Epoch 142/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0312 - accuracy: 0.9891 - val_loss: 0.7364 - val_accuracy: 0.8903
# Epoch 143/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0236 - accuracy: 0.9900 - val_loss: 0.7722 - val_accuracy: 0.8861
# Epoch 144/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0342 - accuracy: 0.9855 - val_loss: 0.8571 - val_accuracy: 0.8903
# Epoch 145/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0275 - accuracy: 0.9891 - val_loss: 0.6746 - val_accuracy: 0.8966
# Epoch 146/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0326 - accuracy: 0.9909 - val_loss: 0.7337 - val_accuracy: 0.8966
# Epoch 147/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0457 - accuracy: 0.9855 - val_loss: 0.6933 - val_accuracy: 0.8945
# Epoch 148/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0432 - accuracy: 0.9882 - val_loss: 0.6116 - val_accuracy: 0.8924
# Epoch 149/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0356 - accuracy: 0.9855 - val_loss: 0.6739 - val_accuracy: 0.8861
# Epoch 150/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0383 - accuracy: 0.9819 - val_loss: 0.7731 - val_accuracy: 0.8861
# Epoch 151/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0486 - accuracy: 0.9792 - val_loss: 0.7143 - val_accuracy: 0.8903
# Epoch 152/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0579 - accuracy: 0.9728 - val_loss: 0.6831 - val_accuracy: 0.8903
# Epoch 153/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0622 - accuracy: 0.9728 - val_loss: 0.5867 - val_accuracy: 0.8903
# Epoch 154/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0550 - accuracy: 0.9764 - val_loss: 0.7060 - val_accuracy: 0.8924
# Epoch 155/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0625 - accuracy: 0.9719 - val_loss: 0.6637 - val_accuracy: 0.8966
# Epoch 156/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0542 - accuracy: 0.9746 - val_loss: 0.7559 - val_accuracy: 0.8945
# Epoch 157/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0372 - accuracy: 0.9900 - val_loss: 0.7953 - val_accuracy: 0.8819
# Epoch 158/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0454 - accuracy: 0.9801 - val_loss: 0.6836 - val_accuracy: 0.8924
# Epoch 159/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0310 - accuracy: 0.9891 - val_loss: 0.6393 - val_accuracy: 0.8945
# Epoch 160/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0356 - accuracy: 0.9855 - val_loss: 0.7741 - val_accuracy: 0.8882
# Epoch 161/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0276 - accuracy: 0.9900 - val_loss: 0.8100 - val_accuracy: 0.8861
# Epoch 162/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0309 - accuracy: 0.9873 - val_loss: 0.8946 - val_accuracy: 0.8882
# Epoch 163/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0280 - accuracy: 0.9918 - val_loss: 1.0431 - val_accuracy: 0.8819
# Epoch 164/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0305 - accuracy: 0.9873 - val_loss: 0.8721 - val_accuracy: 0.8903
# Epoch 165/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0220 - accuracy: 0.9909 - val_loss: 0.8106 - val_accuracy: 0.8861
# Epoch 166/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0343 - accuracy: 0.9891 - val_loss: 0.9070 - val_accuracy: 0.8861
# Epoch 167/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0413 - accuracy: 0.9855 - val_loss: 0.7612 - val_accuracy: 0.8861
# Epoch 168/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0325 - accuracy: 0.9828 - val_loss: 0.7382 - val_accuracy: 0.8966
# Epoch 169/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0425 - accuracy: 0.9846 - val_loss: 0.8074 - val_accuracy: 0.8945
# Epoch 170/200
# 35/35 [==============================] - 6s 181ms/step - loss: 0.0449 - accuracy: 0.9837 - val_loss: 0.7607 - val_accuracy: 0.8861
# Epoch 171/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0234 - accuracy: 0.9918 - val_loss: 0.6874 - val_accuracy: 0.8882
# Epoch 172/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0324 - accuracy: 0.9873 - val_loss: 0.8625 - val_accuracy: 0.8966
# Epoch 173/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0348 - accuracy: 0.9891 - val_loss: 0.7950 - val_accuracy: 0.8966
# Epoch 174/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0211 - accuracy: 0.9873 - val_loss: 0.8093 - val_accuracy: 0.8987
# Epoch 175/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0282 - accuracy: 0.9873 - val_loss: 0.7015 - val_accuracy: 0.8987
# Epoch 176/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.9312 - val_accuracy: 0.8945
# Epoch 177/200
# 35/35 [==============================] - 6s 181ms/step - loss: 0.0299 - accuracy: 0.9882 - val_loss: 0.7082 - val_accuracy: 0.8987
# Epoch 178/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0249 - accuracy: 0.9882 - val_loss: 0.6545 - val_accuracy: 0.8966
# Epoch 179/200
# 35/35 [==============================] - 6s 181ms/step - loss: 0.0310 - accuracy: 0.9900 - val_loss: 0.6812 - val_accuracy: 0.8903
# Epoch 180/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0323 - accuracy: 0.9846 - val_loss: 0.8034 - val_accuracy: 0.8819
# Epoch 181/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0332 - accuracy: 0.9864 - val_loss: 0.7026 - val_accuracy: 0.8924
# Epoch 182/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0526 - accuracy: 0.9810 - val_loss: 0.6592 - val_accuracy: 0.8819
# Epoch 183/200
# 35/35 [==============================] - 6s 181ms/step - loss: 0.0418 - accuracy: 0.9837 - val_loss: 0.8132 - val_accuracy: 0.8987
# Epoch 184/200
# 35/35 [==============================] - 6s 182ms/step - loss: 0.0320 - accuracy: 0.9846 - val_loss: 0.7524 - val_accuracy: 0.8903
# Epoch 185/200
# 35/35 [==============================] - 6s 179ms/step - loss: 0.0312 - accuracy: 0.9909 - val_loss: 0.7211 - val_accuracy: 0.8945
# Epoch 186/200
# 35/35 [==============================] - 6s 173ms/step - loss: 0.0428 - accuracy: 0.9855 - val_loss: 0.8282 - val_accuracy: 0.8882
# Epoch 187/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0344 - accuracy: 0.9846 - val_loss: 0.6997 - val_accuracy: 0.8924
# Epoch 188/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0321 - accuracy: 0.9864 - val_loss: 0.8916 - val_accuracy: 0.8819
# Epoch 189/200
# 35/35 [==============================] - 6s 174ms/step - loss: 0.0230 - accuracy: 0.9909 - val_loss: 0.9165 - val_accuracy: 0.8819
# Epoch 190/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0293 - accuracy: 0.9891 - val_loss: 0.9214 - val_accuracy: 0.8840
# Epoch 191/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0400 - accuracy: 0.9837 - val_loss: 0.7333 - val_accuracy: 0.8987
# Epoch 192/200
# 35/35 [==============================] - 6s 172ms/step - loss: 0.0289 - accuracy: 0.9873 - val_loss: 0.8422 - val_accuracy: 0.8924
# Epoch 193/200
# 35/35 [==============================] - 6s 178ms/step - loss: 0.0285 - accuracy: 0.9882 - val_loss: 0.9605 - val_accuracy: 0.8861
# Epoch 194/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0723 - accuracy: 0.9737 - val_loss: 0.7024 - val_accuracy: 0.8861
# Epoch 195/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0609 - accuracy: 0.9728 - val_loss: 0.6582 - val_accuracy: 0.8924
# Epoch 196/200
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0573 - accuracy: 0.9774 - val_loss: 0.9486 - val_accuracy: 0.8734
# Epoch 197/200
# 35/35 [==============================] - 6s 170ms/step - loss: 0.0399 - accuracy: 0.9828 - val_loss: 0.6477 - val_accuracy: 0.8882
# Epoch 198/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0450 - accuracy: 0.9837 - val_loss: 0.7368 - val_accuracy: 0.8882
# Epoch 199/200
# 35/35 [==============================] - 6s 180ms/step - loss: 0.0366 - accuracy: 0.9846 - val_loss: 0.7358 - val_accuracy: 0.8924
# Epoch 200/200
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0260 - accuracy: 0.9900 - val_loss: 0.7842 - val_accuracy: 0.8882
# 15/15 [==============================] - 1s 71ms/step - loss: 0.7842 - accuracy: 0.8882
# Test Accuracy: 88.82%

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 150, 150, 3)       30
#
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_6 (Flatten)         (None, 8192)              0
#
#  dense_12 (Dense)            (None, 128)               1048704
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 15763809 (60.13 MB)
# Trainable params: 1049121 (4.00 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
num_images_to_display = 10
selected_indices = np.random.choice(len(X_test), num_images_to_display, replace=False)
class_names = ['Benign', 'Malignant', 'Normal']
# Create a subplot grid
num_rows = 2
num_cols = num_images_to_display // num_rows
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 8))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Display predictions for the selected test images
for i, index in enumerate(selected_indices):
    # Get the test image and true label
    test_image = X_test[index]
    true_label = np.argmax(y_test[index])

    # Preprocess the image
    img_array = np.expand_dims(test_image, axis=0)

    # Make predictions
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions)

    # Display the image
    ax = axes[i]
    ax.imshow(test_image.reshape((150, 150)), cmap='gray')
    ax.set_title(f'True: {class_names[true_label]}, Predicted: {class_names[predicted_class]}')
    ax.axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
plt.savefig('/content/drive/MyDrive/Dataset BUSI with GT/prediction.png')
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model


# Save the trained model
model.save('/content/drive/MyDrive/Dataset BUSI with GT/modelvgg16.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Load the model
loaded_model = load_model('/content/drive/MyDrive/Dataset BUSI with GT/modelvgg16.h5')

# Evaluate the model on the test set
y_pred = loaded_model.predict(X_test)

# Convert one-hot encoded labels back to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Plot confusion matrix with seaborn
conf_mat = confusion_matrix(y_true_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=['Benign', 'Malignant', 'Normal'], yticklabels=['Benign', 'Malignant', 'Normal'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot classification report
class_report = classification_report(y_true_classes, y_pred_classes, target_names=['Benign', 'Malignant', 'Normal'])
print('Classification Report:\n', class_report)
# Out:
# 15/15 [==============================] - 1s 70ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Benign       0.88      0.94      0.91       268
#    Malignant       0.87      0.84      0.85       126
#       Normal       0.97      0.80      0.88        80
#
#     accuracy                           0.89       474
#    macro avg       0.91      0.86      0.88       474
# weighted avg       0.89      0.89      0.89       474

# %%
# Visualize input-to-output
for i in range(5):  # You can adjust the range based on the number of samples you want to visualize
    input_image = X_test[i].reshape((150, 150))  # Assuming your input shape is (150, 150, 1)
    output_probabilities = y_pred[i]
    predicted_class = np.argmax(output_probabilities)

    plt.figure(figsize=(8, 4))

    # Plot input image
    plt.subplot(1, 2, 1)
    plt.imshow(input_image, cmap='gray')
    plt.title('Input Image')

    # Plot output probabilities
    plt.subplot(1, 2, 2)
    plt.bar(range(len(output_probabilities)), output_probabilities)
    plt.xticks(range(len(output_probabilities)), ['Benign', 'Malignant', 'Normal'])
    plt.title('Output Probabilities')

    plt.show()
